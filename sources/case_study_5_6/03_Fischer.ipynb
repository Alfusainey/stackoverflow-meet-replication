# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
# %config Completer.use_jedi = False

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42


sns.set(style="whitegrid", color_codes=True)
sns.set_context("paper")

sns.set(style="whitegrid", color_codes=True)
color_blind = ["#999999", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7", "#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
divert_color = ['#a6611a','#dfc27d','#f5f5f5','#80cdc1','#018571']

from itertools import combinations
from collections import Counter

# %%
df_fischer = pd.read_csv('data/fischer_questions.csv', parse_dates=True)

# %%
df_fischer
# Out:
#       QuestionId                                               Tags  \
# 0       10012918                      <java><passwords><encryption>
# 1       10012918                      <java><passwords><encryption>
# 2        1009996                               <java><cryptography>
# 3       10136585                              <java><php><rijndael>
# 4       10136585                              <java><php><rijndael>
# ...          ...                                                ...
# 9363    31939111                                     <android><ssl>
# 9364    36548757                              <java><security><ssl>
# 9365    37937535  <android><google-play><android-security><trust...
# 9366    40914688             <java><x509><pki><java-security><ocsp>
# 9367    43759624                <java><oracle><ssl><plsql><sonicmq>
#
#              CreationDate
# 0     2012-04-04 14:14:00
# 1     2012-04-04 14:14:00
# 2     2009-06-17 23:18:23
# 3     2012-04-13 07:05:12
# 4     2012-04-13 07:05:12
# ...                   ...
# 9363  2015-08-11 10:19:25
# 9364  2016-04-11 12:30:13
# 9365  2016-06-21 07:01:10
# 9366  2016-12-01 15:37:21
# 9367  2017-05-03 12:07:52
#
# [9368 rows x 3 columns]

# %%
df_all_tags = pd.read_feather('data/feather_files/Tags_September_2023.feather')

# %%
df_all_tags['Tags'] = df_all_tags['Tags'].str.replace('><', ' ')
df_all_tags['Tags'] = df_all_tags['Tags'].str.replace('<', '')
df_all_tags['Tags'] = df_all_tags['Tags'].str.replace('>', '')
df_all_tags['Tags'] = df_all_tags['Tags'].str.split(' ')

# %%
display(df_all_tags)
# Out:
#           QuestionId                                               Tags  \
# 0                  4  [c#, floating-point, type-conversion, double, ...
# 1                  6                   [html, css, internet-explorer-7]
# 2                  9                               [c#, .net, datetime]
# 3                 11  [c#, datetime, time, datediff, relative-time-s...
# 4                 13  [html, browser, timezone, user-agent, timezone...
# ...              ...                                                ...
# 23876738    77031693             [next.js, supabase, supabase-database]
# 23876739    77031694                   [javascript, arrays, html-table]
# 23876740    77031699  [flutter, kotlin, dart, bluetooth-lowenergy, p...
# 23876741    77031700                                   [python, memory]
# 23876742    77031706                                             [java]
#
#                  CreationDate
# 0         2008-07-31 21:42:52
# 1         2008-07-31 22:08:08
# 2         2008-07-31 23:40:59
# 3         2008-07-31 23:55:37
# 4         2008-08-01 00:42:38
# ...                       ...
# 23876738  2023-09-03 09:32:29
# 23876739  2023-09-03 09:32:56
# 23876740  2023-09-03 09:33:37
# 23876741  2023-09-03 09:33:40
# 23876742  2023-09-03 09:34:45
#
# [23876743 rows x 3 columns]

# %%
print(len(df_all_tags))
# Out:
# 23876743

# %%
c_tuples = Counter()
c_tags = Counter()
for tags in df_fischer.Tags.items():
    tag_list = tags[1].replace('<','').replace('>', ' ').strip().split(' ')
    tag_list = sorted(tag_list)
    if 'android' in tag_list:
        tag_list.insert(0, tag_list.pop(tag_list.index('android')))
    if 'java' in tag_list:
        tag_list.insert(0, tag_list.pop(tag_list.index('java')))
    c_tags.update(tag_list)
    c_tuples.update(combinations(tag_list,r=2))
display(c_tuples)
display(c_tags)
# Out:
# Counter({('java', 'encryption'): 3325,
#          ('java', 'aes'): 1684,
#          ('aes', 'encryption'): 1509,
#          ('java', 'android'): 1418,
#          ('android', 'encryption'): 1229,
#          ('java', 'cryptography'): 1135,
#          ('cryptography', 'encryption'): 820,
#          ('java', 'ssl'): 812,
#          ('android', 'aes'): 528,
#          ('android', 'ssl'): 471,
#          ('aes', 'cryptography'): 435,
#          ('java', 'php'): 355,
#          ('java', 'c#'): 332,
#          ('java', 'security'): 326,
#          ('java', 'rsa'): 323,
#          ('java', 'https'): 291,
#          ('android', 'cryptography'): 271,
#          ('encryption', 'php'): 262,
#          ('https', 'ssl'): 245,
#          ('c#', 'encryption'): 244,
#          ('encryption', 'rsa'): 244,
#          ('android', 'https'): 230,
#          ('java', 'bouncycastle'): 219,
#          ('java', 'hash'): 219,
#          ('java', 'md5'): 211,
#          ('encryption', 'security'): 164,
#          ('java', 'javascript'): 162,
#          ('android', 'php'): 144,
#          ('android', 'facebook'): 141,
#          ('java', 'base64'): 139,
#          ('java', 'des'): 133,
#          ('java', 'sockets'): 129,
#          ('java', 'ssl-certificate'): 128,
#          ('java', 'jce'): 126,
#          ('aes', 'php'): 124,
#          ('java', 'openssl'): 124,
#          ('ssl', 'ssl-certificate'): 123,
#          ('encryption', 'javascript'): 121,
#          ('des', 'encryption'): 118,
#          ('android', 'rsa'): 114,
#          ('encryption', 'ios'): 112,
#          ('bouncycastle', 'encryption'): 110,
#          ('aes', 'c#'): 104,
#          ('android', 'ios'): 104,
#          ('java', 'python'): 103,
#          ('android', 'c#'): 101,
#          ('android', 'ssl-certificate'): 98,
#          ('android', 'security'): 92,
#          ('java', 'web-services'): 92,
#          ('java', 'sha256'): 91,
#          ('java', 'arrays'): 89,
#          ('java', 'node.js'): 87,
#          ('java', 'string'): 87,
#          ('base64', 'encryption'): 86,
#          ('aes', 'ios'): 86,
#          ('java', 'exception'): 85,
#          ('java', 'sha1'): 84,
#          ('java', 'cryptojs'): 82,
#          ('java', '3des'): 81,
#          ('cryptography', 'security'): 81,
#          ('aes', 'javascript'): 81,
#          ('java', 'certificate'): 81,
#          ('java', 'encoding'): 80,
#          ('c#', 'cryptography'): 78,
#          ('java', 'objective-c'): 77,
#          ('bouncycastle', 'cryptography'): 76,
#          ('encryption', 'openssl'): 76,
#          ('java', 'keystore'): 75,
#          ('certificate', 'ssl'): 75,
#          ('android', 'okhttp'): 73,
#          ('encryption', 'node.js'): 70,
#          ('sockets', 'ssl'): 70,
#          ('cryptography', 'rsa'): 70,
#          ('encryption', 'jce'): 70,
#          ('3des', 'encryption'): 69,
#          ('java', '.net'): 69,
#          ('java', 'encryption-symmetric'): 68,
#          ('java', 'blowfish'): 68,
#          ('encryption', 'objective-c'): 66,
#          ('cryptojs', 'encryption'): 65,
#          ('cryptography', 'php'): 64,
#          ('encryption', 'python'): 64,
#          ('java', 'ios'): 64,
#          ('aes', 'cryptojs'): 64,
#          ('security', 'ssl'): 64,
#          ('java', 'hmac'): 63,
#          ('java', 'httpclient'): 62,
#          ('java', 'file'): 61,
#          ('java', 'ruby'): 61,
#          ('android', 'base64'): 60,
#          ('android', 'hash'): 60,
#          ('java', 'padding'): 59,
#          ('aes', 'security'): 59,
#          ('java', 'sha'): 59,
#          ('hash', 'md5'): 59,
#          ('java', 'public-key-encryption'): 58,
#          ('encryption', 'encryption-symmetric'): 57,
#          ('badpaddingexception', 'encryption'): 57,
#          ('cryptojs', 'javascript'): 57,
#          ('aes', 'python'): 54,
#          ('android', 'httpsurlconnection'): 54,
#          ('aes', 'bouncycastle'): 53,
#          ('aes', 'base64'): 53,
#          ('java', 'badpaddingexception'): 53,
#          ('java', 'apache-httpclient-4.x'): 53,
#          ('keystore', 'ssl'): 53,
#          ('aes', 'openssl'): 52,
#          ('aes', 'cbc-mode'): 52,
#          ('java', 'tripledes'): 51,
#          ('encoding', 'encryption'): 51,
#          ('java', 'spring'): 51,
#          ('encryption', 'exception'): 50,
#          ('blowfish', 'encryption'): 49,
#          ('java', 'rest'): 49,
#          ('java', 'http'): 49,
#          ('encryption', 'padding'): 48,
#          ('encryption', 'ruby'): 48,
#          ('java', 'aes-gcm'): 48,
#          ('ssl', 'sslhandshakeexception'): 48,
#          ('android', 'sockets'): 47,
#          ('java', 'eclipse'): 47,
#          ('android', 'bouncycastle'): 47,
#          ('android', 'md5'): 47,
#          ('android', 'certificate'): 47,
#          ('java', 'passwords'): 46,
#          ('java', 'rijndael'): 46,
#          ('java', 'cbc-mode'): 46,
#          ('java', 'message-digest'): 46,
#          ('okhttp', 'ssl'): 46,
#          ('encryption', 'sockets'): 45,
#          ('java', 'soap'): 45,
#          ('ios', 'objective-c'): 45,
#          ('java', 'mysql'): 45,
#          ('encryption', 'file'): 44,
#          ('java', 'authentication'): 44,
#          ('encryption', 'tripledes'): 43,
#          ('arrays', 'encryption'): 42,
#          ('.net', 'encryption'): 42,
#          ('java', 'algorithm'): 42,
#          ('algorithm', 'encryption'): 42,
#          ('java', 'digital-signature'): 42,
#          ('java', 'sslhandshakeexception'): 42,
#          ('android', 'json'): 41,
#          ('aes', 'badpaddingexception'): 40,
#          ('httpclient', 'ssl'): 40,
#          ('ssl', 'web-services'): 40,
#          ('cryptography', 'node.js'): 39,
#          ('cryptography', 'javascript'): 39,
#          ('aes', 'padding'): 39,
#          ('android', 'android-volley'): 39,
#          ('https', 'ssl-certificate'): 39,
#          ('encryption', 'string'): 38,
#          ('android', 'exception'): 38,
#          ('aes', 'objective-c'): 38,
#          ('android', 'http'): 38,
#          ('java', 'tomcat'): 37,
#          ('encryption', 'public-key-encryption'): 37,
#          ('java', 'x509certificate'): 37,
#          ('java', 'javax.crypto'): 35,
#          ('aes', 'encryption-symmetric'): 35,
#          ('.net', 'c#'): 35,
#          ('java', 'byte'): 35,
#          ('android', 'android-asynctask'): 34,
#          ('encryption', 'rijndael'): 34,
#          ('java', 'secret-key'): 34,
#          ('java', 'multithreading'): 34,
#          ('android', 'keystore'): 34,
#          ('java', 'performance'): 33,
#          ('aes', 'rsa'): 33,
#          ('android', 'web-services'): 33,
#          ('apache-httpclient-4.x', 'ssl'): 33,
#          ('android', 'file'): 32,
#          ('java', 'jsp'): 32,
#          ('android', 'python'): 32,
#          ('android', 'openssl'): 32,
#          ('cbc-mode', 'encryption'): 32,
#          ('java', 'initialization-vector'): 32,
#          ('android', 'httpclient'): 32,
#          ('java', 'servlets'): 31,
#          ('java', 'c'): 31,
#          ('java', 'xml'): 31,
#          ('aes', 'encoding'): 31,
#          ('java', 'post'): 31,
#          ('encryption', 'passwords'): 30,
#          ('android', '.net'): 30,
#          ('encryption', 'md5'): 30,
#          ('encryption', 'iphone'): 30,
#          ('java', 'c++'): 30,
#          ('aes-gcm', 'encryption'): 30,
#          ('cryptography', 'jce'): 30,
#          ('android', 'android-studio'): 30,
#          ('android', 'android-keystore'): 30,
#          ('java', 'java-security'): 30,
#          ('hash', 'sha'): 30,
#          ('android', 'retrofit'): 30,
#          ('encryption', 'ssl'): 29,
#          ('android', 'string'): 29,
#          ('aes', 'node.js'): 29,
#          ('aes', 'ruby'): 29,
#          ('android', 'authentication'): 29,
#          ('http', 'https'): 29,
#          ('android', 'httpurlconnection'): 29,
#          ('java', 'httpsurlconnection'): 29,
#          ('java', 'tls1.2'): 29,
#          ('java', 'key'): 28,
#          ('bouncycastle', 'rsa'): 28,
#          ('java', 'file-io'): 28,
#          ('java', 'vb.net'): 28,
#          ('java', 'password-encryption'): 28,
#          ('android', 'objective-c'): 28,
#          ('java', 'apache'): 28,
#          ('android', 'x509certificate'): 28,
#          ('android', 'sslhandshakeexception'): 28,
#          ('ssl', 'x509certificate'): 28,
#          ('ssl', 'tls1.2'): 28,
#          ('aes', 'arrays'): 27,
#          ('java', 'iphone'): 27,
#          ('encryption', 'initialization-vector'): 27,
#          ('java', 'jakarta-ee'): 27,
#          ('aes', 'exception'): 27,
#          ('aes', 'jce'): 27,
#          ('java', 'encryption-asymmetric'): 27,
#          ('java', 'hex'): 27,
#          ('c#', 'rsa'): 27,
#          ('httpsurlconnection', 'ssl'): 27,
#          ('java', 'salt'): 26,
#          ('public-key-encryption', 'rsa'): 26,
#          ('jsse', 'ssl'): 26,
#          ('android', 'self-signed'): 26,
#          ('android', 'retrofit2'): 26,
#          ('cryptography', 'des'): 25,
#          ('cryptography', 'public-key-encryption'): 25,
#          ('java', 'json'): 25,
#          ('encryption', 'secret-key'): 25,
#          ('javascript', 'node.js'): 25,
#          ('java', 'hibernate'): 25,
#          ('android', 'image'): 25,
#          ('aes-gcm', 'cryptography'): 25,
#          ('hash', 'sha1'): 25,
#          ('java', 'sha512'): 25,
#          ('java', 'api'): 25,
#          ('java', 'amazon-web-services'): 25,
#          ('java', 'httpurlconnection'): 25,
#          ('hash', 'sha256'): 25,
#          ('android', 'encryption-symmetric'): 24,
#          ('android', 'javascript'): 24,
#          ('java', 'facebook'): 24,
#          ('self-signed', 'ssl'): 24,
#          ('md5', 'php'): 23,
#          ('java', 'block-cipher'): 23,
#          ('aes', 'file'): 23,
#          ('android', 'badpaddingexception'): 23,
#          ('java', 'mcrypt'): 23,
#          ('encryption', 'mcrypt'): 23,
#          ('rsa', 'security'): 23,
#          ('cryptography', 'hash'): 23,
#          ('java', 'scala'): 23,
#          ('bouncycastle', 'c#'): 23,
#          ('soap', 'web-services'): 23,
#          ('android', 'facebook-graph-api'): 23,
#          ('handshake', 'ssl'): 23,
#          ('http', 'ssl'): 23,
#          ('encryption', 'password-encryption'): 22,
#          ('java', 'inputstream'): 22,
#          ('android', 'eclipse'): 22,
#          ('android', 'node.js'): 22,
#          ('android', 'bitmap'): 22,
#          ('cryptography', 'cryptojs'): 22,
#          ('java', 'stream'): 22,
#          ('java', 'character-encoding'): 22,
#          ('cryptography', 'python'): 22,
#          ('md5', 'message-digest'): 22,
#          ('java', 'jax-ws'): 22,
#          ('ssl', 'tomcat'): 22,
#          ('https', 'security'): 22,
#          ('java', 'jsse'): 22,
#          ('okhttp', 'retrofit'): 22,
#          ('java', 'sslsocketfactory'): 22,
#          ('rest', 'ssl'): 22,
#          ('eclipse', 'encryption'): 21,
#          ('c', 'encryption'): 21,
#          ('aes', 'c'): 21,
#          ('encryption', 'hash'): 21,
#          ('arrays', 'string'): 21,
#          ('java', 'linux'): 21,
#          ('android', 'performance'): 21,
#          ('aes', 'initialization-vector'): 21,
#          ('aes', 'sha256'): 21,
#          ('https', 'web-services'): 21,
#          ('ssl', 'sslsocketfactory'): 21,
#          ('retrofit', 'ssl'): 21,
#          ('ecb', 'encryption'): 20,
#          ('bouncycastle', 'jce'): 20,
#          ('encryption', 'vb.net'): 20,
#          ('java', 'nullpointerexception'): 20,
#          ('mcrypt', 'php'): 20,
#          ('java', 'public-key'): 20,
#          ('android', 'android-7.0-nougat'): 20,
#          ('java', 'utf-8'): 20,
#          ('openssl', 'ssl'): 20,
#          ('android', 'android-security'): 20,
#          ('c#', 'hash'): 20,
#          ('facebook', 'facebook-graph-api'): 20,
#          ('ssl', 'truststore'): 20,
#          ('android', 'post'): 20,
#          ('certificate', 'https'): 20,
#          ('cryptography', 'padding'): 19,
#          ('android', 'des'): 19,
#          ('c#', 'sha1'): 19,
#          ('c++', 'encryption'): 19,
#          ('android', 'sharedpreferences'): 19,
#          ('php', 'rsa'): 19,
#          ('java', 'serialization'): 19,
#          ('encryption', 'mysql'): 19,
#          ('cryptography', 'exception'): 19,
#          ('android', 'arrays'): 19,
#          ('cryptography', 'openssl'): 19,
#          ('java', 'keytool'): 19,
#          ('java', 'decode'): 19,
#          ('digital-signature', 'rsa'): 19,
#          ('c#', 'md5'): 19,
#          ('java', 'netty'): 19,
#          ('java', 'websocket'): 19,
#          ('hash', 'php'): 19,
#          ('apache', 'ssl'): 19,
#          ('encryption', 'private-key'): 18,
#          ('encryption', 'oracle'): 18,
#          ('base64', 'php'): 18,
#          ('android', 'public-key-encryption'): 18,
#          ('iphone', 'objective-c'): 18,
#          ('java', 'java-8'): 18,
#          ('java', 'tcp'): 18,
#          ('cryptography', 'objective-c'): 18,
#          ('java', 'android-studio'): 18,
#          ('cryptography', 'ios'): 18,
#          ('android', 'sha'): 18,
#          ('android', 'facebook-android-sdk'): 18,
#          ('java', 'amazon-s3'): 18,
#          ('java', 'jersey'): 18,
#          ('android-volley', 'ssl'): 18,
#          ('netty', 'ssl'): 18,
#          ('java', 'ecb'): 17,
#          ('java', 'private-key'): 17,
#          ('encryption', 'key'): 17,
#          ('encryption', 'javax.crypto'): 17,
#          ('android', 'iphone'): 17,
#          ('encryption', 'video'): 17,
#          ('aes', 'rijndael'): 17,
#          ('c#', 'des'): 17,
#          ('aes', 'secret-key'): 17,
#          ('encryption', 'file-io'): 17,
#          ('android', 'listview'): 17,
#          ('java', 'spring-mvc'): 17,
#          ('encryption', 'image'): 17,
#          ('java', 'android-asynctask'): 17,
#          ('android', 'video'): 17,
#          ('java', 'client'): 17,
#          ('android-keystore', 'encryption'): 17,
#          ('java', 'junit'): 17,
#          ('android', 'sslsocketfactory'): 17,
#          ('soap', 'ssl'): 17,
#          ('java', 'okhttp'): 17,
#          ('aes', 'pkcs#7'): 16,
#          ('encryption', 'jsp'): 16,
#          ('encoding', 'php'): 16,
#          ('android', 'javax.crypto'): 16,
#          ('android', 'nullpointerexception'): 16,
#          ('java', 'jar'): 16,
#          ('java', 'oracle'): 16,
#          ('java', 'diffie-hellman'): 16,
#          ('aes', 'algorithm'): 16,
#          ('aes', 'md5'): 16,
#          ('java', 'url'): 16,
#          ('byte', 'encryption'): 16,
#          ('encryption', 'stream'): 16,
#          ('android', 'android-6.0-marshmallow'): 16,
#          ('android', 'sha1'): 16,
#          ('android', 'facebook-login'): 16,
#          ('java', 'proxy'): 16,
#          ('android', 'trustmanager'): 16,
#          ('https', 'rest'): 16,
#          ('https', 'httpsurlconnection'): 16,
#          ('okhttp', 'retrofit2'): 16,
#          ('android', '3des'): 15,
#          ('java', 'pdf'): 15,
#          ('aes', 'aes-gcm'): 15,
#          ('aes-gcm', 'bouncycastle'): 15,
#          ('android', 'spongycastle'): 15,
#          ('android', 'algorithm'): 15,
#          ('java', 'phpseclib'): 15,
#          ('encryption', 'performance'): 15,
#          ('android', 'android-5.0-lollipop'): 15,
#          ('hibernate', 'spring'): 15,
#          ('java', 'html'): 15,
#          ('java', 'networking'): 15,
#          ('android', 'sha256'): 15,
#          ('java', 'digest'): 15,
#          ('android', 'webview'): 15,
#          ('android', 'http-post'): 15,
#          ('java', 'handshake'): 15,
#          ('java', 'truststore'): 15,
#          ('httpclient', 'https'): 15,
#          ('https', 'keystore'): 15,
#          ('android', 'tls1.2'): 15,
#          ('java', 'pkcs#7'): 14,
#          ('3des', 'c#'): 14,
#          ('bouncycastle', 'security'): 14,
#          ('java', 'apache-commons'): 14,
#          ('java', 'perl'): 14,
#          ('php', 'phpseclib'): 14,
#          ('phpseclib', 'rsa'): 14,
#          ('md5', 'security'): 14,
#          ('java', 'netbeans'): 14,
#          ('android', 'out-of-memory'): 14,
#          ('encryption', 'sha256'): 14,
#          ('cryptography', 'passwords'): 14,
#          ('cbc-mode', 'cryptography'): 14,
#          ('hash', 'security'): 14,
#          ('spring', 'spring-mvc'): 14,
#          ('android', 'encoding'): 14,
#          ('ios', 'swift'): 14,
#          ('encryption', 'utf-8'): 14,
#          ('cryptography', 'hmac'): 14,
#          ('android', 'connection'): 14,
#          ('java', 'checksum'): 14,
#          ('facebook', 'hash'): 14,
#          ('android', 'xmpp'): 14,
#          ('amazon-s3', 'amazon-web-services'): 14,
#          ('https', 'soap'): 14,
#          ('authentication', 'ssl'): 14,
#          ('https', 'x509certificate'): 14,
#          ('ssl-certificate', 'sslhandshakeexception'): 14,
#          ('php', 'rijndael'): 13,
#          ('block-cipher', 'encryption'): 13,
#          ('encryption', 'obfuscation'): 13,
#          ('ios', 'iphone'): 13,
#          ('encryption', 'sha1'): 13,
#          ('java', 'elliptic-curve'): 13,
#          ('algorithm', 'cryptography'): 13,
#          ('pycrypto', 'python'): 13,
#          ('3des', 'php'): 13,
#          ('arrays', 'cryptography'): 13,
#          ('java', 'pkcs#5'): 13,
#          ('java', 'image'): 13,
#          ('encryption', 'xml'): 13,
#          ('encryption', 'sqlite'): 13,
#          ('java', 'client-server'): 13,
#          ('base64', 'encoding'): 13,
#          ('aes', 'javax.crypto'): 13,
#          ('c#', 'rijndael'): 13,
#          ('angularjs', 'encryption'): 13,
#          ('encryption', 'scala'): 13,
#          ('java', 'swing'): 13,
#          ('encryption', 'encryption-asymmetric'): 13,
#          ('android', 'rest'): 13,
#          ('java', 'ftp'): 13,
#          ('android', 'websocket'): 13,
#          ('php', 'sha256'): 13,
#          ('java', 'curl'): 13,
#          ('android-security', 'trustmanager'): 13,
#          ('rest', 'web-services'): 13,
#          ('hmac', 'sha256'): 13,
#          ('jax-ws', 'ssl'): 13,
#          ('aes', 'key'): 12,
#          ('java', 'google-app-engine'): 12,
#          ('android', 'aes-gcm'): 12,
#          ('java', 'classloader'): 12,
#          ('encryption', 'inputstream'): 12,
#          ('java', 'outputstream'): 12,
#          ('java', 'pycrypto'): 12,
#          ('java', 'cryptoapi'): 12,
#          ('encryption', 'salt'): 12,
#          ('badpaddingexception', 'cryptography'): 12,
#          ('java', 'io'): 12,
#          ('encryption', 'windows-phone-8'): 12,
#          ('android', 'multithreading'): 12,
#          ('php', 'security'): 12,
#          ('android', 'ruby'): 12,
#          ('android', 'phpseclib'): 12,
#          ('android', 'sqlite'): 12,
#          ('java', 'maven'): 12,
#          ('cryptography', 'encryption-symmetric'): 12,
#          ('c#', 'ios'): 12,
#          ('byte', 'string'): 12,
#          ('android', 'cryptojs'): 12,
#          ('java', 'network-programming'): 12,
#          ('public-key', 'rsa'): 12,
#          ('openssl', 'rsa'): 12,
#          ('android', 'hmac'): 12,
#          ('aes', 'password-encryption'): 12,
#          ('java', 'x509'): 12,
#          ('java', 'hmacsha1'): 12,
#          ('java', 'jks'): 12,
#          ('c#', 'sha256'): 12,
#          ('android', 'session'): 12,
#          ('base64', 'sha1'): 12,
#          ('facebook', 'facebook-login'): 12,
#          ('smack', 'xmpp'): 12,
#          ('android', 'apache'): 12,
#          ('https', 'post'): 12,
#          ('android', 'android-networking'): 12,
#          ('android', 'soap'): 12,
#          ('java', 'jsoup'): 12,
#          ('jersey', 'ssl'): 12,
#          ('encryption', 'jakarta-ee'): 11,
#          ('encryption', 'pkcs#7'): 11,
#          ('jce', 'security'): 11,
#          ('java', 'groovy'): 11,
#          ('encryption', 'groovy'): 11,
#          ('aes', 'iphone'): 11,
#          ('java', 'database'): 11,
#          ('blowfish', 'cryptography'): 11,
#          ('aes', 'salt'): 11,
#          ('cryptography', 'salt'): 11,
#          ('java', 'fileoutputstream'): 11,
#          ('aes', 'public-key-encryption'): 11,
#          ('aes', 'sockets'): 11,
#          ('java', 'fileinputstream'): 11,
#          ('grails', 'groovy'): 11,
#          ('android', 'xml'): 11,
#          ('java', 'nio'): 11,
#          ('java', 'rijndaelmanaged'): 11,
#          ('cryptography', 'javax.crypto'): 11,
#          ('android', 'inputstream'): 11,
#          ('encryption', 'pbkdf2'): 11,
#          ('java', 'cfb-mode'): 11,
#          ('encryption', 'public-key'): 11,
#          ('ios', 'md5'): 11,
#          ('encryption', 'serialization'): 11,
#          ('character-encoding', 'encryption'): 11,
#          ('java', 'jax-rs'): 11,
#          ('.net', 'aes'): 11,
#          ('java', 'java-me'): 11,
#          ('cryptography', 'mcrypt'): 11,
#          ('ios', 'rsa'): 11,
#          ('c++', 'crypto++'): 11,
#          ('aes', 'passwords'): 11,
#          ('encryption-asymmetric', 'rsa'): 11,
#          ('android', 'cbc-mode'): 11,
#          ('aes', 'pbkdf2'): 11,
#          ('android', 'c++'): 11,
#          ('java', 'jdbc'): 11,
#          ('android', 'android-facebook'): 11,
#          ('java', 'smack'): 11,
#          ('http', 'post'): 11,
#          ('android', 'apache-httpclient-4.x'): 11,
#          ('httpclient', 'ssl-certificate'): 11,
#          ('keystore', 'ssl-certificate'): 11,
#          ('java', 'self-signed'): 11,
#          ('ssl-certificate', 'x509certificate'): 11,
#          ('client-certificates', 'ssl'): 11,
#          ('spring', 'ssl'): 11,
#          ('https', 'okhttp'): 11,
#          ('java', 'client-certificates'): 11,
#          ('java', 'zip'): 10,
#          ('cryptography', 'md5'): 10,
#          ('3des', 'cryptography'): 10,
#          ('cryptography', 'encoding'): 10,
#          ('base64', 'sharedpreferences'): 10,
#          ('java', 'go'): 10,
#          ('encryption', 'perl'): 10,
#          ('java', 'postgresql'): 10,
#          ('c', 'openssl'): 10,
#          ('c++', 'openssl'): 10,
#          ('encryption-symmetric', 'security'): 10,
#          ('encryption', 'java-me'): 10,
#          ('java', 'macos'): 10,
#          ('java', 'encode'): 10,
#          ('encryption', 'windows-phone-7'): 10,
#          ('base64', 'c#'): 10,
#          ('android', 'rijndael'): 10,
#          ('java', 'ruby-on-rails'): 10,
#          ('android', 'vb.net'): 10,
#          ('android', 'nfc'): 10,
#          ('aes', 'rijndaelmanaged'): 10,
#          ('encryption', 'multithreading'): 10,
#          ('aes', 'des'): 10,
#          ('java', 'windows'): 10,
#          ('encryption', 'linux'): 10,
#          ('java', 'unit-testing'): 10,
#          ('java', 'swift'): 10,
#          ('java', 'glassfish'): 10,
#          ('java', 'filenotfoundexception'): 10,
#          ('.net', 'cryptography'): 10,
#          ('java', 'angularjs'): 10,
#          ('android', 'key'): 10,
#          ('android', 'encryption-asymmetric'): 10,
#          ('aes', 'string'): 10,
#          ('aes', 'mcrypt'): 10,
#          ('padding', 'rsa'): 10,
#          ('encryption', 'keystore'): 10,
#          ('java', 'biginteger'): 10,
#          ('encryption', 'hmac'): 10,
#          ('java', 'ctr-mode'): 10,
#          ('aes', 'ctr-mode'): 10,
#          ('android', 'decode'): 10,
#          ('android', 'networking'): 10,
#          ('java', 'signature'): 10,
#          ('cryptography', 'sha1'): 10,
#          ('php', 'sha1'): 10,
#          ('spring', 'spring-security'): 10,
#          ('authentication', 'facebook'): 10,
#          ('facebook', 'facebook-android-sdk'): 10,
#          ('android', 'android-fragments'): 10,
#          ('java', 'itext'): 10,
#          ('java', 'jetty'): 10,
#          ('android', 'oauth-2.0'): 10,
#          ('ssl', 'tcp'): 10,
#          ('ssl', 'websocket'): 10,
#          ('c#', 'hmac'): 10,
#          ('hmac', 'php'): 10,
#          ('ssl', 'webview'): 10,
#          ('jks', 'ssl'): 10,
#          ('android', 'androidhttpclient'): 10,
#          ('android', 'google-play'): 10,
#          ('ssl', 'trustmanager'): 10,
#          ('client', 'ssl'): 10,
#          ('android', 'jsoup'): 10,
#          ('https', 'json'): 10,
#          ('web-services', 'wsdl'): 10,
#          ('bouncycastle', 'ssl'): 10,
#          ('java', 'mifare'): 9,
#          ('database', 'encryption'): 9,
#          ('encryption', 'sharedpreferences'): 9,
#          ('java', 'jboss'): 9,
#          ('coldfusion', 'encryption'): 9,
#          ('java', 'asp.net'): 9,
#          ('aes', 'eclipse'): 9,
#          ('java', 'serversocket'): 9,
#          ('java', 'windows-phone-8'): 9,
#          ('encryption', 'pkcs#5'): 9,
#          ('encryption', 'spongycastle'): 9,
#          ('android', 'android-activity'): 9,
#          ('java', 'pbkdf2'): 9,
#          ('java', 'objectinputstream'): 9,
#          ('c#', 'tripledes'): 9,
#          ('commoncrypto', 'encryption'): 9,
#          ('java', 'integer'): 9,
#          ('encryption', 'keytool'): 9,
#          ('java', 'android-6.0-marshmallow'): 9,
#          ('java', 'spring-security'): 9,
#          ('java', 'smartcard'): 9,
#          ('java', 'key-generator'): 9,
#          ('.net', 'rsa'): 9,
#          ('android', 'padding'): 9,
#          ('openssl', 'ssl-certificate'): 9,
#          ('hmac', 'python'): 9,
#          ('keystore', 'rsa'): 9,
#          ('java', 'android-keystore'): 9,
#          ('aes', 'utf-8'): 9,
#          ('cryptography', 'digital-signature'): 9,
#          ('encryption', 'java-security'): 9,
#          ('c++', 'qt'): 9,
#          ('jax-ws', 'web-services'): 9,
#          ('android', 'amazon-s3'): 9,
#          ('java', 'hashcode'): 9,
#          ('hash', 'passwords'): 9,
#          ('java', 'ftps'): 9,
#          ('java', 'session'): 9,
#          ('android', 'amazon-web-services'): 9,
#          ('ldap', 'ssl'): 9,
#          ('android', 'socket.io'): 9,
#          ('hash', 'sha512'): 9,
#          ('android', 'tcp'): 9,
#          ('java', 'resttemplate'): 9,
#          ('http-post', 'https'): 9,
#          ('android', 'tomcat'): 9,
#          ('java', 'apache-httpcomponents'): 9,
#          ('certificate', 'self-signed'): 9,
#          ('android', 'handshake'): 9,
#          ('android', 'google-maps'): 9,
#          ('java', 'http-status-code-401'): 9,
#          ('json', 'ssl'): 9,
#          ('java', 'urlconnection'): 9,
#          ('java-security', 'ssl'): 9,
#          ('java', 'apple-push-notifications'): 9,
#          ('java', 'oauth'): 9,
#          ('ftp', 'ssl'): 9,
#          ('keystore', 'truststore'): 9,
#          ('jax-ws', 'soap'): 9,
#          ('android', 'android-intent'): 8,
#          ('3des', 'iphone'): 8,
#          ('aes', 'block-cipher'): 8,
#          ('java', 'coldfusion'): 8,
#          ('cryptography', 'elliptic-curve'): 8,
#          ('encryption', 'pycrypto'): 8,
#          ('java', 'sql'): 8,
#          ('java', 'android-ndk'): 8,
#          ('3des', 'objective-c'): 8,
#          ('ios', 'php'): 8,
#          ('java', 'windows-phone-7'): 8,
#          ('encryption', 'ruby-on-rails'): 8,
#          ('java', 'bitmap'): 8,
#          ('c#', 'rijndaelmanaged'): 8,
#          ('java', 'cookies'): 8,
#          ('php', 'tripledes'): 8,
#          ('byte', 'cryptography'): 8,
#          ('blowfish', 'php'): 8,
#          ('c#', 'windows-phone-8'): 8,
#          ('des', 'ruby'): 8,
#          ('cryptography', 'mysql'): 8,
#          ('encryption', 'java-8'): 8,
#          ('aes', 'byte'): 8,
#          ('android-5.0-lollipop', 'encryption'): 8,
#          ('c#', 'windows-phone-7'): 8,
#          ('android', 'pbkdf2'): 8,
#          ('java', 'decoding'): 8,
#          ('objective-c', 'rsa'): 8,
#          ('encryption', 'phpseclib'): 8,
#          ('android', 'ioexception'): 8,
#          ('encryption', 'tcp'): 8,
#          ('md5', 'objective-c'): 8,
#          ('openssl', 'ruby'): 8,
#          ('cryptography', 'file-io'): 8,
#          ('block-cipher', 'cryptography'): 8,
#          ('angularjs', 'javascript'): 8,
#          ('java', 'java-7'): 8,
#          ('android', 'fileoutputstream'): 8,
#          ('cryptography', 'diffie-hellman'): 8,
#          ('java', 'javafx'): 8,
#          ('java', 'udp'): 8,
#          ('java', 'java-6'): 8,
#          ('aes', 'stream'): 8,
#          ('aes', 'pkcs#5'): 8,
#          ('android', 'private-key'): 8,
#          ('java', 'pkcs#12'): 8,
#          ('android', 'wcf'): 8,
#          ('commoncrypto', 'ios'): 8,
#          ('ctr-mode', 'encryption'): 8,
#          ('android', 'parse-platform'): 8,
#          ('aes', 'java-security'): 8,
#          ('android', 'picasso'): 8,
#          ('java', 'password-protection'): 8,
#          ('java', 'qt'): 8,
#          ('android', 'android-emulator'): 8,
#          ('hash', 'javascript'): 8,
#          ('android', 'file-upload'): 8,
#          ('proxy', 'ssl'): 8,
#          ('java', 'ldap'): 8,
#          ('android', 'smack'): 8,
#          ('hash', 'salt'): 8,
#          ('android-volley', 'json'): 8,
#          ('android', 'ksoap2'): 8,
#          ('java', 'cxf'): 8,
#          ('apache-httpclient-4.x', 'ssl-certificate'): 8,
#          ('authentication', 'httpclient'): 8,
#          ('json', 'web-services'): 8,
#          ('java', 'trustmanager'): 8,
#          ('php', 'ssl'): 8,
#          ('ssl', 'weblogic'): 8,
#          ('android', 'client-certificates'): 8,
#          ('android-studio', 'ssl'): 8,
#          ('retrofit2', 'ssl'): 8,
#          ('java', 'smtp'): 8,
#          ('android-volley', 'https'): 8,
#          ('https', 'httpurlconnection'): 8,
#          ('keytool', 'ssl'): 8,
#          ('ksoap2', 'ssl'): 8,
#          ('mqtt', 'ssl'): 8,
#          ('java', 'wsdl'): 8,
#          ('asynchttpclient', 'ssl'): 8,
#          ('cryptography', 'ssl'): 8,
#          ('jetty', 'ssl'): 8,
#          ('retrofit', 'retrofit2'): 8,
#          ('encryption', 'zip'): 7,
#          ('encryption', 'servlets'): 7,
#          ('hex', 'string'): 7,
#          ('java', 'try-catch'): 7,
#          ('cryptography', 'tripledes'): 7,
#          ('blowfish', 'python'): 7,
#          ('base64', 'cryptography'): 7,
#          ('java', 'crypto++'): 7,
#          ('android', 'unit-testing'): 7,
#          ('encryption', 'unit-testing'): 7,
#          ('apache-commons', 'base64'): 7,
#          ('java', 'bash'): 7,
#          ('java', 'javacard'): 7,
#          ('inputstream', 'outputstream'): 7,
#          ('java', 'output'): 7,
#          ('android', 'java-native-interface'): 7,
#          ('3des', 'des'): 7,
#          ('aes', 'java-me'): 7,
#          ('java', 'pkcs#11'): 7,
#          ('java', 'email'): 7,
#          ('encryption', 'image-processing'): 7,
#          ('java', 'out-of-memory'): 7,
#          ('java', 'spongycastle'): 7,
#          ('bouncycastle', 'spongycastle'): 7,
#          ('java', 'jca'): 7,
#          ('encryption', 'message-digest'): 7,
#          ('encryption', 'nullpointerexception'): 7,
#          ('encryption', 'swift'): 7,
#          ('java', 'rmi'): 7,
#          ('arrays', 'byte'): 7,
#          ('android', 'filenotfoundexception'): 7,
#          ('android', 'outputstream'): 7,
#          ('objective-c', 'security'): 7,
#          ('base64', 'md5'): 7,
#          ('java', 'porting'): 7,
#          ('encryption', 'porting'): 7,
#          ('java', 'type-conversion'): 7,
#          ('cryptography', 'ruby'): 7,
#          ('keytool', 'rsa'): 7,
#          ('java', 'pkcs#8'): 7,
#          ('encryption', 'pkcs#8'): 7,
#          ('java', 'server'): 7,
#          ('encoding', 'utf-8'): 7,
#          ('c#', 'encryption-symmetric'): 7,
#          ('ios', 'swift3'): 7,
#          ('java', 'jpa'): 7,
#          ('jce', 'rsa'): 7,
#          ('android', 'secret-key'): 7,
#          ('java', 'sqlite'): 7,
#          ('encryption', 'hex'): 7,
#          ('c', 'cryptography'): 7,
#          ('certificate', 'keystore'): 7,
#          ('android', 'mcrypt'): 7,
#          ('android', 'save'): 7,
#          ('private-key', 'rsa'): 7,
#          ('aes', 'c++'): 7,
#          ('android', 'ksoap'): 7,
#          ('base64', 'rsa'): 7,
#          ('rsa', 'sha1'): 7,
#          ('cbc-mode', 'python'): 7,
#          ('cryptography', 'rijndael'): 7,
#          ('android-keystore', 'keystore'): 7,
#          ('android-keystore', 'rsa'): 7,
#          ('c#', 'sha512'): 7,
#          ('base64', 'ios'): 7,
#          ('decode', 'encryption'): 7,
#          ('base64', 'objective-c'): 7,
#          ('cryptography', 'sha256'): 7,
#          ('java', 'android-security'): 7,
#          ('cryptography', 'initialization-vector'): 7,
#          ('java', 'nginx'): 7,
#          ('android', 'qt'): 7,
#          ('java', 'download'): 7,
#          ('authentication', 'security'): 7,
#          ('md5', 'performance'): 7,
#          ('hash', 'hex'): 7,
#          ('javascript', 'websocket'): 7,
#          ('jsp', 'servlets'): 7,
#          ('java', 'md5sum'): 7,
#          ('android', 'html'): 7,
#          ('base64', 'hash'): 7,
#          ('jsf', 'jsf-2'): 7,
#          ('checksum', 'md5'): 7,
#          ('facebook', 'xmpp'): 7,
#          ('java', 'http-post'): 7,
#          ('file', 'hash'): 7,
#          ('hmac', 'hmacsha1'): 7,
#          ('android-studio', 'facebook'): 7,
#          ('php', 'sha'): 7,
#          ('java', 'weblogic'): 7,
#          ('android', 'cookies'): 7,
#          ('https', 'session'): 7,
#          ('security', 'ssl-certificate'): 7,
#          ('apache', 'httpclient'): 7,
#          ('groovy', 'httpbuilder'): 7,
#          ('apache-commons-httpclient', 'ssl'): 7,
#          ('apache', 'apache-httpclient-4.x'): 7,
#          ('connection', 'ssl'): 7,
#          ('apache-httpclient-4.x', 'https'): 7,
#          ('https', 'proxy'): 7,
#          ('resttemplate', 'spring'): 7,
#          ('openfire', 'smack'): 7,
#          ('smack', 'ssl'): 7,
#          ('keystore', 'web-services'): 7,
#          ('amazon-web-services', 'ssl'): 7,
#          ('networking', 'ssl'): 7,
#          ('ssl-certificate', 'trustmanager'): 7,
#          ('java', 'twitter'): 7,
#          ('c#', 'ssl'): 7,
#          ('httpsurlconnection', 'ssl-certificate'): 7,
#          ('apache-camel', 'ssl'): 7,
#          ('java', 'ibm-mq'): 7,
#          ('des', 'php'): 6,
#          ('des', 'padding'): 6,
#          ('.net', '3des'): 6,
#          ('jsp', 'obfuscation'): 6,
#          ('jsp', 'oracle'): 6,
#          ('obfuscation', 'oracle'): 6,
#          ('javascript', 'md5'): 6,
#          ('3des', 'ios'): 6,
#          ('android', 'password-encryption'): 6,
#          ('base64', 'encryption-symmetric'): 6,
#          ('java', 'pki'): 6,
#          ('blowfish', 'password-encryption'): 6,
#          ('bash', 'encryption'): 6,
#          ('java', 'crypt'): 6,
#          ('encryption', 'outputstream'): 6,
#          ('aes', 'google-app-engine'): 6,
#          ('aes', 'pycrypto'): 6,
#          ('aes', 'asp.net'): 6,
#          ('des', 'ecb'): 6,
#          ('aes', 'cryptoapi'): 6,
#          ('java', 'applet'): 6,
#          ('certificate', 'encryption'): 6,
#          ('encryption', 'fileinputstream'): 6,
#          ('java', 'hadoop'): 6,
#          ('cryptography', 'secret-key'): 6,
#          ('java', 'image-processing'): 6,
#          ('android', 'asp.net'): 6,
#          ('java', 'bufferedreader'): 6,
#          ('passwords', 'security'): 6,
#          ('android', 'blowfish'): 6,
#          ('c#', 'php'): 6,
#          ('aes', 'arduino'): 6,
#          ('encryption', 'jca'): 6,
#          ('encryption', 'objectinputstream'): 6,
#          ('java', 'arraylist'): 6,
#          ('cryptography', 'jakarta-ee'): 6,
#          ('commoncrypto', 'objective-c'): 6,
#          ('des', 'openssl'): 6,
#          ('java', 'memory'): 6,
#          ('encryption', 'integer'): 6,
#          ('java', 'class'): 6,
#          ('aes', 'keytool'): 6,
#          ('java', 'plsql'): 6,
#          ('aescryptoserviceprovider', 'encryption'): 6,
#          ('encryption', 'key-generator'): 6,
#          ('blowfish', 'node.js'): 6,
#          ('diffie-hellman', 'encryption'): 6,
#          ('java', 'video'): 6,
#          ('android', 'android-ndk'): 6,
#          ('algorithm', 'encryption-symmetric'): 6,
#          ('javascript', 'sha1'): 6,
#          ('android', 'firebase'): 6,
#          ('security', 'sockets'): 6,
#          ('java', 'gwt'): 6,
#          ('android-7.0-nougat', 'encryption'): 6,
#          ('cryptography', 'string'): 6,
#          ('android', 'public-key'): 6,
#          ('ssl', 'xmpp'): 6,
#          ('exception', 'rsa'): 6,
#          ('java', 'optimization'): 6,
#          ('encryption', 'save'): 6,
#          ('android', 'java-me'): 6,
#          ('aes', 'image'): 6,
#          ('java', 'jaxb'): 6,
#          ('cryptojs', 'javax.crypto'): 6,
#          ('javascript', 'rsa'): 6,
#          ('aes', 'perl'): 6,
#          ('c#', 'vb.net'): 6,
#          ('android', 'pkcs#7'): 6,
#          ('ios', 'pkcs#7'): 6,
#          ('eclipse', 'jar'): 6,
#          ('keystore', 'security'): 6,
#          ('encryption-asymmetric', 'security'): 6,
#          ('message-digest', 'security'): 6,
#          ('aes', 'vb.net'): 6,
#          ('certificate', 'security'): 6,
#          ('badpaddingexception', 'rsa'): 6,
#          ('java', 'whatsapp'): 6,
#          ('string', 'utf-8'): 6,
#          ('encryption', 'spring'): 6,
#          ('api', 'encryption'): 6,
#          ('algorithm', 'c#'): 6,
#          ('digital-signature', 'sha1'): 6,
#          ('java', 'noclassdeffounderror'): 6,
#          ('android', 'utf-8'): 6,
#          ('android', 'character-encoding'): 6,
#          ('android', 'exoplayer'): 6,
#          ('cfb-mode', 'encryption'): 6,
#          ('java', 'android-7.0-nougat'): 6,
#          ('java', 'python-2.7'): 6,
#          ('cfb-mode', 'python'): 6,
#          ('android', 'spring'): 6,
#          ('decode', 'encode'): 6,
#          ('encryption', 'qt'): 6,
#          ('.net', 'windows-phone-7'): 6,
#          ('hash', 'message-digest'): 6,
#          ('parsing', 'xml'): 6,
#          ('encoding', 'hash'): 6,
#          ('java', 'apache-commons-httpclient'): 6,
#          ('glassfish', 'jdbcrealm'): 6,
#          ('android', 'cordova'): 6,
#          ('spring-mvc', 'spring-security'): 6,
#          ('java', 'xmpp'): 6,
#          ('hash', 'scala'): 6,
#          ('md5', 'scala'): 6,
#          ('bouncycastle', 'digital-signature'): 6,
#          ('json', 'php'): 6,
#          ('java', 'starttls'): 6,
#          ('amazon-ec2', 'amazon-web-services'): 6,
#          ('java', 'jwt'): 6,
#          ('php', 'sha512'): 6,
#          ('digital-signature', 'itext'): 6,
#          ('java', 'wildfly'): 6,
#          ('android', 'oauth'): 6,
#          ('digest', 'md5'): 6,
#          ('java', 'axis'): 6,
#          ('base64', 'sha256'): 6,
#          ('java', 'azure'): 6,
#          ('hash', 'hmac'): 6,
#          ('android-networking', 'androidhttpclient'): 6,
#          ('apache-httpclient-4.x', 'httpclient'): 6,
#          ('java', 'rest-client'): 6,
#          ('java', 'sharepoint'): 6,
#          ('sockets', 'ssl-certificate'): 6,
#          ...})
# Counter({'java': 6984,
#          'encryption': 4064,
#          'android': 3152,
#          'aes': 2055,
#          'cryptography': 1287,
#          'ssl': 1188,
#          'https': 454,
#          'php': 450,
#          'c#': 415,
#          'rsa': 391,
#          'security': 380,
#          'hash': 273,
#          'md5': 256,
#          'bouncycastle': 255,
#          'ssl-certificate': 216,
#          'ios': 206,
#          'javascript': 201,
#          'base64': 183,
#          'des': 158,
#          'openssl': 150,
#          'facebook': 150,
#          'sockets': 147,
#          'objective-c': 137,
#          'web-services': 131,
#          'jce': 128,
#          'python': 127,
#          'certificate': 120,
#          'exception': 114,
#          'sha256': 112,
#          'node.js': 110,
#          'sha1': 105,
#          'cryptojs': 103,
#          'string': 102,
#          'keystore': 101,
#          'arrays': 96,
#          'encoding': 94,
#          '3des': 92,
#          'encryption-symmetric': 91,
#          '.net': 91,
#          'httpclient': 87,
#          'okhttp': 82,
#          'file': 79,
#          'authentication': 79,
#          'blowfish': 78,
#          'ruby': 77,
#          'public-key-encryption': 77,
#          'spring': 75,
#          'http': 74,
#          'sha': 73,
#          'httpsurlconnection': 71,
#          'padding': 69,
#          'badpaddingexception': 68,
#          'sslhandshakeexception': 68,
#          'hmac': 67,
#          'rest': 66,
#          'apache-httpclient-4.x': 62,
#          'tripledes': 61,
#          'json': 61,
#          'x509certificate': 61,
#          'eclipse': 60,
#          'cbc-mode': 59,
#          'algorithm': 57,
#          'aes-gcm': 57,
#          'soap': 55,
#          'message-digest': 54,
#          'jsp': 53,
#          'scala': 53,
#          'rijndael': 52,
#          'passwords': 51,
#          'mysql': 50,
#          'post': 50,
#          'digital-signature': 48,
#          'tomcat': 47,
#          'httpurlconnection': 47,
#          'iphone': 46,
#          'performance': 46,
#          'tls1.2': 45,
#          'javax.crypto': 44,
#          'jakarta-ee': 43,
#          'password-encryption': 41,
#          'multithreading': 41,
#          'amazon-web-services': 40,
#          'groovy': 39,
#          'c++': 39,
#          'android-volley': 39,
#          'key': 37,
#          'c': 37,
#          'initialization-vector': 37,
#          'secret-key': 37,
#          'byte': 37,
#          'apache': 37,
#          'xml': 36,
#          'servlets': 35,
#          'image': 35,
#          'vb.net': 35,
#          'android-studio': 35,
#          'sslsocketfactory': 35,
#          'self-signed': 35,
#          'android-asynctask': 34,
#          'websocket': 34,
#          'retrofit': 34,
#          'salt': 32,
#          'inputstream': 32,
#          'android-keystore': 32,
#          'hex': 31,
#          'encryption-asymmetric': 31,
#          'java-security': 31,
#          'sha512': 30,
#          'api': 30,
#          'nullpointerexception': 29,
#          'file-io': 28,
#          'mcrypt': 28,
#          'hibernate': 28,
#          'retrofit2': 28,
#          'amazon-s3': 27,
#          'jsse': 27,
#          'swift': 26,
#          'java-8': 26,
#          'stream': 26,
#          'character-encoding': 26,
#          'decode': 26,
#          'spring-mvc': 25,
#          'utf-8': 25,
#          'handshake': 25,
#          'trustmanager': 25,
#          'pkcs#7': 24,
#          'oracle': 24,
#          'public-key': 24,
#          'jax-ws': 24,
#          'facebook-graph-api': 24,
#          'block-cipher': 23,
#          'ecb': 23,
#          'linux': 23,
#          'android-security': 23,
#          'proxy': 23,
#          'jersey': 23,
#          'private-key': 22,
#          'phpseclib': 22,
#          'bitmap': 22,
#          'tcp': 22,
#          'keytool': 22,
#          'digest': 22,
#          'networking': 22,
#          'netty': 22,
#          'smack': 22,
#          'video': 21,
#          'java-me': 21,
#          'grails': 21,
#          'client': 21,
#          'truststore': 21,
#          'android-7.0-nougat': 20,
#          'xmpp': 20,
#          'junit': 20,
#          'connection': 20,
#          'http-post': 20,
#          'google-app-engine': 19,
#          'sharedpreferences': 19,
#          'pdf': 19,
#          'serialization': 19,
#          'html': 19,
#          'client-certificates': 19,
#          'jar': 18,
#          'outputstream': 18,
#          'diffie-hellman': 18,
#          'url': 18,
#          'pbkdf2': 18,
#          'facebook-android-sdk': 18,
#          'webview': 18,
#          'oauth': 18,
#          'javacard': 17,
#          'pycrypto': 17,
#          'pkcs#5': 17,
#          'netbeans': 17,
#          'listview': 17,
#          'android-5.0-lollipop': 17,
#          'spring-security': 17,
#          'angularjs': 17,
#          'weblogic': 17,
#          'encode': 16,
#          'classloader': 16,
#          'io': 16,
#          'javafx': 16,
#          'sqlite': 16,
#          'glassfish': 16,
#          'android-6.0-marshmallow': 16,
#          'session': 16,
#          'facebook-login': 16,
#          'checksum': 16,
#          'curl': 16,
#          'database': 15,
#          'spongycastle': 15,
#          'client-server': 15,
#          'x509': 15,
#          'ldap': 15,
#          'jsoup': 15,
#          'apache-commons': 14,
#          'perl': 14,
#          'asp.net': 14,
#          'out-of-memory': 14,
#          'maven': 14,
#          'smartcard': 14,
#          'jks': 14,
#          'jsf': 14,
#          'ftp': 14,
#          'obfuscation': 13,
#          'crypto++': 13,
#          'elliptic-curve': 13,
#          'unit-testing': 13,
#          'postgresql': 13,
#          'cryptoapi': 13,
#          'macos': 13,
#          'windows-phone-8': 13,
#          'rijndaelmanaged': 13,
#          'commoncrypto': 13,
#          'jax-rs': 13,
#          'swing': 13,
#          'wcf': 13,
#          'signature': 13,
#          'jdbc': 13,
#          'itext': 13,
#          'resttemplate': 13,
#          'jersey-client': 13,
#          'mifare': 12,
#          'jboss': 12,
#          'pkcs#11': 12,
#          'nio': 12,
#          'cookies': 12,
#          'windows': 12,
#          'filenotfoundexception': 12,
#          'jakarta-mail': 12,
#          'network-programming': 12,
#          'qt': 12,
#          'hmacsha1': 12,
#          'android-fragments': 12,
#          'jetty': 12,
#          'oauth-2.0': 12,
#          'android-networking': 12,
#          'fileoutputstream': 11,
#          'fileinputstream': 11,
#          'cfb-mode': 11,
#          'java-7': 11,
#          'server': 11,
#          'jpa': 11,
#          'java-6': 11,
#          'biginteger': 11,
#          'urlconnection': 11,
#          'spring-boot': 11,
#          'hashcode': 11,
#          'android-facebook': 11,
#          'socket.io': 11,
#          'apache-httpcomponents': 11,
#          'twitter': 11,
#          'mqtt': 11,
#          'zip': 10,
#          'go': 10,
#          'cordova': 10,
#          'serversocket': 10,
#          'windows-phone-7': 10,
#          'email': 10,
#          'ruby-on-rails': 10,
#          'nfc': 10,
#          'jsf-2': 10,
#          'arraylist': 10,
#          'ioexception': 10,
#          'pkcs#12': 10,
#          'ctr-mode': 10,
#          'password-protection': 10,
#          'jdbcrealm': 10,
#          'file-upload': 10,
#          'ksoap2': 10,
#          'androidhttpclient': 10,
#          'google-play': 10,
#          'x509trustmanager': 10,
#          'google-maps': 10,
#          'wsdl': 10,
#          'apache-camel': 10,
#          'coldfusion': 9,
#          'sql': 9,
#          'applet': 9,
#          'get': 9,
#          'android-activity': 9,
#          'objectinputstream': 9,
#          'gradle': 9,
#          'porting': 9,
#          'integer': 9,
#          'key-generator': 9,
#          'gwt': 9,
#          'download': 9,
#          'ftps': 9,
#          'http-status-code-401': 9,
#          'apple-push-notifications': 9,
#          'android-intent': 8,
#          'aescryptoserviceprovider': 8,
#          'android-ndk': 8,
#          'hadoop': 8,
#          'image-processing': 8,
#          'decoding': 8,
#          'apdu': 8,
#          'swift3': 8,
#          'hsm': 8,
#          'udp': 8,
#          'parse-platform': 8,
#          'tomcat7': 8,
#          'picasso': 8,
#          'md5sum': 8,
#          'apache-commons-httpclient': 8,
#          'android-emulator': 8,
#          'cxf': 8,
#          'httpconnection': 8,
#          'hostname': 8,
#          'smtp': 8,
#          'asynchttpclient': 8,
#          'try-catch': 7,
#          'pki': 7,
#          'bash': 7,
#          'output': 7,
#          'java-native-interface': 7,
#          'random': 7,
#          'whatsapp': 7,
#          'rc4-cipher': 7,
#          'jca': 7,
#          'rmi': 7,
#          'blackberry': 7,
#          'type-conversion': 7,
#          'memory': 7,
#          'memory-management': 7,
#          'class': 7,
#          'pkcs#8': 7,
#          'delphi': 7,
#          'firebase': 7,
#          'java-io': 7,
#          'save': 7,
#          'jaxb': 7,
#          'ksoap': 7,
#          'basic-authentication': 7,
#          'android-4.4-kitkat': 7,
#          'nginx': 7,
#          'parsing': 7,
#          'validation': 7,
#          'wildfly': 7,
#          'java-websocket': 7,
#          'apache-spark': 7,
#          'axis': 7,
#          'azure': 7,
#          'android-4.0-ice-cream-sandwich': 7,
#          'httpbuilder': 7,
#          'ca': 7,
#          'openfire': 7,
#          'ibm-mq': 7,
#          'compression': 6,
#          'crypt': 6,
#          'bufferedreader': 6,
#          'null': 6,
#          'arduino': 6,
#          'struts2': 6,
#          'object': 6,
#          'plsql': 6,
#          'pkcs#1': 6,
#          'streaming': 6,
#          'xml-signature': 6,
#          'optimization': 6,
#          'interop': 6,
#          'chat': 6,
#          'ibm-mobilefirst': 6,
#          'noclassdeffounderror': 6,
#          'php-openssl': 6,
#          'exoplayer': 6,
#          'python-2.7': 6,
#          'apache-axis': 6,
#          'kotlin': 6,
#          'ws-security': 6,
#          'sql-server': 6,
#          'http-headers': 6,
#          'ejb': 6,
#          'asmack': 6,
#          'request': 6,
#          'starttls': 6,
#          'amazon-ec2': 6,
#          'jndi': 6,
#          'jwt': 6,
#          'android-webview': 6,
#          'rest-client': 6,
#          'sharepoint': 6,
#          'pinning': 6,
#          'boringssl': 6,
#          'apache-mina': 6,
#          'rabbitmq': 6,
#          'sslcontext': 6,
#          'progress-bar': 5,
#          'fips': 5,
#          'bytebuffer': 5,
#          'java1.4': 5,
#          'jprogressbar': 5,
#          'jpeg': 5,
#          'dsa': 5,
#          'jquery': 5,
#          'classnotfoundexception': 5,
#          'swift2': 5,
#          'meteor': 5,
#          'react-native': 5,
#          'secure-random': 5,
#          'xcode': 5,
#          'oracle11g': 5,
#          'log4j': 5,
#          'hashmap': 5,
#          'mobile': 5,
#          'sms': 5,
#          'deserialization': 5,
#          'mscapi': 5,
#          'garbage-collection': 5,
#          'memory-leaks': 5,
#          'debugging': 5,
#          'symmetric-key': 5,
#          'google-cloud-messaging': 5,
#          'objectoutputstream': 5,
#          'saml': 5,
#          'python-3.x': 5,
#          'android-fingerprint-api': 5,
#          'code-conversion': 5,
#          'eofexception': 5,
#          'service': 5,
#          'configuration': 5,
#          'caching': 5,
#          'adt': 5,
#          'paypal': 5,
#          'http-get': 5,
#          'facebook-sdk-3.0': 5,
#          'signing': 5,
#          'playframework': 5,
#          'primefaces': 5,
#          'pdfbox': 5,
#          'soap-client': 5,
#          'git': 5,
#          'payumoney': 5,
#          'authorization': 5,
#          'ntlm': 5,
#          'multipartform-data': 5,
#          'androidasync-koush': 5,
#          'ejabberd': 5,
#          'mockito': 5,
#          'pkix': 5,
#          'ftp4j': 5,
#          'grizzly': 5,
#          'spray': 5,
#          'mutual-authentication': 5,
#          'sslengine': 5,
#          'urlencode': 4,
#          'android-videoview': 4,
#          'brute-force': 4,
#          'apache-flex': 4,
#          'android-mediaplayer': 4,
#          'key-pair': 4,
#          'imagedownload': 4,
#          'animation': 4,
#          'restful-url': 4,
#          'web-scraping': 4,
#          'hive': 4,
#          'plaintext': 4,
#          'inheritance': 4,
#          'gzip': 4,
#          'typescript': 4,
#          'unicode': 4,
#          'audio': 4,
#          'initialization': 4,
#          'cbc-mac': 4,
#          'vb6': 4,
#          'pem': 4,
#          'sjcl': 4,
#          'verify': 4,
#          'cross-platform': 4,
#          'ruby-on-rails-3': 4,
#          'reflection': 4,
#          'intellij-idea': 4,
#          'wso2': 4,
#          'ecies': 4,
#          'laravel': 4,
#          'uwp': 4,
#          'bluetooth': 4,
#          'thread-safety': 4,
#          'webservice-client': 4,
#          'uuid': 4,
#          'redirect': 4,
#          'google-chrome': 4,
#          'sign': 4,
#          'unix': 4,
#          'permissions': 4,
#          'trusted-timestamp': 4,
#          'image-uploading': 4,
#          'integration': 4,
#          'soapui': 4,
#          'forms': 4,
#          'google-cloud-storage': 4,
#          'multipart': 4,
#          'spring-ldap': 4,
#          'blob': 4,
#          'android-ksoap2': 4,
#          'sha2': 4,
#          'resteasy': 4,
#          'salesforce': 4,
#          'routes': 4,
#          'methods': 4,
#          'stetho': 4,
#          'mule': 4,
#          'proguard': 4,
#          'twitter-oauth': 4,
#          'webservices-client': 4,
#          'trust': 4,
#          '3g': 4,
#          'sslexception': 4,
#          'akka': 4,
#          'restlet': 4,
#          'lets-encrypt': 4,
#          'java-metro-framework': 4,
#          'rx-android': 4,
#          'saaj': 3,
#          'nosuchmethoderror': 3,
#          'classpath': 3,
#          'android-image': 3,
#          'static': 3,
#          'web-applications': 3,
#          'gson': 3,
#          'compiler-errors': 3,
#          'carriage-return': 3,
#          'global-variables': 3,
#          'windows-phone-8.1': 3,
#          'crc32': 3,
#          'ascii': 3,
#          'data-recovery': 3,
#          'recovery': 3,
#          'heap-memory': 3,
#          'zipinputstream': 3,
#          'node-crypto': 3,
#          'ofbiz': 3,
#          'encoder': 3,
#          'firebase-realtime-database': 3,
#          'javafx-8': 3,
#          'indexoutofboundsexception': 3,
#          'equals': 3,
#          'datainputstream': 3,
#          'dataoutputstream': 3,
#          'ios4': 3,
#          'ios5': 3,
#          'vb.net-2010': 3,
#          'm2crypto': 3,
#          'benchmarking': 3,
#          'opayo': 3,
#          'asp.net-mvc-4': 3,
#          'shell': 3,
#          'binary': 3,
#          'jwe': 3,
#          'exec': 3,
#          'voice': 3,
#          'url-encoding': 3,
#          'deflate': 3,
#          'constructor': 3,
#          'appcelerator': 3,
#          'introspection': 3,
#          'webcrypto-api': 3,
#          'filewriter': 3,
#          'android-gradle-plugin': 3,
#          'rsacryptoserviceprovider': 3,
#          'nsdata': 3,
#          'dropbox': 3,
#          'jose4j': 3,
#          'android-lvl': 3,
#          'iso-8859-1': 3,
#          'text': 3,
#          'seek': 3,
#          'python-simple-crypt': 3,
#          'android-sdcard': 3,
#          'atmel': 3,
#          'parallel-processing': 3,
#          'pgcrypto': 3,
#          'media': 3,
#          'cryptoswift': 3,
#          'lua': 3,
#          'intentservice': 3,
#          'assets': 3,
#          'android-assets': 3,
#          'lazylist': 3,
#          'lazy-loading': 3,
#          'visible': 3,
#          'on-the-fly': 3,
#          'bittorrent': 3,
#          'cryptographic-hash-function': 3,
#          'time': 3,
#          'unknown-host': 3,
#          'camera': 3,
#          'wifi': 3,
#          'xamarin.ios': 3,
#          'endianness': 3,
#          'signed': 3,
#          'sdk': 3,
#          'ubuntu': 3,
#          'fragment': 3,
#          'logging': 3,
#          'jaas': 3,
#          'facebook-sdk-4.0': 3,
#          'unsigned-integer': 3,
#          'emulation': 3,
#          'unboundid-ldap-sdk': 3,
#          'shibboleth': 3,
#          'jfilechooser': 3,
#          'android-layout': 3,
#          'pack': 3,
#          'hash-collision': 3,
#          'self': 3,
#          'jgit': 3,
#          'tomcat6': 3,
#          'jvm': 3,
#          'payment-gateway': 3,
#          'payu': 3,
#          'data-structures': 3,
#          'http-status-code-404': 3,
#          'name-value': 3,
#          'java-5': 3,
#          'android-animation': 3,
#          'timeout': 3,
#          'socat': 3,
#          'google-maps-api-3': 3,
#          'parameters': 3,
#          'widget': 3,
#          'sslv3': 3,
#          'httprequest': 3,
#          'android-c2dm': 3,
#          'google-places-api': 3,
#          'universal-image-loader': 3,
#          'sasl': 3,
#          'wget': 3,
#          'android-logcat': 3,
#          'minify': 3,
#          'asyncfileupload': 3,
#          'multiple-file-upload': 3,
#          'http-status-codes': 3,
#          'github': 3,
#          'smslib': 3,
#          'woocommerce': 3,
#          'powermock': 3,
#          'playframework-2.0': 3,
#          'upload': 3,
#          'imap': 3,
#          'cassandra': 3,
#          'java-web-start': 3,
#          'web': 3,
#          'paho': 3,
#          'websphere': 3,
#          'apache-commons-net': 3,
#          'dropwizard': 3,
#          'exchange-server': 3,
#          'tyrus': 3,
#          'akka-http': 3,
#          'http-status-code-403': 3,
#          'android-contentprovider': 2,
#          'parcelable': 2,
#          'pipe': 2,
#          'coldfusion-9': 2,
#          'bzip2': 2,
#          'android-gallery': 2,
#          'printwriter': 2,
#          'size': 2,
#          'try-catch-finally': 2,
#          'digital-certificate': 2,
#          'dialog': 2,
#          'javabeans': 2,
#          'struts': 2,
#          'pandora': 2,
#          'netbeans-7': 2,
#          'number-formatting': 2,
#          'joptionpane': 2,
#          'bcrypt': 2,
#          'desktop': 2,
#          'timer': 2,
#          'export': 2,
#          'gnu': 2,
#          'steganography': 2,
#          'text-files': 2,
#          'ftp-client': 2,
#          'contactless-smartcard': 2,
#          'crc16': 2,
#          'struts-tags': 2,
#          'tomcat8': 2,
#          'crc': 2,
#          'rncryptor': 2,
#          'thrift': 2,
#          'recaptcha': 2,
#          'netsuite': 2,
#          'cracking': 2,
#          'reverse-engineering': 2,
#          'dct': 2,
#          'extends': 2,
#          'pgp': 2,
#          'netbeans-8': 2,
#          'android-permissions': 2,
#          'neo4j': 2,
#          'decoder': 2,
#          'delphi-7': 2,
#          'provider': 2,
#          'datagram': 2,
#          'generics': 2,
#          'midp': 2,
#          'distribution': 2,
#          'cryptlib': 2,
#          'android-2.0-eclair': 2,
#          'wampserver': 2,
#          'android-4.2-jelly-bean': 2,
#          'rfc2898': 2,
#          'actionscript-3': 2,
#          'crash': 2,
#          'windows-8': 2,
#          'copy': 2,
#          'verification': 2,
#          'large-data': 2,
#          'verisign': 2,
#          'nosuchproviderexception': 2,
#          'pidcrypt': 2,
#          'access-token': 2,
#          'ios7': 2,
#          'barcode': 2,
#          'lotus-domino': 2,
#          'libgcrypt': 2,
#          'store': 2,
#          'exponent': 2,
#          'symmetric': 2,
#          'elgamal': 2,
#          'for-loop': 2,
#          'android-service': 2,
#          'twofish': 2,
#          'samsung-mobile': 2,
#          'delphi-xe8': 2,
#          'lockbox-3': 2,
#          'ecdsa': 2,
#          'coldfusion-11': 2,
#          'der': 2,
#          'nonce': 2,
#          'jpbc': 2,
#          'smime': 2,
#          'salesforce-communities': 2,
#          'fingerprint': 2,
#          '7zip': 2,
#          'video-streaming': 2,
#          'iostream': 2,
#          'buffer': 2,
#          'mismatch': 2,
#          'android-context': 2,
#          'android-install-apk': 2,
#          'user-defined-functions': 2,
#          'filenames': 2,
#          'cocoa': 2,
#          'guid': 2,
#          'java-ee-6': 2,
#          'coding-style': 2,
#          'password-hash': 2,
#          'servlet-filters': 2,
#          'facebook-javascript-sdk': 2,
#          'uniqueidentifier': 2,
#          'wsse': 2,
#          'cygwin': 2,
#          'apk': 2,
#          'ssh': 2,
#          'sql-insert': 2,
#          'baseadapter': 2,
#          'timertask': 2,
#          'admob': 2,
#          'ajax': 2,
#          'loopj': 2,
#          'socketexception': 2,
#          'gallery': 2,
#          'android-fragmentactivity': 2,
#          'function': 2,
#          'google-plus': 2,
#          'wildfly-8': 2,
#          'facebook-sdk-3.1': 2,
#          'asynchronous': 2,
#          'poodle-attack': 2,
#          'concatenation': 2,
#          'mail-server': 2,
#          'directory': 2,
#          'response': 2,
#          'instant-messaging': 2,
#          'powermockito': 2,
#          'ssha': 2,
#          'cpu-usage': 2,
#          'google-play-services': 2,
#          'leaderboard': 2,
#          'runtime-error': 2,
#          'collision': 2,
#          'weblogic12c': 2,
#          'jmeter': 2,
#          'apache-poi': 2,
#          'openshift': 2,
#          'oauth-1.0a': 2,
#          'sinch': 2,
#          'jenkins': 2,
#          'hashalgorithm': 2,
#          'compare': 2,
#          'utf-16': 2,
#          'message': 2,
#          'mocking': 2,
#          'protocols': 2,
#          'owasp': 2,
#          'servlet-3.0': 2,
#          'matlab': 2,
#          'sip': 2,
#          'jboss7.x': 2,
#          'guava': 2,
#          'java-stored-procedures': 2,
#          'pfx': 2,
#          'stack-overflow': 2,
#          'timestamp': 2,
#          'bitcoin': 2,
#          'android-alertdialog': 2,
#          'mongodb': 2,
#          'trading': 2,
#          'aws-api-gateway': 2,
#          'gitkraken': 2,
#          'kraken.js': 2,
#          'osgi': 2,
#          'apacheds': 2,
#          'opc': 2,
#          'opc-ua': 2,
#          'twilio': 2,
#          'android-looper': 2,
#          'spring-ws': 2,
#          'apache-nifi': 2,
#          'httpresponse': 2,
#          'android-version': 2,
#          'android-widget': 2,
#          'sax': 2,
#          'ejabberd-module': 2,
#          'connection-reset': 2,
#          'mod-ssl': 2,
#          'backwards-compatibility': 2,
#          'android-7.1-nougat': 2,
#          'executable': 2,
#          'ipv4': 2,
#          'ipv6': 2,
#          'wireshark': 2,
#          'equivalent': 2,
#          'mcrypt-js': 2,
#          'gsm': 2,
#          'grooveshark': 2,
#          'amazon-ses': 2,
#          'coinbase-api': 2,
#          'wordpress': 2,
#          'ibm-midrange': 2,
#          'dropbox-api': 2,
#          'softhsm': 2,
#          'instagram': 2,
#          'instagram-api': 2,
#          'http-status-code-400': 2,
#          'poloniex': 2,
#          'activemq': 2,
#          'cisco': 2,
#          'push-notification': 2,
#          'simple-framework': 2,
#          'securitymanager': 2,
#          'http-status-code-415': 2,
#          'exchange-server-2007': 2,
#          'outlook-2003': 2,
#          'httpserver': 2,
#          'ning': 2,
#          'wav': 2,
#          'socketfactory': 2,
#          'smartclient': 2,
#          'mosquitto': 2,
#          'egit': 2,
#          'groovy-2': 2,
#          'marklogic': 2,
#          'openid': 2,
#          'openid4java': 2,
#          'wso2-identity-server': 2,
#          'spring-amqp': 2,
#          'port': 2,
#          'selenium': 2,
#          'xpath': 2,
#          'jax-rpc': 2,
#          'cookiestore': 2,
#          'geckoboard': 2,
#          'android-virtual-device': 2,
#          'tcpsocket': 2,
#          'plugins': 2,
#          'referenceerror': 2,
#          'pushbullet': 2,
#          'nanohttpd': 2,
#          'undertow': 2,
#          'android-background': 2,
#          'mq': 2,
#          'sni': 2,
#          'blueprint-osgi': 2,
#          'wso2-api-manager': 2,
#          'http2': 2,
#          'android-async-http': 2,
#          'javafx-webengine': 2,
#          'ssl-client-authentication': 2,
#          'wunderground': 2,
#          'android-database': 2,
#          'static-methods': 2,
#          'bearer-token': 2,
#          'mitreid-connect': 2,
#          'spring-oauth2': 2,
#          'testing': 2,
#          'google-maps-android-api-2': 2,
#          'maps': 2,
#          'google-oauth': 2,
#          'firebase-performance': 2,
#          'rx-java': 2,
#          'cxf-client': 2,
#          'xop': 2,
#          'alert': 2,
#          'android-recyclerview': 2,
#          'spring-rest': 2,
#          'filezilla': 2,
#          'wshttpbinding': 2,
#          'sharepoint-2010': 2,
#          'restlet-2.3.1': 2,
#          'mobilefirst-adapters': 2,
#          'mdm': 1,
#          'minecraft': 1,
#          'postgresql-8.4': 1,
#          'module': 1,
#          'openbsd': 1,
#          'apache-commons-codec': 1,
#          'block': 1,
#          'blackberry-jde': 1,
#          'compatibility': 1,
#          'string-matching': 1,
#          'url-rewriting': 1,
#          'newline': 1,
#          'greenplum': 1,
#          'jasypt': 1,
#          'filestream': 1,
#          'ejbca': 1,
#          'environment': 1,
#          'derby': 1,
#          'orm': 1,
#          'libgdx': 1,
#          'ffmpeg': 1,
#          'frames': 1,
#          'video-processing': 1,
#          'xuggler': 1,
#          'funambol': 1,
#          'db2': 1,
#          'playback': 1,
#          'session-keys': 1,
#          'emv': 1,
#          'visa': 1,
#          'android-file': 1,
#          'zlib': 1,
#          'c#-4.0': 1,
#          'chilkat': 1,
#          'nexus-5': 1,
#          'sony-xperia': 1,
#          'django': 1,
#          'robolectric': 1,
#          'sqlcipher-android': 1,
#          'iso8583': 1,
#          'pool': 1,
#          'veracode': 1,
#          'javafx-2': 1,
#          'filereader': 1,
#          'apache-drill': 1,
#          'sails.js': 1,
#          'javax': 1,
#          'binaryfiles': 1,
#          'simultaneous': 1,
#          'midlet': 1,
#          'bit-manipulation': 1,
#          'dictionary': 1,
#          'netbeans-6.9': 1,
#          'cryptostream': 1,
#          'integrity': 1,
#          'sqlcipher': 1,
#          'key-management': 1,
#          'format': 1,
#          'readable': 1,
#          'gnupg': 1,
#          'jsbn': 1,
#          'time-complexity': 1,
#          'genymotion': 1,
#          'robovm': 1,
#          'ibm-was': 1,
#          'rubymotion': 1,
#          'jcryption': 1,
#          'preferences': 1,
#          'int': 1,
#          'xamarin': 1,
#          'modulus': 1,
#          'push-api': 1,
#          'keychain': 1,
#          'modulo': 1,
#          'asp.net-core': 1,
#          'realm': 1,
#          'ionic-framework': 1,
#          'steam': 1,
#          'ssh-keys': 1,
#          'fortify': 1,
#          'enterprise-library': 1,
#          'aix': 1,
#          'asn.1': 1,
#          'jsencrypt': 1,
#          ...})

# %%
# Filter Counter based on key value
# Dict from list of tuples
filter_tags = ['c#',
               '.net',
               'facebook',
               'sockets',
               'base64',
               'javascript',
               'php',
               'web-services',
               'string',
               'exception',
               'node.js',
               'ios',
               'python',
               'encoding',
               'spring',
               'objective-c',
               'file',
               'padding',
               'mysql',
               'apache-httpclient-4.x',
               'ruby',
               'soap',
               'rest',
               'bytearray',
               'algorithm',
               'eclipse',
               'android-asynctask',
               'android-volley',
               'arrays',
               'json',
               'performance',
               'okhttp',
               'hex',
               'byte',
               'android-studio',
               'facebook-graph-api',
               'http',
               'jsp',
               'xml',
               'servlets',
               'tomcat',
               'hibernate',
               'post',
               'multithreading',
               'apache',
               'okhttp3',
               'c',
               'scala',
               'jakarta-ee',
               'amazon-web-services',
               'groovy',
               'websocket',
               'iphone',
               'amazon-s3']
c_tuples = Counter({k: v for k, v in c_tuples.items() if ('android' in k or 'java' in k) and not ('android' in k and 'java' in k) and not any(tag in k for tag in filter_tags)})
display(c_tuples)
# Out:
# Counter({('java', 'encryption'): 3325,
#          ('java', 'aes'): 1684,
#          ('android', 'encryption'): 1229,
#          ('java', 'cryptography'): 1135,
#          ('java', 'ssl'): 812,
#          ('android', 'aes'): 528,
#          ('android', 'ssl'): 471,
#          ('java', 'security'): 326,
#          ('java', 'rsa'): 323,
#          ('java', 'https'): 291,
#          ('android', 'cryptography'): 271,
#          ('android', 'https'): 230,
#          ('java', 'bouncycastle'): 219,
#          ('java', 'hash'): 219,
#          ('java', 'md5'): 211,
#          ('java', 'des'): 133,
#          ('java', 'ssl-certificate'): 128,
#          ('java', 'jce'): 126,
#          ('java', 'openssl'): 124,
#          ('android', 'rsa'): 114,
#          ('android', 'ssl-certificate'): 98,
#          ('android', 'security'): 92,
#          ('java', 'sha256'): 91,
#          ('java', 'sha1'): 84,
#          ('java', 'cryptojs'): 82,
#          ('java', '3des'): 81,
#          ('java', 'certificate'): 81,
#          ('java', 'keystore'): 75,
#          ('java', 'encryption-symmetric'): 68,
#          ('java', 'blowfish'): 68,
#          ('java', 'hmac'): 63,
#          ('java', 'httpclient'): 62,
#          ('android', 'hash'): 60,
#          ('java', 'sha'): 59,
#          ('java', 'public-key-encryption'): 58,
#          ('android', 'httpsurlconnection'): 54,
#          ('java', 'badpaddingexception'): 53,
#          ('java', 'tripledes'): 51,
#          ('java', 'aes-gcm'): 48,
#          ('android', 'bouncycastle'): 47,
#          ('android', 'md5'): 47,
#          ('android', 'certificate'): 47,
#          ('java', 'passwords'): 46,
#          ('java', 'rijndael'): 46,
#          ('java', 'cbc-mode'): 46,
#          ('java', 'message-digest'): 46,
#          ('java', 'authentication'): 44,
#          ('java', 'digital-signature'): 42,
#          ('java', 'sslhandshakeexception'): 42,
#          ('java', 'x509certificate'): 37,
#          ('java', 'javax.crypto'): 35,
#          ('java', 'secret-key'): 34,
#          ('android', 'keystore'): 34,
#          ('android', 'openssl'): 32,
#          ('java', 'initialization-vector'): 32,
#          ('android', 'httpclient'): 32,
#          ('java', 'c++'): 30,
#          ('android', 'android-keystore'): 30,
#          ('java', 'java-security'): 30,
#          ('android', 'retrofit'): 30,
#          ('android', 'authentication'): 29,
#          ('android', 'httpurlconnection'): 29,
#          ('java', 'httpsurlconnection'): 29,
#          ('java', 'tls1.2'): 29,
#          ('java', 'key'): 28,
#          ('java', 'file-io'): 28,
#          ('java', 'vb.net'): 28,
#          ('java', 'password-encryption'): 28,
#          ('android', 'x509certificate'): 28,
#          ('android', 'sslhandshakeexception'): 28,
#          ('java', 'encryption-asymmetric'): 27,
#          ('java', 'salt'): 26,
#          ('android', 'self-signed'): 26,
#          ('android', 'retrofit2'): 26,
#          ('android', 'image'): 25,
#          ('java', 'sha512'): 25,
#          ('java', 'api'): 25,
#          ('java', 'httpurlconnection'): 25,
#          ('android', 'encryption-symmetric'): 24,
#          ('java', 'block-cipher'): 23,
#          ('android', 'badpaddingexception'): 23,
#          ('java', 'mcrypt'): 23,
#          ('java', 'inputstream'): 22,
#          ('android', 'bitmap'): 22,
#          ('java', 'stream'): 22,
#          ('java', 'character-encoding'): 22,
#          ('java', 'jax-ws'): 22,
#          ('java', 'jsse'): 22,
#          ('java', 'sslsocketfactory'): 22,
#          ('java', 'linux'): 21,
#          ('java', 'nullpointerexception'): 20,
#          ('java', 'public-key'): 20,
#          ('android', 'android-7.0-nougat'): 20,
#          ('java', 'utf-8'): 20,
#          ('android', 'android-security'): 20,
#          ('android', 'des'): 19,
#          ('android', 'sharedpreferences'): 19,
#          ('java', 'serialization'): 19,
#          ('java', 'keytool'): 19,
#          ('java', 'decode'): 19,
#          ('java', 'netty'): 19,
#          ('android', 'public-key-encryption'): 18,
#          ('java', 'java-8'): 18,
#          ('java', 'tcp'): 18,
#          ('android', 'sha'): 18,
#          ('android', 'facebook-android-sdk'): 18,
#          ('java', 'jersey'): 18,
#          ('java', 'ecb'): 17,
#          ('java', 'private-key'): 17,
#          ('android', 'listview'): 17,
#          ('java', 'spring-mvc'): 17,
#          ('android', 'video'): 17,
#          ('java', 'client'): 17,
#          ('java', 'junit'): 17,
#          ('android', 'sslsocketfactory'): 17,
#          ('android', 'javax.crypto'): 16,
#          ('android', 'nullpointerexception'): 16,
#          ('java', 'jar'): 16,
#          ('java', 'oracle'): 16,
#          ('java', 'diffie-hellman'): 16,
#          ('java', 'url'): 16,
#          ('android', 'android-6.0-marshmallow'): 16,
#          ('android', 'sha1'): 16,
#          ('android', 'facebook-login'): 16,
#          ('java', 'proxy'): 16,
#          ('android', 'trustmanager'): 16,
#          ('android', '3des'): 15,
#          ('java', 'pdf'): 15,
#          ('android', 'spongycastle'): 15,
#          ('java', 'phpseclib'): 15,
#          ('android', 'android-5.0-lollipop'): 15,
#          ('java', 'html'): 15,
#          ('java', 'networking'): 15,
#          ('android', 'sha256'): 15,
#          ('java', 'digest'): 15,
#          ('android', 'webview'): 15,
#          ('android', 'http-post'): 15,
#          ('java', 'handshake'): 15,
#          ('java', 'truststore'): 15,
#          ('android', 'tls1.2'): 15,
#          ('java', 'pkcs#7'): 14,
#          ('java', 'apache-commons'): 14,
#          ('java', 'perl'): 14,
#          ('java', 'netbeans'): 14,
#          ('android', 'out-of-memory'): 14,
#          ('android', 'connection'): 14,
#          ('java', 'checksum'): 14,
#          ('android', 'xmpp'): 14,
#          ('java', 'elliptic-curve'): 13,
#          ('java', 'pkcs#5'): 13,
#          ('java', 'image'): 13,
#          ('java', 'client-server'): 13,
#          ('java', 'swing'): 13,
#          ('java', 'ftp'): 13,
#          ('java', 'curl'): 13,
#          ('java', 'google-app-engine'): 12,
#          ('android', 'aes-gcm'): 12,
#          ('java', 'classloader'): 12,
#          ('java', 'outputstream'): 12,
#          ('java', 'pycrypto'): 12,
#          ('java', 'cryptoapi'): 12,
#          ('java', 'io'): 12,
#          ('android', 'phpseclib'): 12,
#          ('android', 'sqlite'): 12,
#          ('java', 'maven'): 12,
#          ('android', 'cryptojs'): 12,
#          ('java', 'network-programming'): 12,
#          ('android', 'hmac'): 12,
#          ('java', 'x509'): 12,
#          ('java', 'hmacsha1'): 12,
#          ('java', 'jks'): 12,
#          ('android', 'session'): 12,
#          ('android', 'android-networking'): 12,
#          ('java', 'jsoup'): 12,
#          ('java', 'database'): 11,
#          ('java', 'fileoutputstream'): 11,
#          ('java', 'fileinputstream'): 11,
#          ('java', 'nio'): 11,
#          ('java', 'rijndaelmanaged'): 11,
#          ('android', 'inputstream'): 11,
#          ('java', 'cfb-mode'): 11,
#          ('java', 'jax-rs'): 11,
#          ('java', 'java-me'): 11,
#          ('android', 'cbc-mode'): 11,
#          ('android', 'c++'): 11,
#          ('java', 'jdbc'): 11,
#          ('android', 'android-facebook'): 11,
#          ('java', 'smack'): 11,
#          ('java', 'self-signed'): 11,
#          ('java', 'client-certificates'): 11,
#          ('java', 'zip'): 10,
#          ('java', 'go'): 10,
#          ('java', 'postgresql'): 10,
#          ('java', 'macos'): 10,
#          ('java', 'encode'): 10,
#          ('android', 'rijndael'): 10,
#          ('java', 'ruby-on-rails'): 10,
#          ('android', 'vb.net'): 10,
#          ('android', 'nfc'): 10,
#          ('java', 'windows'): 10,
#          ('java', 'unit-testing'): 10,
#          ('java', 'swift'): 10,
#          ('java', 'glassfish'): 10,
#          ('java', 'filenotfoundexception'): 10,
#          ('java', 'angularjs'): 10,
#          ('android', 'key'): 10,
#          ('android', 'encryption-asymmetric'): 10,
#          ('java', 'biginteger'): 10,
#          ('java', 'ctr-mode'): 10,
#          ('android', 'decode'): 10,
#          ('android', 'networking'): 10,
#          ('java', 'signature'): 10,
#          ('android', 'android-fragments'): 10,
#          ('java', 'itext'): 10,
#          ('java', 'jetty'): 10,
#          ('android', 'oauth-2.0'): 10,
#          ('android', 'androidhttpclient'): 10,
#          ('android', 'google-play'): 10,
#          ('android', 'jsoup'): 10,
#          ('java', 'mifare'): 9,
#          ('java', 'jboss'): 9,
#          ('java', 'asp.net'): 9,
#          ('java', 'serversocket'): 9,
#          ('java', 'windows-phone-8'): 9,
#          ('android', 'android-activity'): 9,
#          ('java', 'pbkdf2'): 9,
#          ('java', 'objectinputstream'): 9,
#          ('java', 'integer'): 9,
#          ('java', 'android-6.0-marshmallow'): 9,
#          ('java', 'spring-security'): 9,
#          ('java', 'smartcard'): 9,
#          ('java', 'key-generator'): 9,
#          ('java', 'android-keystore'): 9,
#          ('java', 'hashcode'): 9,
#          ('java', 'ftps'): 9,
#          ('java', 'session'): 9,
#          ('android', 'socket.io'): 9,
#          ('android', 'tcp'): 9,
#          ('java', 'resttemplate'): 9,
#          ('java', 'apache-httpcomponents'): 9,
#          ('android', 'handshake'): 9,
#          ('android', 'google-maps'): 9,
#          ('java', 'http-status-code-401'): 9,
#          ('java', 'urlconnection'): 9,
#          ('java', 'apple-push-notifications'): 9,
#          ('java', 'oauth'): 9,
#          ('android', 'android-intent'): 8,
#          ('java', 'coldfusion'): 8,
#          ('java', 'sql'): 8,
#          ('java', 'android-ndk'): 8,
#          ('java', 'windows-phone-7'): 8,
#          ('java', 'bitmap'): 8,
#          ('java', 'cookies'): 8,
#          ('android', 'pbkdf2'): 8,
#          ('java', 'decoding'): 8,
#          ('android', 'ioexception'): 8,
#          ('java', 'java-7'): 8,
#          ('android', 'fileoutputstream'): 8,
#          ('java', 'javafx'): 8,
#          ('java', 'udp'): 8,
#          ('java', 'java-6'): 8,
#          ('android', 'private-key'): 8,
#          ('java', 'pkcs#12'): 8,
#          ('android', 'wcf'): 8,
#          ('android', 'parse-platform'): 8,
#          ('android', 'picasso'): 8,
#          ('java', 'password-protection'): 8,
#          ('java', 'qt'): 8,
#          ('android', 'android-emulator'): 8,
#          ('android', 'file-upload'): 8,
#          ('java', 'ldap'): 8,
#          ('android', 'smack'): 8,
#          ('android', 'ksoap2'): 8,
#          ('java', 'cxf'): 8,
#          ('java', 'trustmanager'): 8,
#          ('android', 'client-certificates'): 8,
#          ('java', 'smtp'): 8,
#          ('java', 'wsdl'): 8,
#          ('java', 'try-catch'): 7,
#          ('java', 'crypto++'): 7,
#          ('android', 'unit-testing'): 7,
#          ('java', 'bash'): 7,
#          ('java', 'javacard'): 7,
#          ('java', 'output'): 7,
#          ('android', 'java-native-interface'): 7,
#          ('java', 'pkcs#11'): 7,
#          ('java', 'email'): 7,
#          ('java', 'out-of-memory'): 7,
#          ('java', 'spongycastle'): 7,
#          ('java', 'jca'): 7,
#          ('java', 'rmi'): 7,
#          ('android', 'filenotfoundexception'): 7,
#          ('android', 'outputstream'): 7,
#          ('java', 'porting'): 7,
#          ('java', 'type-conversion'): 7,
#          ('java', 'pkcs#8'): 7,
#          ('java', 'server'): 7,
#          ('java', 'jpa'): 7,
#          ('android', 'secret-key'): 7,
#          ('java', 'sqlite'): 7,
#          ('android', 'mcrypt'): 7,
#          ('android', 'save'): 7,
#          ('android', 'ksoap'): 7,
#          ('java', 'android-security'): 7,
#          ('java', 'nginx'): 7,
#          ('android', 'qt'): 7,
#          ('java', 'download'): 7,
#          ('java', 'md5sum'): 7,
#          ('android', 'html'): 7,
#          ('java', 'http-post'): 7,
#          ('java', 'weblogic'): 7,
#          ('android', 'cookies'): 7,
#          ('java', 'twitter'): 7,
#          ('java', 'ibm-mq'): 7,
#          ('android', 'password-encryption'): 6,
#          ('java', 'pki'): 6,
#          ('java', 'crypt'): 6,
#          ('java', 'applet'): 6,
#          ('java', 'hadoop'): 6,
#          ('java', 'image-processing'): 6,
#          ('android', 'asp.net'): 6,
#          ('java', 'bufferedreader'): 6,
#          ('android', 'blowfish'): 6,
#          ('java', 'arraylist'): 6,
#          ('java', 'memory'): 6,
#          ('java', 'class'): 6,
#          ('java', 'plsql'): 6,
#          ('java', 'video'): 6,
#          ('android', 'android-ndk'): 6,
#          ('android', 'firebase'): 6,
#          ('java', 'gwt'): 6,
#          ('android', 'public-key'): 6,
#          ('java', 'optimization'): 6,
#          ('android', 'java-me'): 6,
#          ('java', 'jaxb'): 6,
#          ('android', 'pkcs#7'): 6,
#          ('java', 'whatsapp'): 6,
#          ('java', 'noclassdeffounderror'): 6,
#          ('android', 'utf-8'): 6,
#          ('android', 'character-encoding'): 6,
#          ('android', 'exoplayer'): 6,
#          ('java', 'android-7.0-nougat'): 6,
#          ('java', 'python-2.7'): 6,
#          ('java', 'apache-commons-httpclient'): 6,
#          ('android', 'cordova'): 6,
#          ('java', 'xmpp'): 6,
#          ('java', 'starttls'): 6,
#          ('java', 'jwt'): 6,
#          ('java', 'wildfly'): 6,
#          ('android', 'oauth'): 6,
#          ('java', 'axis'): 6,
#          ('java', 'azure'): 6,
#          ('java', 'rest-client'): 6,
#          ('java', 'sharepoint'): 6,
#          ('android', 'x509trustmanager'): 6,
#          ('android', 'pinning'): 6,
#          ('java', 'x509trustmanager'): 6,
#          ('android', 'boringssl'): 6,
#          ('java', 'jersey-client'): 6,
#          ('android', 'zip'): 5,
#          ('android', 'progress-bar'): 5,
#          ('android', 'pycrypto'): 5,
#          ('android', 'diffie-hellman'): 5,
#          ('android', 'random'): 5,
#          ('java', 'bytebuffer'): 5,
#          ('java', 'jprogressbar'): 5,
#          ('java', 'nfc'): 5,
#          ('java', 'jpeg'): 5,
#          ('java', 'listview'): 5,
#          ('java', 'rc4-cipher'): 5,
#          ('java', 'dsa'): 5,
#          ('android', 'objectinputstream'): 5,
#          ('android', 'tripledes'): 5,
#          ('android', 'fileinputstream'): 5,
#          ('java', 'struts2'): 5,
#          ('android', 'gradle'): 5,
#          ('java', 'object'): 5,
#          ('java', 'memory-management'): 5,
#          ('android', 'swift'): 5,
#          ('java', 'meteor'): 5,
#          ('android', 'arraylist'): 5,
#          ('android', 'pkcs#5'): 5,
#          ('java', 'log4j'): 5,
#          ('java', 'streaming'): 5,
#          ('java', 'deserialization'): 5,
#          ('java', 'java-io'): 5,
#          ('java', 'mscapi'): 5,
#          ('java', 'garbage-collection'): 5,
#          ('android', 'passwords'): 5,
#          ('android', 'windows-phone-8'): 5,
#          ('java', 'interop'): 5,
#          ('java', 'symmetric-key'): 5,
#          ('java', 'google-cloud-messaging'): 5,
#          ('java', 'basic-authentication'): 5,
#          ('java', 'objectoutputstream'): 5,
#          ('java', 'saml'): 5,
#          ('java', 'parse-platform'): 5,
#          ('android', 'android-fingerprint-api'): 5,
#          ('java', 'code-conversion'): 5,
#          ('java', 'configuration'): 5,
#          ('android', 'caching'): 5,
#          ('android', 'url'): 5,
#          ('java', 'ws-security'): 5,
#          ('android', 'adt'): 5,
#          ('java', 'paypal'): 5,
#          ('java', 'sql-server'): 5,
#          ('android', 'get'): 5,
#          ('android', 'facebook-sdk-3.0'): 5,
#          ('android', 'asmack'): 5,
#          ('java', 'soap-client'): 5,
#          ('java', 'spring-boot'): 5,
#          ('java', 'java-websocket'): 5,
#          ('android', 'sha512'): 5,
#          ('android', 'android-webview'): 5,
#          ('android', 'api'): 5,
#          ('android', 'payumoney'): 5,
#          ('java', 'authorization'): 5,
#          ('java', 'ntlm'): 5,
#          ('android', 'multipartform-data'): 5,
#          ('android', 'parsing'): 5,
#          ('android', 'httpconnection'): 5,
#          ('android', 'hostname'): 5,
#          ('android', 'obfuscation'): 5,
#          ('java', 'boringssl'): 5,
#          ('java', 'pkix'): 5,
#          ('java', 'mqtt'): 5,
#          ('java', 'ftp4j'): 5,
#          ('android', 'mqtt'): 5,
#          ('java', 'apache-camel'): 5,
#          ('java', 'connection'): 5,
#          ('java', 'rabbitmq'): 5,
#          ('android', 'android-4.4-kitkat'): 5,
#          ('java', 'sslcontext'): 5,
#          ('android', 'asynchttpclient'): 5,
#          ('android', 'android-videoview'): 4,
#          ('java', 'compression'): 4,
#          ('java', 'apache-flex'): 4,
#          ('java', 'java-native-interface'): 4,
#          ('android', 'android-mediaplayer'): 4,
#          ('java', 'get'): 4,
#          ('android', 'image-processing'): 4,
#          ('java', 'java1.4'): 4,
#          ('android', 'animation'): 4,
#          ('android', 'whatsapp'): 4,
#          ('java', 'web-scraping'): 4,
#          ('java', 'hive'): 4,
#          ('java', 'jsf-2'): 4,
#          ('android', 'arduino'): 4,
#          ('android', 'pdf'): 4,
#          ('java', 'ioexception'): 4,
#          ('java', 'gradle'): 4,
#          ('java', 'classnotfoundexception'): 4,
#          ('java', 'inheritance'): 4,
#          ('java', 'obfuscation'): 4,
#          ('java', 'pkcs#1'): 4,
#          ('java', 'oracle11g'): 4,
#          ('java', 'firebase'): 4,
#          ('android', 'sms'): 4,
#          ('java', 'xml-signature'): 4,
#          ('android', 'jaxb'): 4,
#          ('java', 'vb6'): 4,
#          ('android', 'sjcl'): 4,
#          ('java', 'chat'): 4,
#          ('java', 'verify'): 4,
#          ('android', 'cross-platform'): 4,
#          ('java', 'ruby-on-rails-3'): 4,
#          ('java', 'reflection'): 4,
#          ('java', 'intellij-idea'): 4,
#          ('java', 'grails'): 4,
#          ('java', 'python-3.x'): 4,
#          ('java', 'ecies'): 4,
#          ('android', 'laravel'): 4,
#          ('android', 'fips'): 4,
#          ('java', 'php-openssl'): 4,
#          ('android', 'junit'): 4,
#          ('java', 'apache-axis'): 4,
#          ('java', 'eofexception'): 4,
#          ('android', 'initialization-vector'): 4,
#          ('android', 'bluetooth'): 4,
#          ('android', 'null'): 4,
#          ('android', 'message-digest'): 4,
#          ('java', 'parsing'): 4,
#          ('java', 'google-chrome'): 4,
#          ('java', 'http-headers'): 4,
#          ('android', 'checksum'): 4,
#          ('android', 'java-websocket'): 4,
#          ('java', 'pdfbox'): 4,
#          ('android', 'image-uploading'): 4,
#          ('java', 'forms'): 4,
#          ('android', 'android-ksoap2'): 4,
#          ('java', 'webview'): 4,
#          ('java', 'resteasy'): 4,
#          ('java', 'methods'): 4,
#          ('android', 'android-4.0-ice-cream-sandwich'): 4,
#          ('android', 'ca'): 4,
#          ('android', 'stetho'): 4,
#          ('android', 'client'): 4,
#          ('java', 'openfire'): 4,
#          ('android', 'proguard'): 4,
#          ('java', 'request'): 4,
#          ('java', 'webservices-client'): 4,
#          ('android', 'jakarta-mail'): 4,
#          ('java', 'grizzly'): 4,
#          ('java', 'apache-mina'): 4,
#          ('java', 'ca'): 4,
#          ('java', 'sslengine'): 4,
#          ('android', 'rx-android'): 4,
#          ('java', 'urlencode'): 3,
#          ('android', 'nosuchmethoderror'): 3,
#          ('java', 'classpath'): 3,
#          ('android', 'android-image'): 3,
#          ('java', 'brute-force'): 3,
#          ('java', 'static'): 3,
#          ('java', 'cordova'): 3,
#          ('android', 'aescryptoserviceprovider'): 3,
#          ('android', 'gson'): 3,
#          ('java', 'random'): 3,
#          ('android', 'jce'): 3,
#          ('android', 'compiler-errors'): 3,
#          ('java', 'carriage-return'): 3,
#          ('java', 'global-variables'): 3,
#          ('android', 'global-variables'): 3,
#          ('java', 'plaintext'): 3,
#          ('java', 'crc32'): 3,
#          ('java', 'ascii'): 3,
#          ('android', 'apdu'): 3,
#          ('android', 'mifare'): 3,
#          ('java', 'aescryptoserviceprovider'): 3,
#          ('java', 'data-recovery'): 3,
#          ('java', 'recovery'): 3,
#          ('java', 'heap-memory'): 3,
#          ('java', 'zipinputstream'): 3,
#          ('java', 'ofbiz'): 3,
#          ('java', 'secure-random'): 3,
#          ('java', 'unicode'): 3,
#          ('java', 'firebase-realtime-database'): 3,
#          ('android', 'firebase-realtime-database'): 3,
#          ('java', 'indexoutofboundsexception'): 3,
#          ('android', 'initialization'): 3,
#          ('java', 'blackberry'): 3,
#          ('java', 'gzip'): 3,
#          ('java', 'datainputstream'): 3,
#          ('java', 'dataoutputstream'): 3,
#          ('java', 'ios4'): 3,
#          ('java', 'ios5'): 3,
#          ('android', 'database'): 3,
#          ('android', 'x509'): 3,
#          ('android', 'io'): 3,
#          ('java', 'vb.net-2010'): 3,
#          ('java', 'memory-leaks'): 3,
#          ('java', 'm2crypto'): 3,
#          ('android', 'ruby-on-rails'): 3,
#          ('java', 'asp.net-mvc-4'): 3,
#          ('android', 'asp.net-mvc-4'): 3,
#          ('java', 'shell'): 3,
#          ('java', 'binary'): 3,
#          ('java', 'jwe'): 3,
#          ('java', 'exec'): 3,
#          ('java', 'voice'): 3,
#          ('java', 'url-encoding'): 3,
#          ('java', 'deflate'): 3,
#          ('java', 'debugging'): 3,
#          ('java', 'pem'): 3,
#          ('java', 'constructor'): 3,
#          ('android', 'commoncrypto'): 3,
#          ('java', 'appcelerator'): 3,
#          ('java', 'introspection'): 3,
#          ('java', 'webcrypto-api'): 3,
#          ('java', 'filewriter'): 3,
#          ('android', 'python-3.x'): 3,
#          ('android', 'android-gradle-plugin'): 3,
#          ('android', 'urlconnection'): 3,
#          ('java', 'dropbox'): 3,
#          ('java', 'hsm'): 3,
#          ('java', 'jose4j'): 3,
#          ('android', 'android-lvl'): 3,
#          ('java', 'iso-8859-1'): 3,
#          ('android', 'iso-8859-1'): 3,
#          ('java', 'text'): 3,
#          ('java', 'seek'): 3,
#          ('java', 'python-simple-crypt'): 3,
#          ('android', 'android-sdcard'): 3,
#          ('java', 'atmel'): 3,
#          ('android', 'atmel'): 3,
#          ('java', 'parallel-processing'): 3,
#          ('java', 'pgcrypto'): 3,
#          ('android', 'media'): 3,
#          ('java', 'lua'): 3,
#          ('android', 'salt'): 3,
#          ('java', 'kotlin'): 3,
#          ('java', 'delphi'): 3,
#          ('java', 'bluetooth'): 3,
#          ('java', 'thread-safety'): 3,
#          ('java', 'save'): 3,
#          ('android', 'assets'): 3,
#          ('android', 'android-assets'): 3,
#          ('android', 'lazylist'): 3,
#          ('android', 'lazy-loading'): 3,
#          ('android', 'visible'): 3,
#          ('android', 'on-the-fly'): 3,
#          ('java', 'bittorrent'): 3,
#          ('java', 'cryptographic-hash-function'): 3,
#          ('java', 'time'): 3,
#          ('android', 'camera'): 3,
#          ('android', 'download'): 3,
#          ('java', 'uuid'): 3,
#          ('android', 'service'): 3,
#          ('java', 'android-activity'): 3,
#          ('java', 'jdbcrealm'): 3,
#          ('java', 'endianness'): 3,
#          ('android', 'http-get'): 3,
#          ('java', 'unix'): 3,
#          ('java', 'signing'): 3,
#          ('java', 'adt'): 3,
#          ('android', 'noclassdeffounderror'): 3,
#          ('java', 'ubuntu'): 3,
#          ('android', 'keytool'): 3,
#          ('java', 'trusted-timestamp'): 3,
#          ('java', 'ejb'): 3,
#          ('android', 'fragment'): 3,
#          ('android', 'mobile'): 3,
#          ('java', 'tomcat7'): 3,
#          ('java', 'jaas'): 3,
#          ('android', 'facebook-sdk-4.0'): 3,
#          ('android', 'signature'): 3,
#          ('java', 'unsigned-integer'): 3,
#          ('java', 'unboundid-ldap-sdk'): 3,
#          ('java', 'jfilechooser'): 3,
#          ('java', 'hashmap'): 3,
#          ('android', 'android-layout'): 3,
#          ('java', 'pack'): 3,
#          ('java', 'hash-collision'): 3,
#          ('android', 'client-server'): 3,
#          ('android', 'password-protection'): 3,
#          ('android', 'react-native'): 3,
#          ('android', 'stream'): 3,
#          ('java', 'tomcat6'): 3,
#          ('java', 'jvm'): 3,
#          ('android', 'payment-gateway'): 3,
#          ('android', 'payu'): 3,
#          ('java', 'data-structures'): 3,
#          ('java', 'salesforce'): 3,
#          ('java', 'jndi'): 3,
#          ('java', 'android-animation'): 3,
#          ('android', 'android-animation'): 3,
#          ('android', 'server'): 3,
#          ('android', 'sharepoint'): 3,
#          ('android', 'ntlm'): 3,
#          ('java', 'socat'): 3,
#          ('android', 'socat'): 3,
#          ('android', 'google-maps-api-3'): 3,
#          ('android', 'androidasync-koush'): 3,
#          ('android', 'widget'): 3,
#          ('java', 'google-play'): 3,
#          ('android', 'ejabberd'): 3,
#          ('java', 'file-upload'): 3,
#          ('android', 'httprequest'): 3,
#          ('android', 'google-places-api'): 3,
#          ('android', 'universal-image-loader'): 3,
#          ('java', 'sasl'): 3,
#          ('java', 'wget'): 3,
#          ('android', 'android-logcat'): 3,
#          ('android', 'minify'): 3,
#          ('java', 'amazon-ec2'): 3,
#          ('android', 'asyncfileupload'): 3,
#          ('android', 'multipart'): 3,
#          ('android', 'multiple-file-upload'): 3,
#          ('android', 'http-status-codes'): 3,
#          ('android', 'forms'): 3,
#          ('java', 'twitter-oauth'): 3,
#          ('java', 'smslib'): 3,
#          ('java', 'powermock'): 3,
#          ('java', 'playframework-2.0'): 3,
#          ('android', 'apache-mina'): 3,
#          ('android', 'ftp'): 3,
#          ('java', 'ksoap2'): 3,
#          ('android', 'sslexception'): 3,
#          ('android', 'serversocket'): 3,
#          ('java', 'java-web-start'): 3,
#          ('android', 'truststore'): 3,
#          ('java', 'wcf'): 3,
#          ('java', 'mutual-authentication'): 3,
#          ('android', 'mutual-authentication'): 3,
#          ('java', 'web'): 3,
#          ('java', 'ibm-mobilefirst'): 3,
#          ('java', 'paho'): 3,
#          ('android', 'paho'): 3,
#          ('java', 'websphere'): 3,
#          ('java', 'asynchttpclient'): 3,
#          ('java', 'apache-commons-net'): 3,
#          ('java', 'tyrus'): 3,
#          ('android', 'lets-encrypt'): 3,
#          ('android', 'android-contentprovider'): 2,
#          ('android', 'parcelable'): 2,
#          ('android', 'pipe'): 2,
#          ('java', 'coldfusion-9'): 2,
#          ('android', 'coldfusion-9'): 2,
#          ('java', 'saaj'): 2,
#          ('java', 'bzip2'): 2,
#          ('android', 'android-gallery'): 2,
#          ('java', 'printwriter'): 2,
#          ('android', 'web-applications'): 2,
#          ('java', 'size'): 2,
#          ('android', 'google-app-engine'): 2,
#          ('android', 'try-catch-finally'): 2,
#          ('android', 'imagedownload'): 2,
#          ('android', 'dialog'): 2,
#          ('android', 'classloader'): 2,
#          ('java', 'javabeans'): 2,
#          ('java', 'struts'): 2,
#          ('java', 'netbeans-7'): 2,
#          ('java', 'number-formatting'): 2,
#          ('android', 'number-formatting'): 2,
#          ('java', 'joptionpane'): 2,
#          ('java', 'desktop'): 2,
#          ('android', 'desktop'): 2,
#          ('java', 'timer'): 2,
#          ('java', 'restful-url'): 2,
#          ('android', 'jpeg'): 2,
#          ('java', 'null'): 2,
#          ('java', 'export'): 2,
#          ('java', 'gnu'): 2,
#          ('android', 'plaintext'): 2,
#          ('java', 'steganography'): 2,
#          ('java', 'text-files'): 2,
#          ('java', 'ftp-client'): 2,
#          ('java', 'apdu'): 2,
#          ('java', 'contactless-smartcard'): 2,
#          ('java', 'crc16'): 2,
#          ('java', 'struts-tags'): 2,
#          ('java', 'android-5.0-lollipop'): 2,
#          ('java', 'tomcat8'): 2,
#          ('java', 'crc'): 2,
#          ('java', 'thrift'): 2,
#          ('java', 'recaptcha'): 2,
#          ('java', 'netsuite'): 2,
#          ('java', 'cracking'): 2,
#          ('java', 'dct'): 2,
#          ('android', 'dct'): 2,
#          ('android', 'swift2'): 2,
#          ('java', 'extends'): 2,
#          ('java', 'windows-phone-8.1'): 2,
#          ('java', 'pgp'): 2,
#          ('java', 'react-native'): 2,
#          ('android', 'secure-random'): 2,
#          ('android', 'android-permissions'): 2,
#          ('java', 'node-crypto'): 2,
#          ('java', 'neo4j'): 2,
#          ('java', 'decoder'): 2,
#          ('java', 'encoder'): 2,
#          ('java', 'arduino'): 2,
#          ('java', 'provider'): 2,
#          ('java', 'datagram'): 2,
#          ('java', 'generics'): 2,
#          ('java', 'swift2'): 2,
#          ('android', 'rc4-cipher'): 2,
#          ('java', 'midp'): 2,
#          ('java', 'distribution'): 2,
#          ('java', 'cryptlib'): 2,
#          ('android', 'java-io'): 2,
#          ('android', 'android-2.0-eclair'): 2,
#          ('android', 'wampserver'): 2,
#          ('java', 'sms'): 2,
#          ('android', 'rijndaelmanaged'): 2,
#          ('android', 'android-4.2-jelly-bean'): 2,
#          ('java', 'rfc2898'): 2,
#          ('java', 'actionscript-3'): 2,
#          ('android', 'crash'): 2,
#          ('android', 'windows-8'): 2,
#          ('java', 'copy'): 2,
#          ('java', 'benchmarking'): 2,
#          ('java', 'verification'): 2,
#          ('android', 'pem'): 2,
#          ('java', 'large-data'): 2,
#          ('java', 'verisign'): 2,
#          ('java', 'nosuchproviderexception'): 2,
#          ('java', 'access-token'): 2,
#          ('java', 'ios7'): 2,
#          ('java', 'barcode'): 2,
#          ('android', 'barcode'): 2,
#          ('java', 'lotus-domino'): 2,
#          ('java', 'cross-platform'): 2,
#          ('java', 'gson'): 2,
#          ('java', 'cbc-mac'): 2,
#          ('android', 'cbc-mac'): 2,
#          ('java', 'libgcrypt'): 2,
#          ('android', 'java-security'): 2,
#          ('android', 'rsacryptoserviceprovider'): 2,
#          ('android', 'porting'): 2,
#          ('java', 'store'): 2,
#          ('java', 'symmetric'): 2,
#          ('java', 'elgamal'): 2,
#          ('java', 'rsacryptoserviceprovider'): 2,
#          ('java', 'for-loop'): 2,
#          ('android', 'android-service'): 2,
#          ('java', 'twofish'): 2,
#          ('java', 'uwp'): 2,
#          ('android', 'uwp'): 2,
#          ('android', 'samsung-mobile'): 2,
#          ('android', 'crypto++'): 2,
#          ('android', 'delphi'): 2,
#          ('android', 'delphi-xe8'): 2,
#          ('android', 'lockbox-3'): 2,
#          ('java', 'ecdsa'): 2,
#          ('java', 'coldfusion-11'): 2,
#          ('java', 'der'): 2,
#          ('android', 'key-pair'): 2,
#          ('android', 'memory-management'): 2,
#          ('java', 'nonce'): 2,
#          ('java', 'jpbc'): 2,
#          ('android', 'fingerprint'): 2,
#          ('java', '7zip'): 2,
#          ('android', '7zip'): 2,
#          ('android', 'kotlin'): 2,
#          ('android', 'intentservice'): 2,
#          ('android', 'linux'): 2,
#          ('java', 'video-streaming'): 2,
#          ('java', 'iostream'): 2,
#          ('java', 'buffer'): 2,
#          ('android', 'android-context'): 2,
#          ('java', 'webservice-client'): 2,
#          ('android', 'android-install-apk'): 2,
#          ('android', 'classnotfoundexception'): 2,
#          ('java', 'filenames'): 2,
#          ('java', 'guid'): 2,
#          ('java', 'java-ee-6'): 2,
#          ('java', 'coding-style'): 2,
#          ('android', 'digital-signature'): 2,
#          ('android', 'facebook-javascript-sdk'): 2,
#          ('java', 'caching'): 2,
#          ('android', 'sign'): 2,
#          ('android', 'signed'): 2,
#          ('java', 'wsse'): 2,
#          ('java', 'jsf'): 2,
#          ('java', 'facebook-login'): 2,
#          ('android', 'apk'): 2,
#          ('android', 'sdk'): 2,
#          ('java', 'ssh'): 2,
#          ('java', 'sql-insert'): 2,
#          ('android', 'baseadapter'): 2,
#          ('android', 'chat'): 2,
#          ('android', 'signing'): 2,
#          ('android', 'admob'): 2,
#          ('android', 'hashcode'): 2,
#          ('android', 'loopj'): 2,
#          ('android', 'gallery'): 2,
#          ('android', 'android-fragmentactivity'): 2,
#          ('android', 'apache-commons'): 2,
#          ('java', 'function'): 2,
#          ('android', 'google-plus'): 2,
#          ('java', 'asmack'): 2,
#          ('android', 'facebook-sdk-3.1'): 2,
#          ('java', 'mobile'): 2,
#          ('android', 'debugging'): 2,
#          ('java', 'android-fragments'): 2,
#          ('java', 'mail-server'): 2,
#          ('java', 'directory'): 2,
#          ('android', 'integration'): 2,
#          ('java', 'soapui'): 2,
#          ('android', 'encode'): 2,
#          ('android', 'instant-messaging'): 2,
#          ('java', 'powermockito'): 2,
#          ('java', 'ssha'): 2,
#          ('java', 'cpu-usage'): 2,
#          ('java', 'runtime-error'): 2,
#          ('java', 'collision'): 2,
#          ('java', 'jmeter'): 2,
#          ('java', 'apache-poi'): 2,
#          ('java', 'openshift'): 2,
#          ('java', 'google-cloud-storage'): 2,
#          ('android', 'oauth-1.0a'): 2,
#          ('java', 'spring-ldap'): 2,
#          ('java', 'self'): 2,
#          ('java', 'hashalgorithm'): 2,
#          ('java', 'compare'): 2,
#          ('java', 'utf-16'): 2,
#          ('java', 'message'): 2,
#          ('java', 'mocking'): 2,
#          ('java', 'playframework'): 2,
#          ('java', 'protocols'): 2,
#          ('java', 'owasp'): 2,
#          ('java', 'matlab'): 2,
#          ('java', 'sha2'): 2,
#          ('java', 'sip'): 2,
#          ('java', 'guava'): 2,
#          ('java', 'pfx'): 2,
#          ('java', 'blob'): 2,
#          ('android', 'stack-overflow'): 2,
#          ('java', 'bitcoin'): 2,
#          ('android', 'android-alertdialog'): 2,
#          ('java', 'mongodb'): 2,
#          ('java', 'trading'): 2,
#          ('java', 'gitkraken'): 2,
#          ('java', 'kraken.js'): 2,
#          ('java', 'git'): 2,
#          ('java', 'sign'): 2,
#          ('java', 'osgi'): 2,
#          ('android', 'apache-commons-httpclient'): 2,
#          ('java', 'timeout'): 2,
#          ('java', 'opc'): 2,
#          ('java', 'opc-ua'): 2,
#          ('android', 'twilio'): 2,
#          ('java', 'redirect'): 2,
#          ('java', 'android-looper'): 2,
#          ('android', 'android-looper'): 2,
#          ('java', 'multipartform-data'): 2,
#          ('java', 'apache-nifi'): 2,
#          ('android', 'httpresponse'): 2,
#          ('android', 'proxy'): 2,
#          ('android', 'parameters'): 2,
#          ('android', 'timeout'): 2,
#          ('android', 'class'): 2,
#          ('android', 'android-widget'): 2,
#          ('android', 'sslv3'): 2,
#          ('java', 'sax'): 2,
#          ('android', 'sax'): 2,
#          ('android', 'ejabberd-module'): 2,
#          ('android', 'openfire'): 2,
#          ('java', 'connection-reset'): 2,
#          ('java', 'mod-ssl'): 2,
#          ('java', 'mule'): 2,
#          ('java', 'ejabberd'): 2,
#          ('android', 'backwards-compatibility'): 2,
#          ('android', 'android-7.1-nougat'): 2,
#          ('java', 'executable'): 2,
#          ('android', 'executable'): 2,
#          ('android', 'wsdl'): 2,
#          ('java', 'equivalent'): 2,
#          ('java', 'shibboleth'): 2,
#          ('android', 'mcrypt-js'): 2,
#          ('java', 'gsm'): 2,
#          ('java', 'grooveshark'): 2,
#          ('java', 'woocommerce'): 2,
#          ('java', 'dropbox-api'): 2,
#          ('java', 'softhsm'): 2,
#          ('java', 'http-status-code-400'): 2,
#          ('java', 'poloniex'): 2,
#          ('java', 'activemq'): 2,
#          ('java', 'cisco'): 2,
#          ('java', 'push-notification'): 2,
#          ('java', 'securitymanager'): 2,
#          ('java', 'http-status-code-415'): 2,
#          ('java', 'exchange-server-2007'): 2,
#          ('java', 'outlook-2003'): 2,
#          ('java', 'jakarta-mail'): 2,
#          ('android', 'smtp'): 2,
#          ('java', 'httpserver'): 2,
#          ('android', 'trust'): 2,
#          ('android', '3g'): 2,
#          ('java', 'audio'): 2,
#          ('java', 'wav'): 2,
#          ('java', 'upload'): 2,
#          ('android', 'upload'): 2,
#          ('java', 'smartclient'): 2,
#          ('java', 'http-get'): 2,
#          ('android', 'netty'): 2,
#          ('android', 'amazon-ec2'): 2,
#          ('android', 'basic-authentication'): 2,
#          ('java', 'permissions'): 2,
#          ('java', 'ksoap'): 2,
#          ('java', 'sslexception'): 2,
#          ('android', 'tomcat6'): 2,
#          ('java', 'marklogic'): 2,
#          ('android', 'pkcs#12'): 2,
#          ('java', 'openid'): 2,
#          ('java', 'openid4java'): 2,
#          ('java', 'wso2'): 2,
#          ('java', 'wso2-identity-server'): 2,
#          ('java', 'imagedownload'): 2,
#          ('java', 'selenium'): 2,
#          ('java', 'xpath'): 2,
#          ('java', 'mockito'): 2,
#          ('java', 'jax-rpc'): 2,
#          ('java', 'geckoboard'): 2,
#          ('java', 'java-5'): 2,
#          ('java', 'android-virtual-device'): 2,
#          ('android', 'android-virtual-device'): 2,
#          ('android', 'tcpsocket'): 2,
#          ('android', 'pushbullet'): 2,
#          ('java', 'trust'): 2,
#          ('android', 'validation'): 2,
#          ('android', 'nanohttpd'): 2,
#          ('java', 'spray'): 2,
#          ('android', 'network-programming'): 2,
#          ('java', 'android-background'): 2,
#          ('android', 'android-background'): 2,
#          ('java', 'mq'): 2,
#          ('android', 'tomcat7'): 2,
#          ('android', 'sni'): 2,
#          ('java', 'google-maps'): 2,
#          ('java', 'wso2-api-manager'): 2,
#          ('java', 'retrofit'): 2,
#          ('android', 'memory-leaks'): 2,
#          ('java', 'http2'): 2,
#          ('java', 'android-async-http'): 2,
#          ('java', 'androidasync-koush'): 2,
#          ('android', 'jersey'): 2,
#          ('java', 'wunderground'): 2,
#          ('android', 'wunderground'): 2,
#          ('java', 'java-metro-framework'): 2,
#          ...})

# %%
display(", ".join(filter_tags))
# Out:
# 'c#, .net, facebook, sockets, base64, javascript, php, web-services, string, exception, node.js, ios, python, encoding, spring, objective-c, file, padding, mysql, apache-httpclient-4.x, ruby, soap, rest, bytearray, algorithm, eclipse, android-asynctask, android-volley, arrays, json, performance, okhttp, hex, byte, android-studio, facebook-graph-api, http, jsp, xml, servlets, tomcat, hibernate, post, multithreading, apache, okhttp3, c, scala, jakarta-ee, amazon-web-services, groovy, websocket, iphone, amazon-s3'

# %%
c_tags_top_crypto = Counter({k: v for k, v in c_tags.items() if (k not in filter_tags and k not in ['android', 'java'])})
display(c_tags_top_crypto.most_common(50))
# Out:
# [('encryption', 4064),
#  ('aes', 2055),
#  ('cryptography', 1287),
#  ('ssl', 1188),
#  ('https', 454),
#  ('rsa', 391),
#  ('security', 380),
#  ('hash', 273),
#  ('md5', 256),
#  ('bouncycastle', 255),
#  ('ssl-certificate', 216),
#  ('des', 158),
#  ('openssl', 150),
#  ('jce', 128),
#  ('certificate', 120),
#  ('sha256', 112),
#  ('sha1', 105),
#  ('cryptojs', 103),
#  ('keystore', 101),
#  ('3des', 92),
#  ('encryption-symmetric', 91),
#  ('httpclient', 87),
#  ('authentication', 79),
#  ('blowfish', 78),
#  ('public-key-encryption', 77),
#  ('sha', 73),
#  ('httpsurlconnection', 71),
#  ('badpaddingexception', 68),
#  ('sslhandshakeexception', 68),
#  ('hmac', 67),
#  ('tripledes', 61),
#  ('x509certificate', 61),
#  ('cbc-mode', 59),
#  ('aes-gcm', 57),
#  ('message-digest', 54),
#  ('rijndael', 52),
#  ('passwords', 51),
#  ('digital-signature', 48),
#  ('httpurlconnection', 47),
#  ('tls1.2', 45),
#  ('javax.crypto', 44),
#  ('password-encryption', 41),
#  ('c++', 39),
#  ('key', 37),
#  ('initialization-vector', 37),
#  ('secret-key', 37),
#  ('image', 35),
#  ('vb.net', 35),
#  ('sslsocketfactory', 35),
#  ('self-signed', 35)]

# %%
l_tags_top_crypto = [k for k, v in c_tags_top_crypto.most_common(50)]
display(l_tags_top_crypto)
# Out:
# ['encryption',
#  'aes',
#  'cryptography',
#  'ssl',
#  'https',
#  'rsa',
#  'security',
#  'hash',
#  'md5',
#  'bouncycastle',
#  'ssl-certificate',
#  'des',
#  'openssl',
#  'jce',
#  'certificate',
#  'sha256',
#  'sha1',
#  'cryptojs',
#  'keystore',
#  '3des',
#  'encryption-symmetric',
#  'httpclient',
#  'authentication',
#  'blowfish',
#  'public-key-encryption',
#  'sha',
#  'httpsurlconnection',
#  'badpaddingexception',
#  'sslhandshakeexception',
#  'hmac',
#  'tripledes',
#  'x509certificate',
#  'cbc-mode',
#  'aes-gcm',
#  'message-digest',
#  'rijndael',
#  'passwords',
#  'digital-signature',
#  'httpurlconnection',
#  'tls1.2',
#  'javax.crypto',
#  'password-encryption',
#  'c++',
#  'key',
#  'initialization-vector',
#  'secret-key',
#  'image',
#  'vb.net',
#  'sslsocketfactory',
#  'self-signed']

# %%
c_tags_top_all = Counter({k: v for k, v in c_tags.most_common(102) if (k not in ['android', 'java'])})
df_tags_top = pd.DataFrame.from_dict(dict(c_tags_top_all), orient='index').reset_index()
df_tags_top.columns = ['tag', 'count']
df_tags_top['crypto']=df_tags_top['tag'].apply(lambda x: x in l_tags_top_crypto)
print(df_tags_top['crypto'].value_counts())
display(df_tags_top)
# Out:
# crypto
# True     50
# False    50
# Name: count, dtype: int64
#                   tag  count  crypto
# 0          encryption   4064    True
# 1                 aes   2055    True
# 2        cryptography   1287    True
# 3                 ssl   1188    True
# 4               https    454    True
# ..                ...    ...     ...
# 95        self-signed     35    True
# 96  android-asynctask     34   False
# 97          websocket     34   False
# 98           retrofit     34   False
# 99               salt     32   False
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(3,15))
ax_tags = sns.barplot(y='tag', x='count', data=df_tags_top, hue='crypto', palette=sns.color_palette("Set1")[0:2])
ax_tags.set_xscale('log')
ax_tags.set(xlabel="Count (log)", ylabel="")
sns.despine(left=True, bottom=True)
plt.yticks(fontsize=7)
ax_tags.legend(ncol=2, loc="lower right", frameon=True, title='Crypto Tag')
plt.savefig('plots/tags_top100.pdf', bbox_inches='tight')

# %%
c_tuples_top_crypto = Counter({k: v for k, v in c_tuples.items() if any(x in l_tags_top_crypto for x in k)})
display(c_tuples_top_crypto)
# Out:
# Counter({('java', 'encryption'): 3325,
#          ('java', 'aes'): 1684,
#          ('android', 'encryption'): 1229,
#          ('java', 'cryptography'): 1135,
#          ('java', 'ssl'): 812,
#          ('android', 'aes'): 528,
#          ('android', 'ssl'): 471,
#          ('java', 'security'): 326,
#          ('java', 'rsa'): 323,
#          ('java', 'https'): 291,
#          ('android', 'cryptography'): 271,
#          ('android', 'https'): 230,
#          ('java', 'bouncycastle'): 219,
#          ('java', 'hash'): 219,
#          ('java', 'md5'): 211,
#          ('java', 'des'): 133,
#          ('java', 'ssl-certificate'): 128,
#          ('java', 'jce'): 126,
#          ('java', 'openssl'): 124,
#          ('android', 'rsa'): 114,
#          ('android', 'ssl-certificate'): 98,
#          ('android', 'security'): 92,
#          ('java', 'sha256'): 91,
#          ('java', 'sha1'): 84,
#          ('java', 'cryptojs'): 82,
#          ('java', '3des'): 81,
#          ('java', 'certificate'): 81,
#          ('java', 'keystore'): 75,
#          ('java', 'encryption-symmetric'): 68,
#          ('java', 'blowfish'): 68,
#          ('java', 'hmac'): 63,
#          ('java', 'httpclient'): 62,
#          ('android', 'hash'): 60,
#          ('java', 'sha'): 59,
#          ('java', 'public-key-encryption'): 58,
#          ('android', 'httpsurlconnection'): 54,
#          ('java', 'badpaddingexception'): 53,
#          ('java', 'tripledes'): 51,
#          ('java', 'aes-gcm'): 48,
#          ('android', 'bouncycastle'): 47,
#          ('android', 'md5'): 47,
#          ('android', 'certificate'): 47,
#          ('java', 'passwords'): 46,
#          ('java', 'rijndael'): 46,
#          ('java', 'cbc-mode'): 46,
#          ('java', 'message-digest'): 46,
#          ('java', 'authentication'): 44,
#          ('java', 'digital-signature'): 42,
#          ('java', 'sslhandshakeexception'): 42,
#          ('java', 'x509certificate'): 37,
#          ('java', 'javax.crypto'): 35,
#          ('java', 'secret-key'): 34,
#          ('android', 'keystore'): 34,
#          ('android', 'openssl'): 32,
#          ('java', 'initialization-vector'): 32,
#          ('android', 'httpclient'): 32,
#          ('java', 'c++'): 30,
#          ('android', 'authentication'): 29,
#          ('android', 'httpurlconnection'): 29,
#          ('java', 'httpsurlconnection'): 29,
#          ('java', 'tls1.2'): 29,
#          ('java', 'key'): 28,
#          ('java', 'vb.net'): 28,
#          ('java', 'password-encryption'): 28,
#          ('android', 'x509certificate'): 28,
#          ('android', 'sslhandshakeexception'): 28,
#          ('android', 'self-signed'): 26,
#          ('android', 'image'): 25,
#          ('java', 'httpurlconnection'): 25,
#          ('android', 'encryption-symmetric'): 24,
#          ('android', 'badpaddingexception'): 23,
#          ('java', 'sslsocketfactory'): 22,
#          ('android', 'des'): 19,
#          ('android', 'public-key-encryption'): 18,
#          ('android', 'sha'): 18,
#          ('android', 'sslsocketfactory'): 17,
#          ('android', 'javax.crypto'): 16,
#          ('android', 'sha1'): 16,
#          ('android', '3des'): 15,
#          ('android', 'sha256'): 15,
#          ('android', 'tls1.2'): 15,
#          ('java', 'image'): 13,
#          ('android', 'aes-gcm'): 12,
#          ('android', 'cryptojs'): 12,
#          ('android', 'hmac'): 12,
#          ('android', 'cbc-mode'): 11,
#          ('android', 'c++'): 11,
#          ('java', 'self-signed'): 11,
#          ('android', 'rijndael'): 10,
#          ('android', 'vb.net'): 10,
#          ('android', 'key'): 10,
#          ('android', 'secret-key'): 7,
#          ('android', 'password-encryption'): 6,
#          ('android', 'blowfish'): 6,
#          ('android', 'tripledes'): 5,
#          ('android', 'passwords'): 5,
#          ('android', 'initialization-vector'): 4,
#          ('android', 'message-digest'): 4,
#          ('android', 'jce'): 3,
#          ('android', 'digital-signature'): 2})

# %%
# Heatmap from Counter of tuple (tag1, tag2) tags
df_tags_top_crypto = pd.DataFrame.from_dict(c_tuples_top_crypto, orient='index').reset_index()

# Tuple to columns
df_tags_top_crypto['tag1'] = df_tags_top_crypto['index'].apply(lambda x: x[0])
df_tags_top_crypto['tag2'] = df_tags_top_crypto['index'].apply(lambda x: x[1])

df_tags_top_crypto.columns = ['index', 'count', 'tag1', 'tag2']
# delete index column
# del df_tags['index']
df_tags_top_crypto = df_tags_top_crypto.pivot(index='tag2', columns='tag1', values='count').fillna(0)
display(df_tags_top_crypto)

plt.figure(figsize=(2,11))
ax_tags = sns.heatmap(df_tags_top_crypto, annot=True, fmt='g', cmap="Blues", cbar=False)
ax_tags.set(xlabel="", ylabel="")
ax_tags.xaxis.tick_top()
plt.savefig('plots/fischer_heatmap_top50.pdf', bbox_inches='tight')
# Out:
# tag1                   android  java
# tag2
# 3des                        15    81
# aes                        528  1684
# aes-gcm                     12    48
# authentication              29    44
# badpaddingexception         23    53
# blowfish                     6    68
# bouncycastle                47   219
# c++                         11    30
# cbc-mode                    11    46
# certificate                 47    81
# cryptography               271  1135
# cryptojs                    12    82
# des                         19   133
# digital-signature            2    42
# encryption                1229  3325
# encryption-symmetric        24    68
# hash                        60   219
# hmac                        12    63
# httpclient                  32    62
# https                      230   291
# httpsurlconnection          54    29
# httpurlconnection           29    25
# image                       25    13
# initialization-vector        4    32
# javax.crypto                16    35
# jce                          3   126
# key                         10    28
# keystore                    34    75
# md5                         47   211
# message-digest               4    46
# openssl                     32   124
# password-encryption          6    28
# passwords                    5    46
# public-key-encryption       18    58
# rijndael                    10    46
# rsa                        114   323
# secret-key                   7    34
# security                    92   326
# self-signed                 26    11
# sha                         18    59
# sha1                        16    84
# sha256                      15    91
# ssl                        471   812
# ssl-certificate             98   128
# sslhandshakeexception       28    42
# sslsocketfactory            17    22
# tls1.2                      15    29
# tripledes                    5    51
# vb.net                      10    28
# x509certificate             28    37

# %%
frozen_l_tags_top_crypto = frozenset(l_tags_top_crypto)
frozen_tags = frozenset(['android', 'java'])

# %%
# %%timeit

# Slower version
# df_all_tags['Crypto'] = df_all_tags['Tags'].map(lambda x: bool(frozen_l_tags_top_crypto & set(x)) and bool(frozen_tags & set(x)))

def isCryptoSet(x):
    return bool(frozen_l_tags_top_crypto & set(x)) and bool(frozen_tags & set(x))

vecIsCryptoSet = np.vectorize(isCryptoSet)
df_all_tags['Crypto'] = vecIsCryptoSet(df_all_tags['Tags'])
# Out:
# 13.7 s ± 588 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df_all_tags['Crypto'].value_counts()
# Out:
# Crypto
# False    23792905
# True        83838
# Name: count, dtype: int64

# %%
display(df_all_tags[df_all_tags['Crypto']==True])
# Out:
#           QuestionId                                               Tags  \
# 312             3049                         [java, c++, windows, unix]
# 790             8318                            [java, security, jboss]
# 1401           14617                        [java, ftp, sftp, security]
# 1724           17944                              [java, c#, c++, math]
# 1852           19347                     [c#, java, c++, visual-studio]
# ...              ...                                                ...
# 23875210    77028536                     [java, c++, recursion, static]
# 23875352    77028842  [android, image, android-studio, android-asset...
# 23875466    77029070     [android, authentication, authorization, maui]
# 23875562    77029281  [java, google-play-console, public-key-encrypt...
# 23876271    77030734                                        [java, c++]
#
#                  CreationDate  Crypto
# 312       2008-08-06 03:19:19    True
# 790       2008-08-11 22:53:50    True
# 1401      2008-08-18 13:43:48    True
# 1724      2008-08-20 13:27:40    True
# 1852      2008-08-21 04:46:02    True
# ...                       ...     ...
# 23875210  2023-09-02 13:45:39    True
# 23875352  2023-09-02 15:16:20    True
# 23875466  2023-09-02 16:23:42    True
# 23875562  2023-09-02 17:17:12    True
# 23876271  2023-09-03 02:42:57    True
#
# [83838 rows x 4 columns]

# %%
df_all_tags_crypto = df_all_tags[df_all_tags['Crypto']==True].filter(['CreationDate', 'Crypto'])
# Set index to CreationDate
df_all_tags_crypto.set_index('CreationDate', inplace=True)
# Index is datetime
df_all_tags_crypto.index = pd.to_datetime(df_all_tags_crypto.index)
df_all_tags_crypto = df_all_tags_crypto[df_all_tags_crypto.index > "2008-09-01"]
df_all_tags_crypto = df_all_tags_crypto[df_all_tags_crypto.index < "2023-09-01"]
display(df_all_tags_crypto)
# Out:
#                      Crypto
# CreationDate
# 2008-09-04 15:21:44    True
# 2008-09-05 01:50:33    True
# 2008-09-08 06:13:19    True
# 2008-09-08 11:04:13    True
# 2008-09-09 05:52:23    True
# ...                     ...
# 2023-08-31 12:47:18    True
# 2023-08-31 14:53:25    True
# 2023-08-31 19:01:27    True
# 2023-08-31 19:44:15    True
# 2023-08-31 22:01:21    True
#
# [83802 rows x 1 columns]

# %%
# Group by month
df_all_tags_crypto = df_all_tags_crypto.resample('ME').sum()
display(df_all_tags_crypto)
# Out:
#               Crypto
# CreationDate
# 2008-09-30        54
# 2008-10-31        40
# 2008-11-30        37
# 2008-12-31        33
# 2009-01-31        54
# ...              ...
# 2023-04-30       155
# 2023-05-31       194
# 2023-06-30       160
# 2023-07-31       151
# 2023-08-31       164
#
# [180 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import kpss
kpss(df_all_tags_crypto['Crypto'], regression='c')
# Out:
# (0.48768237486517385,
#  0.04444090656189779,
#  9,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
from scipy import stats
x = np.arange(len(df_all_tags_crypto.index))
y = df_all_tags_crypto['Crypto'].values
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print(slope, intercept, r_value, p_value, std_err)
# To get coefficient of determination (r_squared)
print("r-squared:", r_value**2)
# Out:
# -0.7855057254853547 535.8694290976059 -0.1575727080600621 0.0346395406186459 0.3689765012275969
# r-squared: 0.02482915832538156

# %%
# Plot timeseries
plt.figure(figsize=(10,4))
ax_all_tags_crypto = sns.lineplot(data=df_all_tags_crypto, x='CreationDate', y='Crypto')
ax_all_tags_crypto.set(xlabel="", ylabel="New posts with crypto-related tags / month")
plt.autoscale(enable=True, axis='x', tight=True)
# x1, x2 = ax_all_tags_crypto.get_xlim()
# ax_all_tags_crypto.axline((x1, intercept), (x2,intercept+(slope/30)*(x2-x1)), color='red', ls='--') # Slope was per month, hence, we divide by 30 to get per day, which is the x-axis scale
sns.despine(left=True, bottom=True)

ax_all_tags_crypto.axvline(x=pd.Timestamp('2018-03-30'), color='black', linestyle=':') # Fischer: Java
ax_all_tags_crypto.annotate("DS$_{2018}$", xy=(pd.Timestamp('2018-03-30'), 50), ha='center', va='center', fontsize=12, color='black', backgroundcolor='white', annotation_clip=False)
#
ax_all_tags_crypto.axvline(x=pd.Timestamp('2016-03-30'), color='black', linestyle=':') # Fischer: Java
ax_all_tags_crypto.annotate("DS$_{2016}$", xy=(pd.Timestamp('2016-03-30'), 50), ha='center', va='center', fontsize=12, color='black', backgroundcolor='white',annotation_clip=False)

plt.savefig('plots/crypto_tag_timeseries.pdf', bbox_inches='tight')

# %%
# Crypto-related tags before Fischer's DS2016
df_all_tags_crypto[df_all_tags_crypto.index < "2016-03-30"].Crypto.sum()
# Out:
# 48888

# %%
# Crypto-related tags after Fischer's DS2016
df_all_tags_crypto[df_all_tags_crypto.index > "2016-03-30"].Crypto.sum()
# Out:
# 34914

# %%
# Calculate growth rate
df_all_tags_crypto.Crypto.sum() / df_all_tags_crypto[df_all_tags_crypto.index < "2016-03-30"].Crypto.sum() - 1
# Out:
# 0.7141629847815414

# %%
df_ds2016 = df_all_tags_crypto[df_all_tags_crypto.index < "2016-03-30"]
display(df_ds2016)
kpss(df_ds2016['Crypto'], regression='c')
# Out:
#               Crypto
# CreationDate
# 2008-09-30        54
# 2008-10-31        40
# 2008-11-30        37
# 2008-12-31        33
# 2009-01-31        54
# ...              ...
# 2015-10-31       824
# 2015-11-30       789
# 2015-12-31       779
# 2016-01-31       769
# 2016-02-29       780
#
# [90 rows x 1 columns]
# /tmp/ipykernel_7425/3742287521.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss(df_ds2016['Crypto'], regression='c')
# (1.453918315105839,
#  0.01,
#  5,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
df_ds2018 = df_all_tags_crypto[df_all_tags_crypto.index < "2018-03-30"]
display(df_ds2018)
kpss(df_ds2018['Crypto'], regression='c')
# Out:
#               Crypto
# CreationDate
# 2008-09-30        54
# 2008-10-31        40
# 2008-11-30        37
# 2008-12-31        33
# 2009-01-31        54
# ...              ...
# 2017-10-31       611
# 2017-11-30       572
# 2017-12-31       468
# 2018-01-31       537
# 2018-02-28       470
#
# [114 rows x 1 columns]
# /tmp/ipykernel_7425/285212050.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss(df_ds2018['Crypto'], regression='c')
# (1.151115714464594,
#  0.01,
#  6,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
c_all_tags = Counter()
for tags in df_all_tags.Tags.items():
    c_all_tags.update(tags[1])
display(c_all_tags)
# Out:
# Counter({'javascript': 2510216,
#          'python': 2160775,
#          'java': 1905586,
#          'c#': 1601044,
#          'php': 1461453,
#          'android': 1409229,
#          'html': 1179886,
#          'jquery': 1034419,
#          'c++': 798607,
#          'css': 797541,
#          'ios': 683117,
#          'sql': 664893,
#          'mysql': 661065,
#          'r': 496409,
#          'node.js': 466595,
#          'reactjs': 465315,
#          'arrays': 414660,
#          'c': 398933,
#          'asp.net': 373696,
#          'json': 357859,
#          'python-3.x': 340880,
#          'ruby-on-rails': 337299,
#          '.net': 333751,
#          'sql-server': 331828,
#          'swift': 329848,
#          'django': 308976,
#          'angular': 299176,
#          'objective-c': 292443,
#          'pandas': 282739,
#          'excel': 281792,
#          'angularjs': 262777,
#          'regex': 258880,
#          'ruby': 228384,
#          'linux': 225973,
#          'ajax': 221872,
#          'typescript': 221483,
#          'iphone': 221320,
#          'xml': 213731,
#          'vba': 211212,
#          'spring': 208632,
#          'laravel': 207984,
#          'asp.net-mvc': 200880,
#          'database': 193772,
#          'wordpress': 191528,
#          'string': 183345,
#          'mongodb': 174536,
#          'postgresql': 171882,
#          'wpf': 168874,
#          'flutter': 167901,
#          'windows': 166728,
#          'xcode': 158744,
#          'amazon-web-services': 154716,
#          'bash': 153969,
#          'git': 150118,
#          'oracle': 149725,
#          'dataframe': 143601,
#          'spring-boot': 143063,
#          'firebase': 141406,
#          'list': 140592,
#          'vb.net': 139782,
#          'multithreading': 139144,
#          'azure': 134203,
#          'react-native': 133727,
#          'docker': 133078,
#          'eclipse': 124724,
#          'algorithm': 119344,
#          'macos': 116418,
#          'powershell': 114443,
#          'visual-studio': 113849,
#          'image': 113459,
#          'forms': 113243,
#          'numpy': 112444,
#          'scala': 111770,
#          'function': 110327,
#          'api': 107042,
#          'vue.js': 105309,
#          'twitter-bootstrap': 102995,
#          'selenium': 101714,
#          'performance': 101160,
#          'winforms': 98336,
#          'loops': 95810,
#          'python-2.7': 95369,
#          'matlab': 94576,
#          'hibernate': 94254,
#          'express': 94185,
#          'sqlite': 94002,
#          'rest': 92640,
#          'apache': 92369,
#          'shell': 91965,
#          'entity-framework': 91467,
#          'kotlin': 90951,
#          'dart': 90408,
#          'android-studio': 89969,
#          'csv': 89579,
#          'maven': 87608,
#          'linq': 86141,
#          'facebook': 85652,
#          'qt': 85575,
#          'dictionary': 85530,
#          'unit-testing': 84743,
#          'tensorflow': 82319,
#          'file': 81162,
#          'apache-spark': 81082,
#          'swing': 81021,
#          'class': 79327,
#          'asp.net-core': 79032,
#          'sorting': 76302,
#          'date': 76168,
#          'unity-game-engine': 75220,
#          'authentication': 74886,
#          'symfony': 73557,
#          '.htaccess': 72903,
#          'opencv': 72693,
#          'tsql': 72680,
#          'google-chrome': 71942,
#          'for-loop': 71460,
#          'matplotlib': 71256,
#          'go': 70633,
#          'datetime': 70348,
#          'codeigniter': 69550,
#          'http': 67858,
#          'perl': 67816,
#          'validation': 67136,
#          'sockets': 66239,
#          'google-maps': 65869,
#          'object': 64873,
#          'uitableview': 64455,
#          'xaml': 61969,
#          'oop': 61843,
#          'if-statement': 61669,
#          'cordova': 61601,
#          'ubuntu': 60785,
#          'web-services': 60158,
#          'email': 59259,
#          'android-layout': 59111,
#          'spring-mvc': 58275,
#          'elasticsearch': 57995,
#          'ms-access': 57302,
#          'kubernetes': 57290,
#          'parsing': 57206,
#          'user-interface': 56866,
#          'github': 56771,
#          'c++11': 56477,
#          'visual-studio-code': 56378,
#          'security': 56159,
#          'pointers': 56143,
#          'ruby-on-rails-3': 56080,
#          'machine-learning': 55156,
#          'nginx': 54672,
#          'ggplot2': 54474,
#          'templates': 54449,
#          'selenium-webdriver': 54410,
#          'flask': 54019,
#          'sql-server-2008': 53833,
#          'variables': 53820,
#          'batch-file': 53749,
#          'exception': 53418,
#          'google-apps-script': 53037,
#          'google-sheets': 52629,
#          'listview': 52600,
#          'jsp': 52203,
#          'debugging': 51814,
#          'jpa': 51406,
#          'delphi': 51204,
#          'tkinter': 51132,
#          'gradle': 51028,
#          'asynchronous': 50986,
#          'pdf': 50954,
#          'haskell': 50849,
#          'wcf': 50818,
#          'ssl': 50649,
#          'xamarin': 50483,
#          'jenkins': 50375,
#          'amazon-s3': 49853,
#          'testing': 49749,
#          'web-scraping': 49498,
#          'npm': 49307,
#          'generics': 49047,
#          'ionic-framework': 48449,
#          'web': 47750,
#          'unix': 47503,
#          'google-cloud-platform': 47360,
#          'google-app-engine': 46953,
#          'visual-studio-2010': 46745,
#          'recursion': 46628,
#          'mongoose': 46563,
#          'android-fragments': 45664,
#          'session': 44562,
#          'animation': 44512,
#          'hadoop': 44312,
#          '.net-core': 43861,
#          'curl': 43769,
#          'heroku': 43711,
#          'laravel-5': 43705,
#          'math': 43692,
#          'url': 43464,
#          'svg': 43452,
#          'django-models': 43356,
#          'join': 43282,
#          'assembly': 43224,
#          'tomcat': 43031,
#          'intellij-idea': 42891,
#          'webpack': 42488,
#          'redirect': 42481,
#          'asp.net-mvc-4': 42411,
#          'inheritance': 42240,
#          'keras': 42226,
#          'winapi': 42225,
#          'image-processing': 41950,
#          'google-cloud-firestore': 41600,
#          'dom': 41368,
#          'actionscript-3': 41245,
#          'logging': 41051,
#          'gcc': 40899,
#          'matrix': 40828,
#          'post': 40734,
#          'button': 40395,
#          'firebase-realtime-database': 40023,
#          'jquery-ui': 39786,
#          'cocoa': 39610,
#          'd3.js': 39249,
#          'internet-explorer': 39115,
#          'xpath': 39109,
#          'pyspark': 39040,
#          'iis': 38892,
#          'optimization': 38859,
#          'firefox': 38730,
#          'rust': 38493,
#          'asp.net-mvc-3': 38473,
#          'select': 38454,
#          'networking': 38382,
#          'xslt': 38232,
#          'javafx': 38025,
#          'opengl': 37963,
#          'caching': 37951,
#          'events': 37885,
#          'magento': 37818,
#          'asp.net-web-api': 37664,
#          'plot': 37444,
#          'search': 37196,
#          'encryption': 36868,
#          'stored-procedures': 36811,
#          'ruby-on-rails-4': 36769,
#          'amazon-ec2': 36497,
#          'dplyr': 36033,
#          'audio': 35962,
#          'canvas': 35908,
#          'memory': 35870,
#          'jsf': 35732,
#          'swiftui': 35564,
#          'redux': 35446,
#          'multidimensional-array': 35235,
#          'random': 35209,
#          'flash': 35017,
#          'vector': 34996,
#          'facebook-graph-api': 34979,
#          'next.js': 34908,
#          'input': 34906,
#          'cookies': 34831,
#          'ipad': 34727,
#          'cocoa-touch': 34585,
#          'arraylist': 34500,
#          'xamarin.forms': 34435,
#          'video': 34044,
#          'indexing': 33948,
#          'model-view-controller': 33630,
#          'data-structures': 33457,
#          'servlets': 33258,
#          'serialization': 33154,
#          'jdbc': 33111,
#          'mod-rewrite': 33050,
#          'razor': 33002,
#          'routes': 32965,
#          'woocommerce': 32881,
#          'awk': 32718,
#          'iframe': 32618,
#          'beautifulsoup': 32284,
#          'filter': 31997,
#          'design-patterns': 31944,
#          'apache-kafka': 31848,
#          'text': 31734,
#          'cakephp': 31692,
#          'visual-c++': 31422,
#          'django-rest-framework': 31346,
#          'android-intent': 30912,
#          'aws-lambda': 30627,
#          'mobile': 30519,
#          'docker-compose': 30435,
#          'excel-formula': 30304,
#          'methods': 30287,
#          'struct': 30233,
#          'azure-devops': 30036,
#          'mvvm': 29964,
#          'ssh': 29962,
#          'ecmascript-6': 29892,
#          'react-hooks': 29890,
#          'groovy': 29883,
#          'grails': 29868,
#          'checkbox': 29823,
#          'lambda': 29764,
#          'time': 29680,
#          'jakarta-ee': 29436,
#          'installation': 29338,
#          'google-chrome-extension': 29258,
#          'android-recyclerview': 29231,
#          'meteor': 29095,
#          'sharepoint': 29084,
#          'core-data': 29072,
#          'android-activity': 28988,
#          'bootstrap-4': 28792,
#          'graph': 28707,
#          'activerecord': 28653,
#          'sed': 28565,
#          'plsql': 28549,
#          'types': 28472,
#          'shiny': 28414,
#          'spring-security': 28315,
#          'file-upload': 28064,
#          'scikit-learn': 28009,
#          'vim': 27994,
#          'websocket': 27910,
#          'replace': 27898,
#          'junit': 27788,
#          'soap': 27660,
#          'boost': 27542,
#          'group-by': 27486,
#          'cmake': 27451,
#          'deep-learning': 27366,
#          'memory-management': 27279,
#          'import': 27262,
#          'sass': 27238,
#          'silverlight': 27234,
#          'dynamic': 27206,
#          'eloquent': 26962,
#          'error-handling': 26931,
#          'gridview': 26807,
#          'layout': 26718,
#          'svn': 26701,
#          'async-await': 26569,
#          'browser': 26546,
#          'apache-spark-sql': 26502,
#          'charts': 26445,
#          'cmd': 26375,
#          'vuejs2': 26318,
#          'dependency-injection': 26292,
#          'while-loop': 26262,
#          'ffmpeg': 26078,
#          'view': 25980,
#          'deployment': 25934,
#          'dll': 25852,
#          'c#-4.0': 25851,
#          'highcharts': 25759,
#          'foreach': 25608,
#          'plugins': 25565,
#          'reporting-services': 25468,
#          'twitter': 25291,
#          'makefile': 25114,
#          'google-bigquery': 25100,
#          'google-maps-api-3': 25062,
#          'server': 25034,
#          'https': 24992,
#          'mysqli': 24945,
#          'redis': 24941,
#          'merge': 24914,
#          'unicode': 24912,
#          'reflection': 24898,
#          'extjs': 24871,
#          'jupyter-notebook': 24639,
#          'split': 24253,
#          'axios': 24251,
#          'encoding': 24169,
#          'netbeans': 24156,
#          'terminal': 24115,
#          'django-views': 24029,
#          'database-design': 23976,
#          'ember.js': 23975,
#          'collections': 23955,
#          'apache-flex': 23926,
#          'pdo': 23912,
#          'hash': 23892,
#          'oauth-2.0': 23794,
#          'data-binding': 23686,
#          'tcp': 23625,
#          'automation': 23510,
#          'command-line': 23434,
#          'react-redux': 23335,
#          'pip': 23271,
#          'printing': 23207,
#          'build': 23185,
#          'service': 23120,
#          'ansible': 23066,
#          'java-8': 23025,
#          'sqlalchemy': 22983,
#          'visual-studio-2012': 22958,
#          'html-table': 22954,
#          'jestjs': 22692,
#          'neo4j': 22691,
#          'parameters': 22673,
#          'pytorch': 22599,
#          'jquery-mobile': 22598,
#          'module': 22542,
#          'concurrency': 22515,
#          'promise': 22509,
#          'webview': 22464,
#          'web-applications': 22458,
#          'spring-data-jpa': 22440,
#          'uwp': 22264,
#          'lua': 22256,
#          'enums': 22253,
#          'datatable': 22187,
#          'utf-8': 22171,
#          'material-ui': 22083,
#          'outlook': 22003,
#          'drop-down-menu': 21875,
#          'flexbox': 21874,
#          'hive': 21842,
#          'tfs': 21755,
#          'python-requests': 21741,
#          'scroll': 21702,
#          'firebase-authentication': 21659,
#          'colors': 21645,
#          'twitter-bootstrap-3': 21474,
#          'count': 21454,
#          'syntax': 21427,
#          'parallel-processing': 21334,
#          'google-analytics': 21293,
#          'entity-framework-core': 21217,
#          'ssis': 21138,
#          'scipy': 21112,
#          'file-io': 21103,
#          'paypal': 20987,
#          'fonts': 20970,
#          'ms-word': 20955,
#          'constructor': 20912,
#          'gwt': 20827,
#          'graphql': 20792,
#          'three.js': 20786,
#          'socket.io': 20683,
#          'datatables': 20640,
#          'backbone.js': 20627,
#          'cassandra': 20595,
#          'rxjs': 20557,
#          'solr': 20554,
#          'graphics': 20502,
#          'url-rewriting': 20476,
#          'discord': 20476,
#          'zend-framework': 20405,
#          'drupal': 20350,
#          'datagridview': 20349,
#          'oracle11g': 20277,
#          'knockout.js': 20269,
#          'compiler-errors': 20213,
#          'nlp': 20173,
#          'memory-leaks': 20172,
#          'react-router': 20171,
#          'oauth': 20107,
#          'django-forms': 20039,
#          'neural-network': 19978,
#          'interface': 19928,
#          'casting': 19747,
#          'linked-list': 19716,
#          'google-api': 19700,
#          'parse-platform': 19680,
#          'triggers': 19677,
#          'windows-phone-7': 19662,
#          'proxy': 19636,
#          'visual-studio-2015': 19634,
#          'timer': 19565,
#          'directory': 19497,
#          'django-templates': 19484,
#          'cron': 19419,
#          'pygame': 19408,
#          'path': 19399,
#          'orm': 19298,
#          'primefaces': 19278,
#          'angular-material': 19258,
#          'arduino': 19233,
#          'push-notification': 19146,
#          'conditional-statements': 19089,
#          'jmeter': 19052,
#          'model': 18987,
#          'functional-programming': 18898,
#          'jar': 18880,
#          'visual-studio-2013': 18770,
#          'xamarin.android': 18754,
#          'vbscript': 18712,
#          'uiview': 18705,
#          'hyperlink': 18607,
#          'swift3': 18453,
#          'powerbi': 18444,
#          'download': 18420,
#          'sql-server-2005': 18391,
#          'windows-phone-8': 18215,
#          'rspec': 18192,
#          'process': 18164,
#          'properties': 18118,
#          'terraform': 18099,
#          'combobox': 18058,
#          'callback': 18057,
#          'configuration': 18008,
#          'scrapy': 17735,
#          'safari': 17722,
#          'emacs': 17682,
#          'pagination': 17652,
#          'scripting': 17651,
#          'clojure': 17607,
#          'gitlab': 17605,
#          'permissions': 17579,
#          'google-cloud-functions': 17571,
#          'angularjs-directive': 17529,
#          'scope': 17520,
#          'nhibernate': 17517,
#          'raspberry-pi': 17487,
#          'io': 17481,
#          'azure-active-directory': 17445,
#          'request': 17435,
#          'linux-kernel': 17368,
#          'jwt': 17321,
#          'responsive-design': 17316,
#          'mongodb-query': 17309,
#          'playframework': 17265,
#          'compilation': 17177,
#          'doctrine-orm': 17177,
#          'binding': 17167,
#          'bluetooth': 17151,
#          'dns': 17139,
#          'get': 17139,
#          'version-control': 17112,
#          '3d': 17099,
#          'architecture': 17079,
#          'reference': 17079,
#          'sql-server-2012': 17074,
#          'discord.js': 17065,
#          'pyqt': 16984,
#          'x86': 16949,
#          'rubygems': 16884,
#          'f#': 16859,
#          'package': 16834,
#          'kendo-ui': 16783,
#          'yii': 16776,
#          'autocomplete': 16716,
#          'datepicker': 16710,
#          'pycharm': 16673,
#          'tree': 16655,
#          'controller': 16590,
#          'xamarin.ios': 16576,
#          'grep': 16450,
#          'jackson': 16398,
#          'phpmyadmin': 16395,
#          'nested': 16382,
#          'openssl': 16371,
#          'static': 16356,
#          'statistics': 16309,
#          'uiviewcontroller': 16289,
#          'datagrid': 16227,
#          'null': 16204,
#          'active-directory': 16147,
#          'webforms': 16096,
#          'transactions': 16092,
#          'notifications': 15970,
#          'youtube': 15960,
#          'nullpointerexception': 15956,
#          'menu': 15810,
#          'duplicates': 15772,
#          'jsf-2': 15731,
#          'stream': 15720,
#          'bitmap': 15708,
#          'discord.py': 15682,
#          'visual-studio-2008': 15670,
#          'asp.net-mvc-5': 15660,
#          'sas': 15654,
#          'mocking': 15650,
#          'android-listview': 15567,
#          'computer-vision': 15545,
#          'yii2': 15454,
#          'ant': 15409,
#          'stl': 15386,
#          'sum': 15346,
#          'azure-functions': 15291,
#          'css-selectors': 15250,
#          'yaml': 15249,
#          'hashmap': 15200,
#          'time-series': 15178,
#          'dockerfile': 15176,
#          'jboss': 15132,
#          'character-encoding': 15128,
#          'electron': 15108,
#          'joomla': 15104,
#          'devise': 15024,
#          'floating-point': 15006,
#          'sdk': 14934,
#          'msbuild': 14912,
#          'cryptography': 14866,
#          'background': 14805,
#          'linq-to-sql': 14803,
#          'anaconda': 14770,
#          'google-drive-api': 14737,
#          'frontend': 14729,
#          'binary': 14708,
#          'expo': 14701,
#          'ios7': 14691,
#          'camera': 14688,
#          'navigation': 14666,
#          'pyqt5': 14644,
#          'onclick': 14613,
#          'android-asynctask': 14543,
#          'iterator': 14460,
#          'laravel-4': 14441,
#          'selenium-chromedriver': 14378,
#          'multiprocessing': 14347,
#          'insert': 14333,
#          'uicollectionview': 14311,
#          'tabs': 14308,
#          'asp.net-core-mvc': 14275,
#          'cuda': 14265,
#          'rabbitmq': 14225,
#          'ftp': 14196,
#          'upload': 14138,
#          'textview': 14125,
#          'coldfusion': 14098,
#          'xsd': 14063,
#          'opengl-es': 14058,
#          'console': 14027,
#          'linker': 13904,
#          'mariadb': 13888,
#          'leaflet': 13878,
#          'plotly': 13878,
#          'xml-parsing': 13853,
#          'amazon-dynamodb': 13784,
#          'continuous-integration': 13764,
#          'localization': 13708,
#          'environment-variables': 13698,
#          'operating-system': 13697,
#          'kivy': 13646,
#          'calendar': 13642,
#          'cors': 13642,
#          'formatting': 13621,
#          'json.net': 13611,
#          'timestamp': 13568,
#          'mockito': 13544,
#          'android-ndk': 13538,
#          'header': 13522,
#          'type-conversion': 13520,
#          'macros': 13488,
#          'data.table': 13451,
#          'integer': 13439,
#          'prolog': 13358,
#          'segmentation-fault': 13343,
#          'jasmine': 13304,
#          'drag-and-drop': 13302,
#          'char': 13272,
#          'crash': 13247,
#          'sprite-kit': 13201,
#          'itext': 13150,
#          'automated-tests': 13129,
#          'nosql': 13109,
#          'jquery-plugins': 13086,
#          'flutter-layout': 13064,
#          'attributes': 13040,
#          'annotations': 13024,
#          'mfc': 13002,
#          'microsoft-graph-api': 12999,
#          'geometry': 12985,
#          'android-gradle-plugin': 12902,
#          'format': 12895,
#          'fortran': 12866,
#          'dependencies': 12823,
#          'event-handling': 12746,
#          'visual-studio-2017': 12688,
#          'db2': 12683,
#          'gulp': 12677,
#          'textbox': 12670,
#          'keyboard': 12642,
#          'libgdx': 12607,
#          'xampp': 12588,
#          'jenkins-pipeline': 12585,
#          'firebase-cloud-messaging': 12548,
#          'crystal-reports': 12504,
#          'uiscrollview': 12500,
#          'centos': 12482,
#          'odoo': 12478,
#          'dom-events': 12470,
#          'synchronization': 12445,
#          'geolocation': 12394,
#          'namespaces': 12340,
#          'sequelize.js': 12338,
#          'postman': 12298,
#          'android-emulator': 12287,
#          'aggregation-framework': 12269,
#          'timezone': 12249,
#          'arm': 12246,
#          'julia': 12243,
#          'webdriver': 12235,
#          'com': 12233,
#          'blazor': 12218,
#          'wso2': 12182,
#          'windows-10': 12160,
#          'jvm': 12157,
#          'subprocess': 12152,
#          'mapreduce': 12150,
#          'ionic2': 12143,
#          'dialog': 12142,
#          'html5-canvas': 12136,
#          'chart.js': 12129,
#          'numbers': 12114,
#          'nuxt.js': 12109,
#          'android-edittext': 12096,
#          'garbage-collection': 12063,
#          'xmlhttprequest': 12038,
#          'concatenation': 12030,
#          'widget': 12026,
#          'set': 12014,
#          'rotation': 12012,
#          'sql-update': 12008,
#          'lucene': 11993,
#          'swagger': 11992,
#          'modal-dialog': 11986,
#          'radio-button': 11981,
#          'smtp': 11941,
#          'tuples': 11938,
#          'doctrine': 11929,
#          'grid': 11909,
#          'spring-data': 11872,
#          'http-headers': 11823,
#          'sonarqube': 11813,
#          'uikit': 11802,
#          'listbox': 11797,
#          'nestjs': 11786,
#          'ios5': 11775,
#          'qml': 11752,
#          'switch-statement': 11701,
#          'boolean': 11683,
#          'frameworks': 11670,
#          'internationalization': 11655,
#          'components': 11653,
#          'initialization': 11647,
#          'apache-camel': 11644,
#          'eclipse-plugin': 11634,
#          'ldap': 11621,
#          'azure-web-app-service': 11619,
#          'compiler-construction': 11616,
#          'nuget': 11611,
#          'return': 11603,
#          'serial-port': 11587,
#          'google-play': 11583,
#          'vuejs3': 11551,
#          'stripe-payments': 11533,
#          'tags': 11487,
#          'asp-classic': 11473,
#          'java-stream': 11470,
#          'youtube-api': 11459,
#          'dataset': 11406,
#          'uinavigationcontroller': 11390,
#          'struts2': 11366,
#          'pivot': 11337,
#          'azure-pipelines': 11335,
#          'protractor': 11334,
#          'gdb': 11324,
#          'sql-server-2008-r2': 11320,
#          'delegates': 11319,
#          'subquery': 11313,
#          'network-programming': 11292,
#          'foreign-keys': 11288,
#          'label': 11276,
#          'copy': 11273,
#          'uibutton': 11251,
#          'containers': 11194,
#          'fetch': 11183,
#          'find': 11181,
#          'base64': 11146,
#          'latex': 11137,
#          'append': 11132,
#          'google-sheets-formula': 11110,
#          'queue': 11093,
#          'jaxb': 11090,
#          'arguments': 11087,
#          'composer-php': 11060,
#          'autolayout': 11052,
#          'zip': 11019,
#          'migration': 11007,
#          'windows-7': 11007,
#          'cucumber': 10960,
#          'entity-framework-6': 10952,
#          'popup': 10948,
#          'ide': 10896,
#          'stack': 10887,
#          'jqgrid': 10872,
#          'android-viewpager': 10802,
#          'vb6': 10798,
#          'google-cloud-storage': 10798,
#          'iteration': 10791,
#          'passwords': 10714,
#          'uiwebview': 10713,
#          'snowflake-cloud-data-platform': 10691,
#          'hover': 10687,
#          'command': 10684,
#          'ios4': 10676,
#          'c++17': 10668,
#          'udp': 10649,
#          'gmail': 10633,
#          'uiimageview': 10624,
#          'twig': 10601,
#          'ssl-certificate': 10577,
#          'conv-neural-network': 10573,
#          'range': 10553,
#          'embedded': 10533,
#          'vue-component': 10522,
#          'r-markdown': 10481,
#          'salesforce': 10453,
#          'g++': 10450,
#          'jersey': 10402,
#          'angular-ui-router': 10400,
#          'ionic3': 10389,
#          'bots': 10355,
#          'local-storage': 10342,
#          'authorization': 10327,
#          'windows-8': 10290,
#          'constants': 10282,
#          'user-controls': 10278,
#          'gps': 10257,
#          'connection': 10247,
#          'wix': 10232,
#          'compare': 10210,
#          'twilio': 10205,
#          'cocos2d-iphone': 10198,
#          'debian': 10197,
#          'polymorphism': 10188,
#          'django-admin': 10184,
#          'slider': 10165,
#          'localhost': 10139,
#          'android-jetpack-compose': 10129,
#          'clang': 10114,
#          'airflow': 10092,
#          'ado.net': 10073,
#          'time-complexity': 10060,
#          'save': 10019,
#          'admob': 10015,
#          'mono': 10000,
#          'phpunit': 9980,
#          'jframe': 9959,
#          'certificate': 9941,
#          'sbt': 9904,
#          'python-imaging-library': 9868,
#          'imageview': 9865,
#          'pytest': 9818,
#          'pipe': 9805,
#          'output': 9791,
#          'drupal-7': 9776,
#          'gson': 9763,
#          'coffeescript': 9747,
#          'cypher': 9746,
#          'fullcalendar': 9740,
#          'mapping': 9736,
#          'include': 9734,
#          'tidyverse': 9729,
#          'cypress': 9724,
#          'apache-poi': 9723,
#          'java-native-interface': 9713,
#          'timeout': 9708,
#          'google-oauth': 9697,
#          'babeljs': 9688,
#          'web-crawler': 9679,
#          'int': 9665,
#          'location': 9644,
#          'hex': 9639,
#          'runtime-error': 9615,
#          'erlang': 9598,
#          'export': 9582,
#          'log4j': 9578,
#          'azure-sql-database': 9576,
#          'filesystems': 9573,
#          'icons': 9562,
#          'substring': 9555,
#          'observable': 9525,
#          'regression': 9524,
#          'iis-7': 9489,
#          'elixir': 9481,
#          'odbc': 9480,
#          'jinja2': 9470,
#          'storyboard': 9464,
#          'syntax-error': 9457,
#          'key': 9454,
#          'window': 9454,
#          'seaborn': 9445,
#          'telerik': 9444,
#          'maps': 9443,
#          'treeview': 9437,
#          'typo3': 9424,
#          'printf': 9421,
#          'ruby-on-rails-5': 9413,
#          'click': 9397,
#          'signalr': 9390,
#          'command-line-interface': 9380,
#          'cocoapods': 9371,
#          'github-actions': 9370,
#          'realm': 9369,
#          'logic': 9356,
#          'kernel': 9332,
#          'bluetooth-lowenergy': 9332,
#          'wordpress-theming': 9324,
#          'thread-safety': 9310,
#          'resources': 9302,
#          'ios8': 9298,
#          'ip': 9295,
#          'wsdl': 9289,
#          'ckeditor': 9278,
#          'botframework': 9276,
#          'amazon-elastic-beanstalk': 9251,
#          'cloud': 9246,
#          'in-app-purchase': 9246,
#          'dojo': 9244,
#          'uiimage': 9236,
#          'position': 9209,
#          'thymeleaf': 9201,
#          'resize': 9194,
#          'imagemagick': 9191,
#          'compression': 9172,
#          'malloc': 9144,
#          'actionscript': 9141,
#          'styles': 9128,
#          'state': 9105,
#          'repository': 9102,
#          'gruntjs': 9082,
#          'angularjs-ng-repeat': 9074,
#          'data-science': 9074,
#          'where-clause': 9068,
#          'cross-browser': 9067,
#          'microservices': 9054,
#          'build.gradle': 9049,
#          'jquery-selectors': 9007,
#          'google-visualization': 8985,
#          'max': 8976,
#          'windows-services': 8973,
#          'jsx': 8965,
#          'celery': 8958,
#          'pattern-matching': 8954,
#          'webrtc': 8953,
#          'angularjs-scope': 8949,
#          'escaping': 8922,
#          'closures': 8908,
#          'android-actionbar': 8890,
#          'swift2': 8879,
#          'pthreads': 8867,
#          'vuetify.js': 8865,
#          'asp.net-identity': 8858,
#          'gpu': 8846,
#          '.net-4.0': 8834,
#          'windows-installer': 8831,
#          'office365': 8828,
#          'constraints': 8809,
#          'global-variables': 8808,
#          'locking': 8782,
#          'pandas-groupby': 8780,
#          'google-chrome-devtools': 8739,
#          'applescript': 8735,
#          'try-catch': 8731,
#          'qt5': 8714,
#          'shopify': 8700,
#          'http-post': 8699,
#          'windows-runtime': 8697,
#          'ios6': 8692,
#          'many-to-many': 8684,
#          'zend-framework2': 8670,
#          'markdown': 8663,
#          'web-config': 8662,
#          'match': 8642,
#          'alignment': 8626,
#          'logstash': 8604,
#          'video-streaming': 8574,
#          'retrofit': 8571,
#          'vagrant': 8554,
#          'singleton': 8549,
#          'mocha.js': 8537,
#          'material-design': 8537,
#          'amazon-redshift': 8532,
#          'ef-code-first': 8514,
#          'jtable': 8513,
#          'uitextfield': 8508,
#          'azure-blob-storage': 8495,
#          'sh': 8490,
#          'internet-explorer-8': 8489,
#          'testng': 8485,
#          'task': 8481,
#          'sharepoint-2010': 8480,
#          'c++14': 8472,
#          'dax': 8472,
#          'artificial-intelligence': 8468,
#          'gtk': 8467,
#          'jasper-reports': 8461,
#          'operator-overloading': 8451,
#          'asp.net-mvc-2': 8449,
#          'asp.net-core-webapi': 8446,
#          'azure-data-factory': 8437,
#          'react-navigation': 8416,
#          'backend': 8409,
#          'controls': 8394,
#          'blackberry': 8384,
#          'bitbucket': 8369,
#          'broadcastreceiver': 8368,
#          'spring-batch': 8347,
#          ...})

# %%
# Create a DataFrame from the Counter that ranks the tags
df_tags = pd.DataFrame.from_dict(c_all_tags, orient='index').reset_index()
df_tags.columns = ['tag', 'count']
df_tags = df_tags.sort_values('count', ascending=False)
df_tags['rank'] = df_tags['count'].rank(ascending=False)
display(df_tags)
# Out:
#                                tag    count     rank
# 208                     javascript  2510216      1.0
# 123                         python  2160775      2.0
# 78                            java  1905586      3.0
# 0                               c#  1601044      4.0
# 45                             php  1461453      5.0
# ...                            ...      ...      ...
# 63530                bsb-framework        1  64170.0
# 60792                html5-pattern        1  64170.0
# 63525                   magic.link        1  64170.0
# 51451  analytics-engine-python-sdk        1  64170.0
# 65136                   jsonloader        1  64170.0
#
# [65137 rows x 3 columns]

# %%
# Rank the tags in l_tags_top_crypto
df_tags_top_crypto_rank = df_tags_top_crypto.reset_index()[['tag2']].copy()
df_tags_top_crypto_rank.columns = ['Tag']
df_tags_top_crypto_rank['Rank'] = df_tags_top_crypto_rank['Tag'].map(df_tags.set_index('tag')['rank'])
df_tags_top_crypto_rank['Rank'] = df_tags_top_crypto_rank['Rank'].astype(int)
df_tags_top_crypto_rank = df_tags_top_crypto_rank.sort_values('Rank')
display(df_tags_top_crypto_rank)
# Out:
#                       Tag   Rank
# 7                     c++      9
# 48                 vb.net     60
# 22                  image     70
# 3          authentication    110
# 37               security    145
# 42                    ssl    171
# 14             encryption    241
# 19                  https    361
# 16                   hash    380
# 30                openssl    551
# 10           cryptography    593
# 32              passwords    792
# 43        ssl-certificate    803
# 9             certificate    841
# 26                    key    882
# 1                     aes   1145
# 18             httpclient   1167
# 35                    rsa   1189
# 28                    md5   1851
# 13      digital-signature   2160
# 21      httpurlconnection   2219
# 46                 tls1.2   2238
# 49        x509certificate   2274
# 6            bouncycastle   2313
# 27               keystore   2572
# 41                 sha256   3349
# 33  public-key-encryption   3390
# 40                   sha1   3530
# 11               cryptojs   3866
# 17                   hmac   4188
# 39                    sha   4442
# 31    password-encryption   4802
# 38            self-signed   6309
# 15   encryption-symmetric   6670
# 12                    des   7257
# 36             secret-key   7390
# 44  sslhandshakeexception   8283
# 5                blowfish   9109
# 25                    jce   9471
# 34               rijndael   9496
# 2                 aes-gcm  10051
# 0                    3des  10688
# 20     httpsurlconnection  11241
# 47              tripledes  12707
# 8                cbc-mode  13306
# 29         message-digest  18991
# 23  initialization-vector  19723
# 45       sslsocketfactory  19723
# 24           javax.crypto  23299
# 4     badpaddingexception  25066

# %%
c_all_tuples = Counter()
for tags in df_all_tags.Tags.items():
    tag_list = tags[1]
    # Check that android or java in tags
    if not ('android' in tag_list or 'java' in tag_list):
        continue
    android_present = False
    java_present = False
    if 'android' in tag_list:
        android_present = True
        tag_list.remove('android')
    if 'java' in tag_list:
        java_present = True
        tag_list.remove('java')
    if android_present:
        c_all_tuples.update([('android', element) for element in tag_list])
    if java_present:
        c_all_tuples.update([('java', element) for element in tag_list])
display(c_all_tuples)
# Out:
# Counter({('java', 'spring'): 128083,
#          ('java', 'swing'): 79498,
#          ('java', 'spring-boot'): 74193,
#          ('android', 'android-studio'): 67465,
#          ('java', 'eclipse'): 59401,
#          ('java', 'hibernate'): 58764,
#          ('android', 'android-layout'): 57068,
#          ('android', 'kotlin'): 55218,
#          ('java', 'arrays'): 52237,
#          ('java', 'maven'): 47781,
#          ('android', 'android-fragments'): 44034,
#          ('java', 'multithreading'): 39271,
#          ('java', 'json'): 39210,
#          ('android', 'firebase'): 36870,
#          ('java', 'xml'): 36507,
#          ('android', 'listview'): 34768,
#          ('java', 'string'): 32596,
#          ('java', 'spring-mvc'): 32112,
#          ('java', 'jpa'): 31324,
#          ('android', 'xml'): 31314,
#          ('java', 'mysql'): 30590,
#          ('android', 'android-intent'): 29824,
#          ('android', 'sqlite'): 29186,
#          ('android', 'android-activity'): 27768,
#          ('android', 'android-recyclerview'): 27636,
#          ('java', 'jsp'): 27581,
#          ('java', 'arraylist'): 26391,
#          ('android', 'json'): 25410,
#          ('android', 'eclipse'): 24879,
#          ('java', 'javafx'): 24492,
#          ('java', 'tomcat'): 23651,
#          ('java', 'regex'): 23448,
#          ('java', 'servlets'): 23240,
#          ('java', 'android-studio'): 23204,
#          ('java', 'jdbc'): 22515,
#          ('java', 'selenium'): 22041,
#          ('android', 'ios'): 21865,
#          ('android', 'cordova'): 21603,
#          ('java', 'javascript'): 21253,
#          ('android', 'gradle'): 21096,
#          ('android', 'flutter'): 20223,
#          ('java', 'rest'): 20182,
#          ('java', 'junit'): 18830,
#          ('android', 'google-maps'): 18545,
#          ('java', 'sql'): 18534,
#          ('android', 'react-native'): 18413,
#          ('android', 'javascript'): 17842,
#          ('java', 'generics'): 17690,
#          ('java', 'java-8'): 17675,
#          ('java', 'intellij-idea'): 17201,
#          ('java', 'jakarta-ee'): 16742,
#          ('android', 'firebase-realtime-database'): 15677,
#          ('java', 'exception'): 15344,
#          ('java', 'html'): 15276,
#          ('java', 'algorithm'): 15151,
#          ('android', 'android-listview'): 15070,
#          ('android', 'webview'): 15058,
#          ('java', 'netbeans'): 14664,
#          ('java', 'gradle'): 14518,
#          ('java', 'jar'): 14253,
#          ('java', 'web-services'): 14176,
#          ('java', 'sockets'): 14176,
#          ('android', 'android-asynctask'): 14152,
#          ('java', 'file'): 13927,
#          ('java', 'database'): 13899,
#          ('android', 'xamarin'): 13873,
#          ('java', 'user-interface'): 13506,
#          ('java', 'selenium-webdriver'): 13343,
#          ('android', 'textview'): 13230,
#          ('java', 'kotlin'): 12784,
#          ('java', 'jackson'): 12226,
#          ('java', 'class'): 12181,
#          ('android', 'c#'): 11898,
#          ('android', 'android-edittext'): 11745,
#          ('android', 'php'): 11705,
#          ('java', 'spring-security'): 11491,
#          ('java', 'methods'): 11414,
#          ('java', 'collections'): 11178,
#          ('java', 'spring-data-jpa'): 11166,
#          ('java', 'unit-testing'): 11110,
#          ('android', 'android-gradle-plugin'): 11091,
#          ('android', 'facebook'): 11059,
#          ('java', 'oop'): 11010,
#          ('java', 'performance'): 10935,
#          ('android', 'image'): 10932,
#          ('android', 'android-ndk'): 10926,
#          ('android', 'database'): 10821,
#          ('android', 'layout'): 10757,
#          ('java', 'hashmap'): 10754,
#          ('java', 'oracle'): 10652,
#          ('java', 'list'): 10622,
#          ('java', 'firebase'): 10468,
#          ('java', 'java-stream'): 10413,
#          ('android', 'android-viewpager'): 10407,
#          ('android', 'html'): 10387,
#          ('java', 'sorting'): 10194,
#          ('android', 'android-emulator'): 10024,
#          ('java', 'loops'): 9944,
#          ('android', 'multithreading'): 9941,
#          ('android', 'google-play'): 9874,
#          ('java', 'jframe'): 9691,
#          ('java', 'nullpointerexception'): 9584,
#          ('java', 'object'): 9526,
#          ('java', 'mongodb'): 9468,
#          ('java', 'date'): 9392,
#          ('android', 'bitmap'): 9309,
#          ('java', 'jvm'): 9199,
#          ('java', 'sqlite'): 9191,
#          ('android', 'service'): 9136,
#          ('java', 'linux'): 9101,
#          ('java', 'image'): 9098,
#          ('java', 'android-fragments'): 8997,
#          ('android', 'button'): 8987,
#          ('java', 'google-app-engine'): 8958,
#          ('java', 'mockito'): 8915,
#          ('java', 'concurrency'): 8814,
#          ('android', 'imageview'): 8741,
#          ('java', 'scala'): 8737,
#          ('android', 'android-actionbar'): 8639,
#          ('java', 'inheritance'): 8621,
#          ('android', 'bluetooth'): 8560,
#          ('java', 'postgresql'): 8478,
#          ('java', 'parsing'): 8420,
#          ('android', 'dart'): 8251,
#          ('java', 'c#'): 8189,
#          ('android', 'broadcastreceiver'): 8171,
#          ('java', 'jtable'): 8107,
#          ('java', 'jaxb'): 8092,
#          ('java', 'gwt'): 8014,
#          ('java', 'c++'): 7947,
#          ('java', 'for-loop'): 7933,
#          ('java', 'hadoop'): 7927,
#          ('java', 'apache-poi'): 7906,
#          ('java', 'http'): 7888,
#          ('android', 'android-jetpack-compose'): 7837,
#          ('java', 'logging'): 7720,
#          ('android', 'nullpointerexception'): 7704,
#          ('java', 'recursion'): 7634,
#          ('android', 'xamarin.android'): 7629,
#          ('android', 'retrofit'): 7595,
#          ('android', 'fragment'): 7592,
#          ('android', 'mobile'): 7563,
#          ('java', 'ssl'): 7554,
#          ('java', 'serialization'): 7482,
#          ('java', 'reflection'): 7469,
#          ('java', 'jsf'): 7468,
#          ('java', 'php'): 7395,
#          ('android', 'android-sqlite'): 7343,
#          ('java', 'libgdx'): 7336,
#          ('java', 'jpanel'): 7334,
#          ('java', 'jboss'): 7301,
#          ('java', 'python'): 7298,
#          ('java', 'android-layout'): 7243,
#          ('android', 'arrays'): 7241,
#          ('java', 'windows'): 7151,
#          ('java', 'jersey'): 7138,
#          ('java', 'design-patterns'): 7105,
#          ('android', 'notifications'): 7066,
#          ('java', 'encryption'): 6936,
#          ('android', 'arraylist'): 6887,
#          ('android', 'animation'): 6862,
#          ('android', 'view'): 6833,
#          ('android', 'android-webview'): 6754,
#          ('java', 'if-statement'): 6735,
#          ('android', 'retrofit2'): 6728,
#          ('android', 'sharedpreferences'): 6704,
#          ('android', 'apk'): 6692,
#          ('java', 'annotations'): 6690,
#          ('java', 'applet'): 6655,
#          ('android', 'push-notification'): 6620,
#          ('java', 'apache-spark'): 6609,
#          ('android', 'unity-game-engine'): 6577,
#          ('android', 'android-service'): 6550,
#          ('android', 'adb'): 6530,
#          ('java', 'listview'): 6523,
#          ('android', 'performance'): 6514,
#          ('java', 'testing'): 6432,
#          ('java', 'awt'): 6432,
#          ('android', 'mysql'): 6394,
#          ('android', 'android-volley'): 6321,
#          ('java', 'amazon-web-services'): 6316,
#          ('android', 'google-play-services'): 6313,
#          ('java', 'data-structures'): 6275,
#          ('java', 'java.util.scanner'): 6225,
#          ('java', 'gson'): 6225,
#          ('java', 'excel'): 6204,
#          ('android', 'opengl-es'): 6201,
#          ('java', 'api'): 6182,
#          ('java', 'security'): 6180,
#          ('java', 'ant'): 6172,
#          ('android', 'c++'): 6120,
#          ('android', 'ionic-framework'): 6108,
#          ('android', 'admob'): 6102,
#          ('android', 'android-camera'): 6100,
#          ('java', 'interface'): 6050,
#          ('java', 'log4j'): 5993,
#          ('android', 'camera'): 5912,
#          ('android', 'android-room'): 5899,
#          ('java', 'android-recyclerview'): 5886,
#          ('java', 'soap'): 5838,
#          ('java', 'apache-kafka'): 5832,
#          ('java', 'enums'): 5811,
#          ('java', 'apache'): 5804,
#          ('java', 'macos'): 5715,
#          ('android', 'google-cloud-firestore'): 5668,
#          ('java', 'firebase-realtime-database'): 5662,
#          ('android', 'audio'): 5657,
#          ('java', 'pdf'): 5647,
#          ('android', 'android-manifest'): 5647,
#          ('android', 'string'): 5644,
#          ('android', 'user-interface'): 5642,
#          ('android', 'android-alertdialog'): 5525,
#          ('java', 'java-native-interface'): 5504,
#          ('android', 'android-widget'): 5493,
#          ('java', 'jquery'): 5461,
#          ('java', 'groovy'): 5420,
#          ('java', 'android-intent'): 5407,
#          ('android', 'android-animation'): 5400,
#          ('java', 'spring-data'): 5387,
#          ('android', 'gps'): 5383,
#          ('android', 'google-cloud-messaging'): 5370,
#          ('android', 'gridview'): 5351,
#          ('java', 'lambda'): 5350,
#          ('android', 'firebase-cloud-messaging'): 5328,
#          ('java', 'struts2'): 5315,
#          ('java', 'android-activity'): 5216,
#          ('android', 'api'): 5214,
#          ('android', 'firebase-authentication'): 5211,
#          ('android', 'sdk'): 5176,
#          ('android', 'sockets'): 5130,
#          ('android', 'navigation-drawer'): 5128,
#          ('java', 'constructor'): 5100,
#          ('java', 'io'): 5084,
#          ('java', 'linked-list'): 5041,
#          ('android', 'libgdx'): 5015,
#          ('android', 'build.gradle'): 4985,
#          ('java', 'validation'): 4957,
#          ('java', 'csv'): 4939,
#          ('android', 'file'): 4930,
#          ('java', 'testng'): 4848,
#          ('android', 'video'): 4839,
#          ('java', 'swt'): 4827,
#          ('java', 'jax-rs'): 4821,
#          ('android', 'android-linearlayout'): 4795,
#          ('java', 'file-io'): 4778,
#          ('java', 'jbutton'): 4772,
#          ('java', 'jsoup'): 4759,
#          ('java', 'math'): 4754,
#          ('java', 'playframework'): 4715,
#          ('java', 'ajax'): 4709,
#          ('java', 'docker'): 4666,
#          ('java', 'garbage-collection'): 4657,
#          ('android', 'material-design'): 4649,
#          ('android', 'android-notifications'): 4614,
#          ('java', 'random'): 4596,
#          ('android', 'android-mediaplayer'): 4584,
#          ('java', 'apache-camel'): 4583,
#          ('java', 'datetime'): 4579,
#          ('java', 'dictionary'): 4559,
#          ('java', 'graphics'): 4544,
#          ('java', 'while-loop'): 4510,
#          ('android', 'alarmmanager'): 4480,
#          ('java', 'authentication'): 4477,
#          ('android', 'dialog'): 4448,
#          ('java', 'elasticsearch'): 4437,
#          ('android', 'location'): 4436,
#          ('android', 'web-services'): 4428,
#          ('android', 'python'): 4406,
#          ('java', 'dependency-injection'): 4398,
#          ('android', 'opencv'): 4364,
#          ('android', 'parse-platform'): 4356,
#          ('java', 'debugging'): 4314,
#          ('java', 'static'): 4309,
#          ('java', 'multidimensional-array'): 4275,
#          ('java', 'networking'): 4249,
#          ('android', 'spinner'): 4224,
#          ('java', 'sql-server'): 4223,
#          ('android', 'android-arrayadapter'): 4211,
#          ('java', 'eclipse-plugin'): 4208,
#          ('java', 'itext'): 4168,
#          ('java', 'xpath'): 4155,
#          ('android', 'android-imageview'): 4136,
#          ('android', 'xamarin.forms'): 4052,
#          ('java', 'jenkins'): 4040,
#          ('android', 'http'): 4038,
#          ('java', 'variables'): 3999,
#          ('android', 'java-native-interface'): 3980,
#          ('android', 'gson'): 3970,
#          ('android', 'css'): 3957,
#          ('android', 'adapter'): 3954,
#          ('android', 'scrollview'): 3951,
#          ('java', 'glassfish'): 3922,
#          ('android', 'android-view'): 3912,
#          ('java', 'android-asynctask'): 3890,
#          ('java', 'web-applications'): 3884,
#          ('android', 'bluetooth-lowenergy'): 3876,
#          ('java', 'google-maps'): 3862,
#          ('android', 'sql'): 3833,
#          ('java', 'c'): 3832,
#          ('java', 'orm'): 3814,
#          ('android', 'android-relativelayout'): 3778,
#          ('java', 'audio'): 3777,
#          ('java', 'caching'): 3770,
#          ('java', 'thymeleaf'): 3765,
#          ('java', 'memory'): 3747,
#          ('android', 'android-canvas'): 3699,
#          ('java', 'jetty'): 3664,
#          ('java', 'email'): 3650,
#          ('android', 'android-permissions'): 3639,
#          ('java', 'classpath'): 3637,
#          ('android', 'rx-java'): 3637,
#          ('java', 'casting'): 3624,
#          ('java', 'jakarta-mail'): 3616,
#          ('android', 'reactjs'): 3575,
#          ('android', 'onclicklistener'): 3548,
#          ('java', 'split'): 3547,
#          ('java', 'ejb'): 3526,
#          ('android', 'canvas'): 3517,
#          ('android', 'exception'): 3500,
#          ('java', 'jms'): 3487,
#          ('android', 'unit-testing'): 3474,
#          ('java', 'url'): 3456,
#          ('android', 'android-support-library'): 3455,
#          ('android', 'jquery'): 3441,
#          ('java', 'css'): 3434,
#          ('java', 'layout'): 3425,
#          ('java', 'button'): 3403,
#          ('android', 'android-spinner'): 3402,
#          ('java', 'session'): 3389,
#          ('android', 'authentication'): 3382,
#          ('java', 'opencv'): 3362,
#          ('java', 'timer'): 3357,
#          ('android', 'proguard'): 3337,
#          ('android', 'sms'): 3315,
#          ('android', 'iphone'): 3308,
#          ('java', 'javafx-8'): 3304,
#          ('android', 'debugging'): 3300,
#          ('java', 'compiler-errors'): 3290,
#          ('java', 'inputstream'): 3281,
#          ('java', 'spring-batch'): 3278,
#          ('java', 'classloader'): 3265,
#          ('java', 'lucene'): 3263,
#          ('android', 'android-adapter'): 3251,
#          ('android', 'google-maps-android-api-2'): 3226,
#          ('java', 'actionlistener'): 3220,
#          ('android', 'android-custom-view'): 3220,
#          ('android', 'okhttp'): 3212,
#          ('java', 'model-view-controller'): 3184,
#          ('java', 'tcp'): 3174,
#          ('java', 'webdriver'): 3163,
#          ('android', 'actionbarsherlock'): 3158,
#          ('java', 'jlabel'): 3153,
#          ('java', 'transactions'): 3143,
#          ('java', 'input'): 3141,
#          ('android', 'tabs'): 3138,
#          ('android', 'crash'): 3133,
#          ('android', 'parsing'): 3132,
#          ('android', 'realm'): 3132,
#          ('java', 'jasper-reports'): 3130,
#          ('android', 'android-contentprovider'): 3120,
#          ('java', 'asynchronous'): 3116,
#          ('java', 'time'): 3074,
#          ('java', 'vaadin'): 3074,
#          ('java', 'web'): 3065,
#          ('android', 'background'): 3063,
#          ('android', 'android-constraintlayout'): 3019,
#          ('android', 'linux'): 3018,
#          ('android', 'rest'): 3005,
#          ('java', 'bufferedreader'): 2997,
#          ('java', 'ubuntu'): 2992,
#          ('android', 'android-toolbar'): 2991,
#          ('android', 'android-espresso'): 2979,
#          ('android', 'facebook-graph-api'): 2964,
#          ('android', 'expandablelistview'): 2960,
#          ('java', 'mapreduce'): 2958,
#          ('java', 'encoding'): 2951,
#          ('java', 'synchronization'): 2945,
#          ('android', 'permissions'): 2945,
#          ('java', 'layout-manager'): 2934,
#          ('android', 'android-xml'): 2923,
#          ('java', 'properties'): 2918,
#          ('java', 'guava'): 2911,
#          ('android', 'android-drawable'): 2910,
#          ('java', 'cxf'): 2909,
#          ('java', 'server'): 2898,
#          ('android', 'checkbox'): 2897,
#          ('java', 'osgi'): 2885,
#          ('java', 'thread-safety'): 2879,
#          ('android', 'intellij-idea'): 2873,
#          ('java', 'jtextfield'): 2866,
#          ('android', 'onclick'): 2859,
#          ('android', 'drawable'): 2855,
#          ('android', 'nfc'): 2832,
#          ('java', 'wildfly'): 2821,
#          ('java', 'opengl'): 2805,
#          ('java', 'iterator'): 2788,
#          ('java', 'stream'): 2780,
#          ('java', 'jsf-2'): 2769,
#          ('java', 'cryptography'): 2767,
#          ('java', 'nio'): 2764,
#          ('android', 'scroll'): 2746,
#          ('android', 'date'): 2709,
#          ('java', 'weblogic'): 2707,
#          ('java', 'xml-parsing'): 2706,
#          ('android', 'build'): 2699,
#          ('java', 'integer'): 2698,
#          ('java', 'search'): 2695,
#          ('java', 'double'): 2695,
#          ('java', 'lwjgl'): 2691,
#          ('java', 'log4j2'): 2688,
#          ('java', 'calendar'): 2686,
#          ('android', 'networking'): 2681,
#          ('android', 'surfaceview'): 2679,
#          ('java', 'websocket'): 2671,
#          ('java', 'utf-8'): 2649,
#          ('android', 'testing'): 2646,
#          ('java', 'netty'): 2643,
#          ('android', 'keyboard'): 2640,
#          ('android', 'android-5.0-lollipop'): 2638,
#          ('android', 'dagger-2'): 2638,
#          ('java', 'xsd'): 2635,
#          ('java', 'printing'): 2635,
#          ('java', 'sonarqube'): 2629,
#          ('android', 'google-chrome'): 2611,
#          ('java', 'primefaces'): 2608,
#          ('android', 'security'): 2600,
#          ('java', 'build'): 2590,
#          ('java', 'image-processing'): 2588,
#          ('android', 'android-jetpack'): 2584,
#          ('java', 'mocking'): 2576,
#          ('android', 'android-softkeyboard'): 2573,
#          ('android', 'android-livedata'): 2573,
#          ('java', 'amazon-s3'): 2571,
#          ('android', 'android-appcompat'): 2569,
#          ('java', 'jax-ws'): 2566,
#          ('java', 'processing'): 2553,
#          ('java', 'pdfbox'): 2547,
#          ('java', 'javabeans'): 2546,
#          ('java', 'spring-webflux'): 2546,
#          ('java', 'cucumber'): 2545,
#          ('java', 'eclipselink'): 2536,
#          ('java', 'websphere'): 2533,
#          ('java', 'azure'): 2523,
#          ('android', 'geolocation'): 2521,
#          ('android', 'kotlin-coroutines'): 2519,
#          ('android', 'encryption'): 2514,
#          ('java', 'webview'): 2510,
#          ('java', 'int'): 2495,
#          ('java', 'javafx-2'): 2491,
#          ('android', 'in-app-purchase'): 2490,
#          ('java', 'post'): 2489,
#          ('java', 'switch-statement'): 2484,
#          ('android', 'widget'): 2483,
#          ('java', 'dependencies'): 2480,
#          ('android', 'wear-os'): 2480,
#          ('java', 'pom.xml'): 2466,
#          ('android', 'android-source'): 2463,
#          ('android', 'mvvm'): 2462,
#          ('java', 'null'): 2460,
#          ('android', 'android-videoview'): 2460,
#          ('java', 'jstl'): 2458,
#          ('android', 'picasso'): 2445,
#          ('java', 'automation'): 2433,
#          ('java', 'service'): 2432,
#          ('java', 'spring-integration'): 2426,
#          ('android', 'android-resources'): 2423,
#          ('java', 'junit4'): 2421,
#          ('android', 'emulation'): 2420,
#          ('java', 'configuration'): 2419,
#          ('java', 'cassandra'): 2418,
#          ('java', 'wsdl'): 2414,
#          ('java', 'https'): 2388,
#          ('android', 'pdf'): 2384,
#          ('java', 'optimization'): 2379,
#          ('android', 'rx-java2'): 2379,
#          ('android', 'calendar'): 2370,
#          ('java', 'try-catch'): 2364,
#          ('android', 'node.js'): 2364,
#          ('android', 'appium'): 2359,
#          ('java', 'boolean'): 2353,
#          ('android', 'menu'): 2351,
#          ('java', 'jcombobox'): 2350,
#          ('java', 'eclipse-rcp'): 2343,
#          ('android', 'list'): 2340,
#          ('android', 'maven'): 2340,
#          ('android', 'android-databinding'): 2335,
#          ('android', 'navigation'): 2334,
#          ('android', 'ssl'): 2333,
#          ('java', 'minecraft'): 2329,
#          ('android', 'android-lifecycle'): 2326,
#          ('android', 'android-button'): 2324,
#          ('java', 'tree'): 2313,
#          ('android', 'in-app-billing'): 2310,
#          ('java', 'rx-java'): 2310,
#          ('java', 'polymorphism'): 2308,
#          ('android', 'media-player'): 2308,
#          ('java', 'google-cloud-firestore'): 2306,
#          ('java', 'plugins'): 2299,
#          ('java', 'text'): 2299,
#          ('java', 'tomcat7'): 2296,
#          ('android', 'timer'): 2292,
#          ('java', 'grails'): 2289,
#          ('java', 'rmi'): 2276,
#          ('android', 'wifi'): 2248,
#          ('java', 'package'): 2245,
#          ('java', 'graph'): 2236,
#          ('java', 'fxml'): 2235,
#          ('java', 'character-encoding'): 2234,
#          ('java', 'angularjs'): 2226,
#          ('android', 'colors'): 2225,
#          ('java', 'compilation'): 2224,
#          ('android', 'android-virtual-device'): 2223,
#          ('android', 'android-cardview'): 2219,
#          ('java', 'deserialization'): 2211,
#          ('java', 'git'): 2209,
#          ('java', 'java-7'): 2207,
#          ('android', 'android-glide'): 2207,
#          ('java', 'import'): 2203,
#          ('java', 'animation'): 2196,
#          ('java', 'textview'): 2196,
#          ('java', 'deployment'): 2190,
#          ('java', 'neo4j'): 2187,
#          ('java', 'matrix'): 2183,
#          ('java', 'set'): 2182,
#          ('java', 'out-of-memory'): 2179,
#          ('java', 'memory-leaks'): 2177,
#          ('java', 'h2'): 2177,
#          ('java', 'heap-memory'): 2176,
#          ('java', 'solr'): 2175,
#          ('java', 'unicode'): 2158,
#          ('java', 'facebook'): 2158,
#          ('java', 'jodatime'): 2158,
#          ('java', 'char'): 2155,
#          ('java', 'dom'): 2150,
#          ('java', 'swagger'): 2144,
#          ('android', 'androidx'): 2141,
#          ('java', 'retrofit'): 2139,
#          ('java', 'bitmap'): 2136,
#          ('java', '.net'): 2130,
#          ('android', 'android-theme'): 2128,
#          ('java', 'simpledateformat'): 2123,
#          ('android', 'ffmpeg'): 2122,
#          ('java', 'guice'): 2121,
#          ('java', 'comparator'): 2118,
#          ('android', 'logcat'): 2118,
#          ('java', 'path'): 2115,
#          ('android', 'searchview'): 2111,
#          ('java', 'types'): 2104,
#          ('java', 'events'): 2087,
#          ('android', 'url'): 2084,
#          ('java', 'jscrollpane'): 2083,
#          ('android', 'email'): 2083,
#          ('java', 'maven-2'): 2078,
#          ('android', 'adt'): 2075,
#          ('java', 'shell'): 2069,
#          ('java', 'executorservice'): 2069,
#          ('java', 'junit5'): 2065,
#          ('java', 'javac'): 2063,
#          ('android', 'android-tabhost'): 2062,
#          ('java', 'jfreechart'): 2058,
#          ('java', 'selenium-chromedriver'): 2056,
#          ('java', 'singleton'): 2047,
#          ('java', 'stack'): 2044,
#          ('java', 'hql'): 2043,
#          ('android', 'android-6.0-marshmallow'): 2039,
#          ('java', 'file-upload'): 2035,
#          ('java', 'proxy'): 2034,
#          ('java', 'overriding'): 2032,
#          ('android', 'junit'): 2031,
#          ('java', 'android-listview'): 2030,
#          ('java', 'aspectj'): 2026,
#          ('java', 'bufferedimage'): 2025,
#          ('java', 'slf4j'): 2024,
#          ('java', 'colors'): 2018,
#          ('java', 'return'): 2017,
#          ('android', 'android-mapview'): 2009,
#          ('android', 'android-fragmentactivity'): 2008,
#          ('java', 'process'): 2007,
#          ('java', 'memory-management'): 2001,
#          ('java', 'command-line'): 1998,
#          ('java', 'persistence'): 1990,
#          ('android', 'android-contacts'): 1988,
#          ('java', 'java-11'): 1979,
#          ('android', 'c'): 1975,
#          ('java', 'byte'): 1971,
#          ('java', 'jtextarea'): 1971,
#          ('java', 'quartz-scheduler'): 1970,
#          ('java', 'wicket'): 1970,
#          ('java', 'queue'): 1966,
#          ('java', 'activemq'): 1965,
#          ('java', 'struts'): 1961,
#          ('java', 'httpurlconnection'): 1958,
#          ('android', 'andengine'): 1955,
#          ('android', 'google-app-engine'): 1950,
#          ('android', 'android-tablayout'): 1948,
#          ('android', 'post'): 1945,
#          ('android', 'firebase-storage'): 1941,
#          ('android', 'android-wifi'): 1940,
#          ('java', 'client'): 1938,
#          ('java', 'oauth-2.0'): 1934,
#          ('java', 'bluetooth'): 1933,
#          ('android', 'uri'): 1929,
#          ('android', 'expo'): 1929,
#          ('java', 'executable-jar'): 1923,
#          ('android', 'class'): 1923,
#          ('android', 'caching'): 1920,
#          ('android', 'out-of-memory'): 1918,
#          ('java', 'logback'): 1915,
#          ('java', 'hash'): 1911,
#          ('java', 'google-cloud-platform'): 1911,
#          ('android', 'memory-leaks'): 1908,
#          ('android', 'android-context'): 1906,
#          ('java', 'client-server'): 1897,
#          ('java', 'function'): 1896,
#          ('android', 'google-api'): 1896,
#          ('java', 'android-edittext'): 1887,
#          ('android', 'android-styles'): 1885,
#          ('android', 'android-testing'): 1881,
#          ('java', 'equals'): 1872,
#          ('android', 'android-dialogfragment'): 1871,
#          ('java', 'appium'): 1871,
#          ('java', 'javadoc'): 1870,
#          ('java', 'runtime'): 1863,
#          ('android', 'android-preferences'): 1863,
#          ('java', 'parameters'): 1860,
#          ('java', 'redis'): 1860,
#          ('android', 'google-play-console'): 1856,
#          ('java', 'hibernate-mapping'): 1855,
#          ('java', 'httpclient'): 1854,
#          ('java', 'joptionpane'): 1846,
#          ('android', 'screen'): 1844,
#          ('java', 'indexoutofboundsexception'): 1844,
#          ('java', 'war'): 1834,
#          ('java', 'aes'): 1833,
#          ('android', 'usb'): 1832,
#          ('android', 'cursor'): 1828,
#          ('java', 'mybatis'): 1828,
#          ('android', 'android-pendingintent'): 1827,
#          ('java', 'angular'): 1826,
#          ('android', 'download'): 1822,
#          ('java', 'ldap'): 1819,
#          ('java', 'node.js'): 1818,
#          ('java', 'rabbitmq'): 1816,
#          ('java', 'sharedpreferences'): 1812,
#          ('java', 'xslt'): 1810,
#          ('android', 'image-processing'): 1803,
#          ('java', 'lombok'): 1803,
#          ('android', 'jquery-mobile'): 1797,
#          ('java', 'jpql'): 1795,
#          ('android', 'twitter'): 1795,
#          ('android', 'httpurlconnection'): 1788,
#          ('java', 'listener'): 1787,
#          ('java', 'maven-3'): 1782,
#          ('java', 'jlist'): 1780,
#          ('java', 'retrofit2'): 1776,
#          ('android', 'android-library'): 1775,
#          ('android', 'jsoup'): 1774,
#          ('android', 'android-bluetooth'): 1774,
#          ('java', 'aop'): 1771,
#          ('android', 'kivy'): 1768,
#          ('java', 'timezone'): 1766,
#          ('java', 'java-me'): 1762,
#          ('java', 'jmeter'): 1761,
#          ('java', 'error-handling'): 1760,
#          ('android', 'mpandroidchart'): 1756,
#          ('java', 'bouncycastle'): 1755,
#          ('java', 'cdi'): 1749,
#          ('android', 'maps'): 1745,
#          ('java', 'jna'): 1740,
#          ('java', 'playframework-2.0'): 1737,
#          ('java', 'fonts'): 1736,
#          ('android', 'progressdialog'): 1732,
#          ('android', 'memory'): 1728,
#          ('android', 'exoplayer'): 1722,
#          ('android', 'text'): 1721,
#          ('android', 'windows'): 1721,
#          ('java', 'jndi'): 1714,
#          ('java', 'cmd'): 1713,
#          ('android', 'android-bitmap'): 1712,
#          ('java', 'batch-file'): 1711,
#          ('android', 'git'): 1709,
#          ('android', 'youtube'): 1708,
#          ('android', 'android-scrollview'): 1703,
#          ('java', 'mobile'): 1699,
#          ('android', 'delphi'): 1698,
#          ('android', 'opengl-es-2.0'): 1698,
#          ('java', 'network-programming'): 1696,
#          ('android', 'handler'): 1696,
#          ('java', 'bash'): 1695,
#          ('android', 'asynchronous'): 1695,
#          ('java', 'abstract-class'): 1690,
#          ('java', 'apache-httpclient-4.x'): 1688,
#          ('java', 'threadpool'): 1686,
#          ('java', 'replace'): 1682,
#          ('android', 'progress-bar'): 1681,
#          ('java', 'prepared-statement'): 1680,
#          ('android', 'listener'): 1679,
#          ('android', 'google-analytics'): 1677,
#          ('java', 'resttemplate'): 1667,
#          ('android', 'fonts'): 1662,
#          ('java', 'ios'): 1661,
#          ('java', 'zip'): 1660,
#          ('android', 'facebook-android-sdk'): 1650,
#          ('java', 'jooq'): 1649,
#          ('java', 'cookies'): 1642,
#          ('java', 'connection'): 1641,
#          ('android', 'amazon-web-services'): 1636,
#          ('android', 'macos'): 1633,
#          ('android', 'touch'): 1630,
#          ('java', 'paintcomponent'): 1626,
#          ('android', 'android-architecture-components'): 1624,
#          ('android', 'baseadapter'): 1622,
#          ('android', 'icons'): 1619,
#          ('java', 'automated-tests'): 1613,
#          ('java', 'build.gradle'): 1608,
#          ('android', 'parcelable'): 1605,
#          ('java', 'android-volley'): 1599,
#          ('java', 'resultset'): 1598,
#          ('android', 'angularjs'): 1594,
#          ('android', 'android-progressbar'): 1590,
#          ('java', 'android-sqlite'): 1589,
#          ('java', 'synchronized'): 1588,
#          ('java', 'ide'): 1587,
#          ('java', 'udp'): 1587,
#          ('java', 'forms'): 1587,
#          ('android', 'android-gridview'): 1584,
#          ('java', 'microservices'): 1575,
#          ('java', 'binary'): 1574,
#          ('java', 'java-io'): 1572,
#          ('java', 'project-reactor'): 1572,
#          ('java', 'download'): 1571,
#          ('android', 'rotation'): 1571,
#          ('java', 'java-web-start'): 1568,
#          ('java', 'autowired'): 1568,
#          ('android', 'google-maps-markers'): 1568,
#          ('java', 'reference'): 1565,
#          ('java', 'derby'): 1559,
#          ('java', 'apache-commons'): 1556,
#          ('android', 'android-viewmodel'): 1556,
#          ('android', 'titanium'): 1554,
#          ('android', 'datepicker'): 1549,
#          ('java', 'keylistener'): 1545,
#          ('java', 'quarkus'): 1544,
#          ('android', 'qt'): 1540,
#          ('android', 'intentfilter'): 1539,
#          ('java', 'architecture'): 1534,
#          ('android', 'gallery'): 1534,
#          ('java', 'filter'): 1533,
#          ('android', 'search'): 1532,
#          ('android', 'radio-button'): 1531,
#          ('java', 'liferay'): 1526,
#          ('java', 'bukkit'): 1526,
#          ('java', 'ftp'): 1525,
#          ('android', 'google-places-api'): 1525,
#          ('android', 'visual-studio'): 1519,
#          ('android', 'android-camera2'): 1519,
#          ('android', 'google-maps-api-3'): 1518,
#          ('java', 'akka'): 1517,
#          ('java', 'rsa'): 1516,
#          ('java', 'unix'): 1511,
#          ('android', 'robolectric'): 1510,
#          ('android', 'floating-action-button'): 1510,
#          ('java', 'jersey-2.0'): 1507,
#          ('android', 'orientation'): 1506,
#          ('java', 'inner-classes'): 1505,
#          ('android', 'toolbar'): 1503,
#          ('android', 'storage'): 1502,
#          ('java', 'graphics2d'): 1501,
#          ('android', 'splash-screen'): 1501,
#          ('java', 'visual-studio-code'): 1500,
#          ('android', 'http-post'): 1498,
#          ('java', 'binary-search-tree'): 1495,
#          ('android', 'contacts'): 1488,
#          ('java', 'imageview'): 1487,
#          ('android', 'android-coordinatorlayout'): 1484,
#          ('android', 'android-image'): 1478,
#          ('android', 'android-sensors'): 1474,
#          ('java', 'resources'): 1471,
#          ('java', 'spring-aop'): 1469,
#          ('android', 'jar'): 1467,
#          ('android', 'bottomnavigationview'): 1464,
#          ('java', 'java-time'): 1462,
#          ('java', 'binary-tree'): 1462,
#          ('java', 'sdk'): 1461,
#          ('java', 'drools'): 1460,
#          ('android', 'time'): 1457,
#          ('java', 'mapping'): 1456,
#          ('java', 'parallel-processing'): 1456,
#          ('java', 'hashset'): 1454,
#          ('android', 'google-signin'): 1453,
#          ('android', 'deep-linking'): 1452,
#          ('android', 'cordova-plugins'): 1452,
#          ('java', 'bytecode'): 1449,
#          ('java', 'substring'): 1443,
#          ('java', 'locking'): 1442,
#          ('android', 'android-sdcard'): 1440,
#          ('android', 'events'): 1439,
#          ('android', 'datetime'): 1438,
#          ('java', 'console'): 1436,
#          ('android', 'zxing'): 1436,
#          ('android', 'ads'): 1434,
#          ('java', 'canvas'): 1430,
#          ('java', 'base64'): 1428,
#          ('java', 'integration-testing'): 1427,
#          ('android', 'resources'): 1424,
#          ('java', 'initialization'): 1422,
#          ('android', 'android-dialog'): 1421,
#          ('android', 'rx-android'): 1420,
#          ('android', 'dependency-injection'): 1419,
#          ('java', '2d'): 1416,
#          ('android', 'phonegap-plugins'): 1415,
#          ('java', 'numbers'): 1414,
#          ('android', 'regex'): 1412,
#          ('java', 'jwt'): 1412,
#          ('java', 'reactive-programming'): 1411,
#          ('java', 'maven-plugin'): 1409,
#          ('java', 'processbuilder'): 1409,
#          ('java', 'refactoring'): 1407,
#          ('java', 'powermock'): 1407,
#          ('java', 'type-conversion'): 1404,
#          ('android', 'firebaseui'): 1404,
#          ('java', 'google-chrome'): 1403,
#          ('android', 'hashmap'): 1403,
#          ('java', 'noclassdeffounderror'): 1399,
#          ('java', 'okhttp'): 1398,
#          ('android', 'ontouchlistener'): 1397,
#          ('android', 'angular'): 1396,
#          ('android', 'xml-parsing'): 1395,
#          ('java', 'syntax'): 1389,
#          ('java', 'heroku'): 1389,
#          ('java', 'jpa-2.0'): 1388,
#          ('java', 'ssh'): 1384,
#          ('java', 'resteasy'): 1383,
#          ('android', 'autocompletetextview'): 1383,
#          ('android', 'dictionary'): 1382,
#          ('java', 'jmx'): 1374,
#          ('android', 'samsung-mobile'): 1374,
#          ('java', 'functional-programming'): 1366,
#          ('java', 'paint'): 1363,
#          ('android', 'google-drive-api'): 1363,
#          ('android', 'styles'): 1361,
#          ('java', 'directory'): 1359,
#          ('java', 'dynamic'): 1358,
#          ('java', 'spring-kafka'): 1355,
#          ('java', 'compare'): 1352,
#          ('android', 'android-4.4-kitkat'): 1352,
#          ('android', 'xmpp'): 1349,
#          ('android', 'native'): 1349,
#          ('java', 'hashcode'): 1346,
#          ('java', 'keystore'): 1342,
#          ('java', 'final'): 1341,
#          ('android', 'video-streaming'): 1337,
#          ('java', 'classnotfoundexception'): 1332,
#          ('java', 'jsch'): 1329,
#          ('java', 'runtime-error'): 1324,
#          ('android', 'nativescript'): 1324,
#          ('java', 'vector'): 1320,
#          ('android', 'ant'): 1315,
#          ('java', 'hbase'): 1315,
#          ('java', 'runnable'): 1314,
#          ('android', 'swipe'): 1312,
#          ('java', 'bigdecimal'): 1309,
#          ('java', 'fragment'): 1309,
#          ('android', 'themes'): 1308,
#          ('java', 'view'): 1307,
#          ('android', 'android-location'): 1305,
#          ('java', 'rest-assured'): 1304,
#          ('java', 'indexing'): 1303,
#          ('android', 'mockito'): 1299,
#          ('java', 'video'): 1289,
#          ('android', 'data-binding'): 1288,
#          ('java', 'ssl-certificate'): 1286,
#          ('java', 'time-complexity'): 1285,
#          ('android', 'installation'): 1285,
#          ('java', 'serversocket'): 1284,
#          ('java', 'checkbox'): 1283,
#          ('android', 'viewmodel'): 1283,
#          ('java', 'spring-jdbc'): 1280,
#          ('android', 'text-to-speech'): 1280,
#          ('android', 'material-components-android'): 1279,
#          ('java', 'java-9'): 1277,
#          ('java', 'apache-axis'): 1276,
#          ('java', 'timestamp'): 1276,
#          ('android', 'imagebutton'): 1275,
#          ('android', 'android-architecture-navigation'): 1274,
#          ('java', 'spring-cloud'): 1272,
#          ('android', 'android-8.0-oreo'): 1272,
#          ('java', 'android-ndk'): 1269,
#          ('android', 'seekbar'): 1268,
#          ('java', 'dropwizard'): 1267,
#          ('java', 'formatting'): 1266,
#          ('java', 'stored-procedures'): 1266,
#          ('java', 'pojo'): 1266,
#          ('java', 'java.util.concurrent'): 1265,
#          ('java', 'vert.x'): 1265,
#          ('android', 'dependencies'): 1264,
#          ('java', 'aws-lambda'): 1261,
#          ('java', 'cordova'): 1260,
#          ('android', 'shell'): 1259,
#          ('java', 'flutter'): 1259,
#          ('android', 'google-play-games'): 1258,
#          ('java', 'certificate'): 1257,
#          ('java', 'floating-point'): 1257,
#          ('java', 'htmlunit'): 1257,
#          ('java', 'amazon-dynamodb'): 1257,
#          ('android', 'web'): 1255,
#          ('java', 'apache-flink'): 1252,
#          ('java', 'tomcat8'): 1251,
#          ('java', 'android-gradle-plugin'): 1247,
#          ('android', 'toast'): 1244,
#          ('android', 'tcp'): 1244,
#          ('java', 'ehcache'): 1242,
#          ('java', 'output'): 1239,
#          ('java', 'oauth'): 1238,
#          ('java', 'clojure'): 1237,
#          ('android', 'crashlytics'): 1236,
#          ('android', 'localization'): 1234,
#          ('java', 'foreach'): 1233,
#          ('java', 'installation'): 1230,
#          ('android', 'android-menu'): 1230,
#          ('android', 'dynamic'): 1229,
#          ('java', 'dialog'): 1228,
#          ('java', 'google-cloud-datastore'): 1228,
#          ('java', 'spring-data-mongodb'): 1228,
#          ('java', 'scenebuilder'): 1228,
#          ('java', 'apache-spark-sql'): 1228,
#          ('android', 'save'): 1227,
#          ('android', 'manifest'): 1227,
#          ('java', 'amazon-ec2'): 1226,
#          ('java', 'android-viewpager'): 1225,
#          ('java', 'dao'): 1221,
#          ('java', 'connection-pooling'): 1218,
#          ('android', 'bundle'): 1217,
#          ('android', 'browser'): 1215,
#          ('android', 'https'): 1214,
#          ('android', 'android-workmanager'): 1214,
#          ('java', 'format'): 1211,
#          ('java', 'servlet-filters'): 1210,
#          ('java', 'jboss7.x'): 1209,
#          ('java', 'twitter'): 1208,
#          ('android', 'android-broadcast'): 1208,
#          ('java', 'gridbaglayout'): 1202,
#          ('java', 'compiler-construction'): 1201,
#          ('android', 'touch-event'): 1201,
#          ('android', 'dagger'): 1200,
#          ('java', 'opengl-es'): 1198,
#          ('android', 'android-studio-3.0'): 1198,
#          ('java', 'stack-overflow'): 1195,
#          ('android', 'serialization'): 1193,
#          ('android', 'android-tablelayout'): 1193,
#          ('android', 'dagger-hilt'): 1189,
#          ('android', 'layout-inflater'): 1188,
#          ('android', 'android-collapsingtoolbarlayout'): 1188,
#          ('android', 'android-4.0-ice-cream-sandwich'): 1187,
#          ('java', 'jdbctemplate'): 1186,
#          ('android', 'graphics'): 1184,
#          ('java', 'completable-future'): 1184,
#          ('java', 'hashtable'): 1182,
#          ('java', 'tostring'): 1181,
#          ('java', 'oracle11g'): 1181,
#          ('android', 'android-tabs'): 1179,
#          ('java', 'browser'): 1178,
#          ('java', 'notifications'): 1177,
#          ('android', 'callback'): 1172,
#          ('java', 'jnlp'): 1171,
#          ('android', 'ubuntu'): 1170,
#          ('java', 'internationalization'): 1169,
#          ('android', 'accessibility'): 1168,
#          ('java', 'ejb-3.0'): 1162,
#          ('java', 'firefox'): 1161,
#          ('java', 'r'): 1161,
#          ('android', 'server'): 1160,
#          ('java', 'firebase-authentication'): 1160,
#          ('java', 'jtree'): 1159,
#          ('java', 'protocol-buffers'): 1158,
#          ('android', 'genymotion'): 1158,
#          ('java', 'hazelcast'): 1152,
#          ('android', 'share'): 1151,
#          ('android', 'air'): 1151,
#          ('android', 'zooming'): 1150,
#          ('java', 'yaml'): 1147,
#          ('java', 'google-api'): 1143,
#          ('android', 'android-gallery'): 1143,
#          ('java', 'terminal'): 1137,
#          ('android', 'augmented-reality'): 1137,
#          ('android', 'android-navigation'): 1136,
#          ('android', 'achartengine'): 1133,
#          ('java', 'mouselistener'): 1132,
#          ('java', 'jfilechooser'): 1131,
#          ('android', 'android-alarms'): 1131,
#          ('android', 'android-listfragment'): 1131,
#          ('java', 'hsqldb'): 1130,
#          ('android', 'logging'): 1127,
#          ('java', 'reactjs'): 1126,
#          ('java', 'keycloak'): 1126,
#          ('java', 'proguard'): 1124,
#          ('java', 'kubernetes'): 1124,
#          ('java', 'controller'): 1123,
#          ('java', 'camera'): 1122,
#          ('java', 'comparable'): 1121,
#          ...})

# %%
# Dataframe from Counter
df_all_tuples = pd.DataFrame.from_dict(c_all_tuples, orient='index').reset_index()
df_all_tuples.columns = ['index', 'count']
# Tuple to columns
df_all_tuples['tag1'] = df_all_tuples['index'].apply(lambda x: x[0])
df_all_tuples['tag2'] = df_all_tuples['index'].apply(lambda x: x[1])
df_all_tuples.columns = ['index', 'count', 'tag1', 'tag2']
# delete index column
del df_all_tuples['index']
df_all_tuples['crypto'] = df_all_tuples['tag2'].apply(lambda x: x in l_tags_top_crypto)
df_all_tuples['rank'] = df_all_tuples['count'].rank(ascending=False)
df_all_tuples = df_all_tuples.sort_values('rank')
display(df_all_tuples)
# Out:
#         count     tag1               tag2  crypto     rank
# 73     128083     java             spring   False      1.0
# 16      79498     java              swing   False      2.0
# 17292   74193     java        spring-boot   False      3.0
# 9605    67465  android     android-studio   False      4.0
# 44      59401     java            eclipse   False      5.0
# ...       ...      ...                ...     ...      ...
# 32956       1     java  access-protection   False  42940.5
# 17518       1  android     plugin-pattern   False  42940.5
# 40097       1  android   browsermob-proxy   False  42940.5
# 17509       1  android            ecma262   False  42940.5
# 48892       1     java      boomerang-app   False  42940.5
#
# [48893 rows x 5 columns]

# %%
df_all_tuples_10 = df_all_tuples.head(10)
del(df_all_tuples_10['crypto'])
df_all_tuples_10 = df_all_tuples_10.reset_index(drop=True)
# Rename columns
df_all_tuples_10.columns = ['Count', 'Tag1', 'Tag2', 'Rank']
df_all_tuples_10['Rank'] = df_all_tuples_10['Rank'].astype(int)
df_all_tuples_10['Count'] = df_all_tuples_10['Count'].apply(lambda x: "{:,}".format(x))
# Print as LaTeX table
print(df_all_tuples_10.to_latex(index=False))
# Out:
# \begin{tabular}{lllr}
# \toprule
# Count & Tag1 & Tag2 & Rank \\
# \midrule
# 128,083 & java & spring & 1 \\
# 79,498 & java & swing & 2 \\
# 74,193 & java & spring-boot & 3 \\
# 67,465 & android & android-studio & 4 \\
# 59,401 & java & eclipse & 5 \\
# 58,764 & java & hibernate & 6 \\
# 57,068 & android & android-layout & 7 \\
# 55,218 & android & kotlin & 8 \\
# 52,237 & java & arrays & 9 \\
# 47,781 & java & maven & 10 \\
# \bottomrule
# \end{tabular}

# %%
df_all_tuples.loc[df_all_tuples['crypto']==True]
# Out:
#        count     tag1                   tag2  crypto     rank
# 2379   10932  android                  image    True     85.0
# 175     9098     java                  image    True    111.0
# 22      7947     java                    c++    True    130.0
# 598     7554     java                    ssl    True    143.0
# 163     6936     java             encryption    True    159.0
# ...      ...      ...                    ...     ...      ...
# 7524      11  android               blowfish    True  17678.5
# 18563     10  android               rijndael    True  18416.0
# 15726      8  android              tripledes    True  20214.5
# 25468      6  android               cbc-mode    True  22748.0
# 11456      6  android  initialization-vector    True  22748.0
#
# [100 rows x 5 columns]

# %%
# Print as LaTeX table
df_all_tuples_latex = df_all_tuples.loc[df_all_tuples['crypto']==True].copy()
del(df_all_tuples_latex['crypto'])
# Only the top 20
df_all_tuples_latex = df_all_tuples_latex.head(20)
df_all_tuples_latex = df_all_tuples_latex.reset_index(drop=True)
# Rename columns
df_all_tuples_latex.columns = ['Count', 'Tag1', 'Tag2', 'Rank']
df_all_tuples_latex['Rank'] = df_all_tuples_latex['Rank'].astype(int)
# Print as LaTeX table
print(df_all_tuples_latex.to_latex(index=False))
# Out:
# \begin{tabular}{rllr}
# \toprule
# Count & Tag1 & Tag2 & Rank \\
# \midrule
# 10932 & android & image & 85 \\
# 9098 & java & image & 111 \\
# 7947 & java & c++ & 130 \\
# 7554 & java & ssl & 143 \\
# 6936 & java & encryption & 159 \\
# 6180 & java & security & 189 \\
# 6120 & android & c++ & 191 \\
# 4477 & java & authentication & 263 \\
# 3382 & android & authentication & 330 \\
# 2767 & java & cryptography & 399 \\
# 2600 & android & security & 426 \\
# 2514 & android & encryption & 446 \\
# 2388 & java & https & 472 \\
# 2333 & android & ssl & 488 \\
# 1958 & java & httpurlconnection & 592 \\
# 1911 & java & hash & 609 \\
# 1854 & java & httpclient & 629 \\
# 1833 & java & aes & 634 \\
# 1788 & android & httpurlconnection & 651 \\
# 1755 & java & bouncycastle & 666 \\
# \bottomrule
# \end{tabular}
